# %%
pip install mysql
# Out:
# Collecting mysql
#   Downloading mysql-0.0.3-py3-none-any.whl.metadata (746 bytes)
# Collecting mysqlclient (from mysql)
#   Downloading mysqlclient-2.2.7-cp313-cp313-win_amd64.whl.metadata (4.8 kB)
# Downloading mysql-0.0.3-py3-none-any.whl (1.2 kB)
# Downloading mysqlclient-2.2.7-cp313-cp313-win_amd64.whl (208 kB)
# Installing collected packages: mysqlclient, mysql
#
#    ---------------------------------------- 2/2 [mysql]
#
# Successfully installed mysql-0.0.3 mysqlclient-2.2.7
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.common.exceptions import StaleElementReferenceException, NoSuchAttributeException
from webdriver_manager.chrome import ChromeDriverManager
import time

service = Service(ChromeDriverManager().install())

options = Options()
options.add_argument("--window-size=1920x1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent = Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/139.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")

driver = webdriver.Chrome(service=service, options=options)

categorys = ["001001","001005","001004"]

data = []

for category in categorys:
    url = f"https://display.wconcept.co.kr/category/women/{category}"
    driver.get(url)
    time.sleep(2)
    print(f"\n\n-----------{category} 카테고리 ------")


    try:
        try : 
            last_height = driver.execute_script("return document.body.scrollHeight")
            scroll_pause = 1
        except Exception as e: 
            print("스크롤 내림 실패 : ", e)
        
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);") 
        cards = driver.find_elements(By.CSS_SELECTOR,"span.sc-jpuob9-6.ejEjBO.area-info")
        for i, card in enumerate(cards, 1):
            try:
                title = card.find_element(By.CSS_SELECTOR, "span.sc-tdjdw3-0.frpBAf.text.title").text.strip()
            except:
                title = ""                
            try:
                score = card.find_element(By.CSS_SELECTOR, "em.score").text.strip()
            except:
                score = ""
            try:
                review = card.find_element(By.CSS_SELECTOR, "span.sc-tdjdw3-0.frpBAf.text.cnt").text.strip()
            except:
                review = ""                
       
            print(f"{i}. {title},{score},{review}")
            data.append({"상품명": title, "평점": score, "리뷰수": review})

        time.sleep(2)
        idx += 1
    except StaleElementReferenceException:
        print(f"{idx+1}번째 요소 실패. 재시도")
        time.sleep(1)
        continue
driver.quit()
# Out:
# -----------001001 카테고리 ------
# 1. 올리브데올리브,4.9,(141)
# 2. 던스트,5.0,(8)
# 3. 틸아이다이,4.9,(612)
# 4. 이바나헬싱키,4.9,(610)
# 5. 망고매니플리즈,,1,035
# 6. 아디다스,4.9,(45)
# 7. 프론트로우,4.9,(130)
# 8. 르하스,4.9,(123)
# 9. 틸아이다이,5.0,(5)
# 10. 잇미샤,4.9,(33)
# 11. 더라우스트,5.0,(3)
# 12. 올리브데올리브,4.8,(6)
# 13. 망고매니플리즈,4.9,(163)
# 14. 르로망,4.9,(59)
# 15. 하네,,1,092
# 16. 아우어노스텔지아,4.8,(48)
# 17. 마롭,5.0,(28)
# 18. 제이청,,1,300
# 19. 룩캐스트,4.9,(561)
# 20. 르메메,4.9,(102)
# 21. 프론트로우,4.9,(629)
# 22. 누토프,4.8,(4)
# 23. 룩캐스트,,1,262
# 24. 모한,5.0,(90)
# 25. 플로움,5.0,(68)
# 26. 뮤제,5.0,(4)
# 27. 틸아이다이,4.9,(281)
# 28. 우알롱,5.0,(8)
# 29. 에잇데이즈어위크,4.9,(82)
# 30. 에트몽,5.0,(254)
# 31. 모한,4.9,(92)
# 32. 틸아이다이,5.0,(143)
# 33. 르하스,4.9,(70)
# 34. 르세지엠,4.7,(182)
# 35. 이바나헬싱키,5.0,(18)
# 36. 르로망,4.9,(19)
# 37. 뮤제,,674
# 38. 우알롱,5.0,(8)
# 39. 틸아이다이,4.9,(130)
# 40. 루에브르,5.0,(22)
# 41. 이바나헬싱키,5.0,(92)
# 42. 프론트로우,5.0,(47)
# 43. 이바나헬싱키,4.9,(13)
# 44. 프론트로우,,1,493
# 45. 메무아,5.0,(8)
# 46. 룩캐스트,4.8,(446)
# 47. 에트몽,5.0,(62)
# 48. 루에브르,4.8,(412)
# 49. 모한,5.0,(10)
# 50. 엔오르,5.0,(323)
# 51. 틸아이다이,4.9,(56)
# 52. 비에이유 바이 브라이드앤유,5.0,(8)
# 53. 우알롱,5.0,(6)
# 54. 우알롱,5.0,(8)
# 55. 우알롱,5.0,(7)
# 56. 올리브데올리브,4.9,(14)
# 57. 우알롱,5.0,(11)
# 58. 온앤온,4.8,(42)
# 59. 비에이유 바이 브라이드앤유,5.0,(19)
# 60. 온앤온,4.9,(17)
#
#
# -----------001005 카테고리 ------
# 1. 폴앤앨리스,5.0,(73)
# 2. 아무르 무아르,4.9,(1,470)
# 3. 슬로우롤리,5.0,(249)
# 4. 이바나헬싱키,4.9,(143)
# 5. 제로스트릿,5.0,(187)
# 6. 안젤로 비안코,4.9,(141)
# 7. 플로움,4.9,(804)
# 8. 해바이해킴,4.9,(41)
# 9. 비에이유 바이 브라이드앤유,4.8,(19)
# 10. 드헤베,4.9,(69)
# 11. 비에이유 바이 브라이드앤유,4.9,(368)
# 12. 해바이해킴,4.9,(44)
# 13. 플로움,4.9,(152)
# 14. 플로움,4.9,(50)
# 15. 비에이유 바이 브라이드앤유,4.9,(36)
# 16. 그레이스유,4.9,(146)
# 17. 플로움,4.9,(696)
# 18. 프론트로우,4.8,(43)
# 19. 비에이유 바이 브라이드앤유,5.0,(120)
# 20. 비에이유 바이 브라이드앤유,5.0,(18)
# 21. 하시에,4.9,(614)
# 22. 슬로우롤리,5.0,(107)
# 23. 잇미샤,4.9,(31)
# 24. 비에이유 바이 브라이드앤유,4.9,(201)
# 25. 라메레이,4.9,(204)
# 26. 더케미,4.9,(30)
# 27. 토와브,4.9,(27)
# 28. 무니드,5.0,(20)
# 29. 마인드브릿지 우먼,4.9,(164)
# 30. 플로움,5.0,(573)
# 31. 아무르 무아르,4.9,(832)
# 32. 비에이유 바이 브라이드앤유,4.8,(26)
# 33. 플로움,4.9,(624)
# 34. 명주루,5.0,(24)
# 35. 비에이유 바이 브라이드앤유,4.9,(147)
# 36. 플로움,4.9,(50)
# 37. 플로움,5.0,(107)
# 38. 브아빗포우먼,4.8,(125)
# 39. 플로움,4.9,(608)
# 40. 플로움,5.0,(21)
# 41. 주르티,5.0,(12)
# 42. 루에브르,5.0,(249)
# 43. 플로움,5.0,(11)
# 44. 그레이스유,5.0,(24)
# 45. 나이스클랍,4.7,(31)
# 46. 이바나헬싱키,4.9,(91)
# 47. 히비스커스블룸,4.9,(83)
# 48. 바시카,4.9,(94)
# 49. 더라우스트,5.0,(44)
# 50. 이바나헬싱키,5.0,(44)
# 51. 비에이유 바이 브라이드앤유,4.9,(166)
# 52. 이바나헬싱키,4.9,(19)
# 53. 비에이유 바이 브라이드앤유,4.9,(139)
# 54. 프론트로우,4.9,(82)
# 55. 비에이유 바이 브라이드앤유,4.9,(17)
# 56. 안토메,4.9,(9)
# 57. 이바나헬싱키,5.0,(29)
# 58. 플로움,5.0,(9)
# 59. 라메레이,5.0,(13)
# 60. 플로움,4.8,(13)
#
#
# -----------001004 카테고리 ------
# 1. 아틀리에 나인,4.9,(1,006)
# 2. 로브로브,5.0,(362)
# 3. 프론트로우,4.9,(60)
# 4. 제이청,4.9,(68)
# 5. 주르티,4.7,(83)
# 6. 모센틱,5.0,(27)
# 7. 아워코모스,5.0,(2,112)
# 8. 오브에르,4.9,(183)
# 9. 잇미샤,5.0,(183)
# 10. 드헤베,4.9,(268)
# 11. 아무르 무아르,4.9,(58)
# 12. 루에브르,5.0,(526)
# 13. 아무르 무아르,4.9,(21)
# 14. 우이,4.9,(239)
# 15. 틸아이다이,5.0,(39)
# 16. 로트르드민,5.0,(91)
# 17. 르와,4.8,(68)
# 18. 아무르 무아르,4.9,(1,398)
# 19. 비바셔스,4.9,(165)
# 20. 프론트로우,4.8,(56)
# 21. 쥬아르,4.9,(137)
# 22. 언에디트,4.9,(137)
# 23. 주르티,4.9,(50)
# 24. 언에디트,5.0,(85)
# 25. 라츠유,5.0,(182)
# 26. 틸아이다이,4.9,(52)
# 27. 리엘,4.9,(90)
# 28. 르와,4.9,(191)
# 29. 티프오브,4.9,(30)
# 30. 제로스트릿,4.9,(431)
# 31. 로라로라,4.9,(371)
# 32. 르와,4.9,(104)
# 33. 아무르 무아르,4.9,(832)
# 34. 메무아,5.0,(4)
# 35. 드로우핏 우먼,4.9,(267)
# 36. 드헤베,4.9,(607)
# 37. 프론트로우,4.9,(85)
# 38. 아워코모스,4.9,(1,421)
# 39. 제이 쿠,5.0,(117)
# 40. 엽페,4.9,(137)
# 41. 브아빗포우먼,4.8,(125)
# 42. 헌치,5.0,(34)
# 43. 르와,5.0,(44)
# 44. 잇미샤,5.0,(6)
# 45. 히비스커스블룸,4.9,(116)
# 46. 리엘,4.9,(216)
# 47. 디애니,4.9,(236)
# 48. 킨더살몬,4.9,(116)
# 49. 시그레이트,4.9,(57)
# 50. 잇미샤,4.9,(133)
# 51. 오브에르,4.7,(26)
# 52. 하우스 오브 폰드,4.9,(53)
# 53. 비에이유 바이 브라이드앤유,4.9,(316)
# 54. 플로움,4.9,(19)
# 55. 주르티,4.9,(363)
# 56. 무니드,4.9,(45)
# 57. 루에브르,4.9,(72)
# 58. 로라로라,4.9,(211)
# 59. 이아,4.9,(350)
# 60. 틸아이다이,4.8,(22)

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from webdriver_manager.chrome import ChromeDriverManager
import time
import mysql.connector

service = Service(ChromeDriverManager().install())

options = Options()
options.add_argument("--window-size=1920x1080")

options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")

driver = webdriver.Chrome(service=service, options=options)

categorys = ["001013", "001005", "001001008", "001001010", "001001003", "001001011", "001001007" ]

for category in categorys:
    url = f"https://display.wconcept.co.kr/category/women/{category}"
    driver.get(url)
    time.sleep(3)

    print(f"\n\n========== {category} 카테고리 여성의류==========")

    idx = 0
    while idx < 30:
        try:
            buttons = driver.find_elements(By.CSS_SELECTOR, "button.area-img")
            if idx >= len(buttons):
                break

            driver.execute_script("arguments[0].click();", buttons[idx])
            time.sleep(3)

            print(f"\n----- {category} {idx+1}번째 의류 -----")

            try:
                title = driver.find_element(By.CSS_SELECTOR, "h2.brand").text.strip()
            except NoSuchElementException:
                title = "상품명 없음"

            try:
                rate = driver.find_element(By.CSS_SELECTOR, "p.grade_num").text.strip()
            except NoSuchElementException:
                rate = "0"

            try:
                review_num = driver.find_element(By.CSS_SELECTOR, "#reviewCnt1").text.strip()
            except NoSuchElementException:
                review_num = "0"

            # 리뷰 (최대 3개)
            reviews = []
            try:
                driver.execute_script("window.scrollBy(0, 300);")
                time.sleep(0.5)
                review_button = driver.find_element(By.CSS_SELECTOR, "#detail > li:nth-child(2)")
                review_button.click()
                time.sleep(3)

                review_elements = driver.find_elements(By.CSS_SELECTOR, "p.pdt_review_text")
                reviews = [r.text.strip() for r in review_elements[:3]]

                if not reviews:
                    reviews = ["댓글 정보 없음"]

            except NoSuchElementException:
                reviews = ["댓글 정보 없음"]

            print("상품명:", title)
            print("평점:", rate)
            print("리뷰수:", review_num)
            for i, review in enumerate(reviews, start=1):
                print(f"리뷰{i}:", review)

            # save_to_db(category, title, rate, review_num)

            driver.back()
            time.sleep(1)
            driver.back()
            time.sleep(2)
            driver.execute_script("window.scrollBy(0, 200);")
            time.sleep(1)

            idx += 1

        except StaleElementReferenceException:
            print(f"{idx+1}번째 요소 stale 참조 발생, 재시도")
            time.sleep(1)
            continue

driver.quit()
# Out:
# ========== 001001001 카테고리 여성의류==========
#
# ----- 001001001 1번째 의류 -----
# 상품명: Dunst for WOMEN
# 평점: 5
# 리뷰수: 8
# 리뷰1: 브라운 색상으로 사이즈 진짜 고민 많이 했는데
# 키가 커서 m했는데 아주 찰떡 !
# 평소에도 아우터는 한치수나 두치수 업해서
# 입기때문에 사이즈 아주 굿 좋아요
# 리뷰2: 던스트 신상나와서 바로 구매했어요!
# 아우터는 조금 크게나오는듯해서 XS로 주문했는데 잘 주문한것같아요!! S했으면 어정쩡하게 커서 어색했을것같아요!! 입어봤는데 박시핏에 길이도 넉넉해서 예뻐요!!
# 리뷰3: 예뻐요..! S랑 고민했는데 XS 하길 너무 잘했어요 ! 색도 너무 예쁘고 두루두루 어울릴 거 같아요!
#
# ----- 001001001 2번째 의류 -----
# 상품명: IvanaHelsinki단독
# 평점: 4.9
# 리뷰수: 610
# 리뷰1: 디자인이랑 컬러는 사진이랑 똑같아요 맘에듬!
# 사이즈는 평소에 s사이즈 자켓입는데 작은듯하면서 따악 맞는느낌이라 요즘 살이좀 쪘나싶은 ㅎㅎ 옷이이쁘니까 그냥 조금만 빼서 입으면 될듯용 하나큰거샀음 좀 애매했을거같아요!
# 리뷰2: 상견례용으로 구입했는데 옷은 예뻐요
# 근데 다들 어깨뽕 어떻게 하셨나요? 잘 맞으시나요..?
# 리뷰3: 가슴이 좀 큰 편이라 플러스 사이즈 구매했는데 불편하지 않고 좋아요!! 스커트와 함께 입으니 정말 예뻐요~
#
# ----- 001001001 3번째 의류 -----
# 상품명: MangoManyPlease
# 평점: 0
# 리뷰수: 0
# 리뷰1: 댓글 정보 없음
#
# ----- 001001001 4번째 의류 -----
# 상품명: ADIDAS
# 평점: 4.9
# 리뷰수: 46
# 리뷰1: 역시 아디다스네요.
# 기본컬러 트랙탑이라 정말 1도 고민 안하고 구매했어요.
# 역시나 핏도 길이도 너무 맘에 들고 화이트 롱스커트에 잠깐 매치해봤는데도 아묻따 예쁘네요.
# 리뷰2: 라지 사이즈 적당하고 딱 좋아요 키165에 77사이즈 날씬해보이네요
# 리뷰3: 얇은 너무박시하지 않은 딱 원하던 ^^ 너무잘샀어요~~
#
# ----- 001001001 5번째 의류 -----
# 상품명: FRONTROW단독
# 평점: 4.9
# 리뷰수: 131
# 리뷰1: 예쁘고 소재가 조금 두껍지만
# 핏이 예쁩니다 허리벨드가 많이 길어요
# 역시 옷을 잘 만드는 브랜드같아요.
# 리뷰2: 마음에 들어요. 좀 시원해지면 입으려구요~~
# 리뷰3: 너무 예뻐요!
# 진짜 잘 샀어요
# 역시 가성비는 프론트로우
# 긴 자켓인데 허리끈이 핏을 잡아줘서 저같은 키작녀가 입어도 다리 안 짧아보여요
# 회색 자켓 흔한데 허리끈 디테일 덕에 색달라 보이고.. 너무 맘에 듭니다
#
# ----- 001001001 6번째 의류 -----
# 상품명: L’H.A.S
# 평점: 4.9
# 리뷰수: 123
# 리뷰1: 예뻐요~안에 옷을 잘 챙겨 입어야 할 것 같아요.
# 리뷰2: 소재가 탄탄해요 바스트가 있는편인데 잘 맞아서 다행이네여
# 입다보니 소매 끝단이 풀림이 있어요
# 리뷰3: 저한테는 약간 큰 듯 하지만 바지랑 잘어울려요
#
# ----- 001001001 7번째 의류 -----
# 상품명: IT MICHAA
# 평점: 4.9
# 리뷰수: 33
# 리뷰1: 사이즈 딱 맞고
# 라인도 이쁘고 비침 없이 구김 없이 완전 만족
# 요새 상의 짧은 것이 많은데 그거 싫으시면 이제 딱
# 리뷰2: 청바지랑도 잘 어울려요
# 리뷰3: 디자인이 너무 깔끔하게 떨어지고 패브릭도 여름에 시원하게 입을 수 있는 소재로 넘 밈에 들어요...격식 있는 자리에 입기에 충분힙니다. 망설이지 마세요~ 사이즈는 낙낙하니 참고하세요^^
#
# ----- 001001001 8번째 의류 -----
# 상품명: MangoManyPlease
# 평점: 4.9
# 리뷰수: 163
# 리뷰1: 원피스에 입어보려고 샀어요.
# 핏이 생각보다 더 이쁘게 빠지더라구요
# 아주 잘 산거 같아요
# 리뷰2: 살이 쪄서 넉넉한 사이즈 옷을 샀는데 멋스럽네요
# 이번달 말에 호주가는데 입어야겠어요 ㅎ
# 리뷰3: 완전 스타일리쉬해보이고 좋아욧
#
# ----- 001001001 9번째 의류 -----
# 상품명: LE ROMAN
# 평점: 4.9
# 리뷰수: 60
# 리뷰1: 두께감 있어서 고급스러운거같아여
# 보통 55사이즈 입는데 타이트해요
# 리뷰2: 언니 결혼식때 입으려고 구매했어요 팔쪽이 조금 타이트 하기는 하지만 더 큰 사이즈는 클거같아서 교환없이 입으려구요 소재가 좋고 약감 바른자세 하게되는 옷이에요 어깨뽕이 살짝있어서 핏이 예뻐요
# 리뷰3: 1사이즈 예쁘게 딱 맞아요
# 어깨뽕이 폭신한데 그래서 핏이 예뻐보여요
# 암튼 비싼값을 하네용
#
# ----- 001001001 10번째 의류 -----
# 상품명: HANE
# 평점: 0
# 리뷰수: 0
# 리뷰1: 댓글 정보 없음
#
# ----- 001001001 11번째 의류 -----
# 상품명: MaLoupe
# 평점: 5
# 리뷰수: 28
# 리뷰1: 소재가 고급져보이지는 않지만 핏은 좋네요
# 리뷰2: 소재가 생각한것과는 좀 다른 느낌이었지만 핏이 너무 오버핏도 아니고 적당해서 아주 잘 활용해서 입을거 같아요!
# 리뷰3: 좀더 오버핏이길 바랬으나 살짝 오버핏이에요 출근룩으로 입기에는 괜찮아요 힙하게 입기이는 점잖은 옷입니다
#
# ----- 001001001 12번째 의류 -----
# 상품명: LOOKAST
# 평점: 4.9
# 리뷰수: 563
# 리뷰1: 바지랑 세트로 구매했는데
# 캐주얼로도 오프스룩으로도 입을수 있을거 같아요
# 칙칙하지 않은 아이보리라 좋아요!
# 리뷰2: 시원한 소재로 여름에 입으면 좋을거같아서 구매했는데 만족
# 리뷰3: 생각보다 제어깨가좁아서인지 어벙벙해보여요
# 그래서뭔가옷이 남의옷입은느낌이랄까 천은 괜찮아요 반바지도좋구요 자켓만좀어벙벙해서 한사이즈작은거사야했을까싶어요
#
# ----- 001001001 13번째 의류 -----
# 상품명: NUTOFFE
# 평점: 4.8
# 리뷰수: 4
# 리뷰1: 결혼식에 입으려고 샀어요 격식 있는 자리 아주 고급스럽고 예쁘게 잘 어울릴 거 같애요. 착용감도 좋고 다만 소재가 보푸라기가 일어날 거 같은 소재긴 한데 관리만 잘하면 크게 신경 쓰이지 않을 거 같애요. 마감이나 디테일도 훌륭하고 왜 누토프 찾는지 알겠어요.
# 리뷰2: 처음 보는 브랜드라 고민했는데 고민은 배송만 늦출 뿐! 너무 이쁘고 고급스러운 자켓입니다. 라인도 날씬하게 빠지고 모양도 잘 잡혀있어요- 정55사이즈 입는데 여유있게 잘 맞아요!
# 리뷰3: 사이즈교환하여 오늘받았어요
# 쿠폰사용하여 좋은가격에 구매했습니다
#
# ----- 001001001 14번째 의류 -----
# 상품명: LOOKAST
# 평점: 0
# 리뷰수: 0
# 리뷰1: 댓글 정보 없음
#
# ----- 001001001 15번째 의류 -----
# 상품명: FLOWOOM
# 평점: 5
# 리뷰수: 69
# 리뷰1: 한 눈에 보고 넘 예뻐서 바로 샀어요. 사이즈 1은 살짝 불편하고 2는 편한데 겨드랑이쪽이 많이 남긴 하네요ㅠ 자주 손 가려면 편한 사이즈가 좋을 듯 합니다
# 리뷰2: 하객용이나 격식있는 자리에 어울리는 옷이에요
# 마음에 쏙 들어요
# 리뷰3: 정말 잘 테일러된 고급스러운 자켓이네요. 예쁘긴하지만 한여름에 입기엔 살짝 도톰한 재질이고 팔뚝살이 부각되어 보이는게 단점이에요
#
# ----- 001001001 16번째 의류 -----
# 상품명: EIGHT DAYS A WEEK
# 평점: 4.9
# 리뷰수: 82
# 리뷰1: 여행내내 너무 이쁘게 잘 입었습니다 바지 치마 원피스 모든 옷에 너무 잘어울려요 사이즈도 적당한 오버핏에 카라가 포인트 됩니다
# 리뷰2: 적당하게 오버핏 돼서 좋아요
# 리뷰3: 넘 맘에듭니다 프리사이즈라서 66까지도 잘맞을듯해요 편하게 걸치기 좋은 스타일이에요 만족합니다
#
# ----- 001001001 17번째 의류 -----
# 상품명: ETMON
# 평점: 5
# 리뷰수: 254
# 리뷰1: 예쁩니다🖤
# 하객룩이나 중요한날 입기 좋구
# 사진이랑 똑같네요
# 핏도 맘에 들구
# 얇아서 여름에 입기 조아용
# 단추도 귀엽고 ㅎㅎㅎ 만족합니다
# 리뷰2: 짱예쁨🖤🖤🤍🤍
# 리뷰3: 소재도 시원한 소재고 차려 입어야 할때 입기 딱이예요 다만 사이즈가 에스 치고 좀 큰편인거 같아요..ㅠ 그래듀 이뻐서 입으려구요!
#
# ----- 001001001 18번째 의류 -----
# 상품명: TILLIDIE
# 평점: 5
# 리뷰수: 145
# 리뷰1: 딱 적당한 핏이면서 디자인도 넘나 예뻐요. 입자마자 맘에 쏙 들었어요!!
# 리뷰2: 생각보다 많이 크긴한데 여름자켓이 없어서
# 품으려고 합니다~
#
# 두꺼워서 지금부터 한동안 잘 입을꺼 같아요
# 리뷰3: 생각보다 살짝 커서 여유있어서 편하게 입기좋아요
# 세일할때 좋게 구매했어요
#
# ----- 001001001 19번째 의류 -----
# 상품명: L’H.A.S
# 평점: 4.9
# 리뷰수: 70
# 리뷰1: 반팔 디자인 구매해서 잘 입어서 긴팔 버전도 구매함 팔 단추 걷을수 있는 디자인이라 좋음 생각보다 원단은 하늘하늘한 얇은 원단임
# 리뷰2: 너무이쁨!!!! 입으니까 더이쁨 너무 맘에들어요 딱 내 추구미임
# 리뷰3: 비싼감이 없지않아 있지만 디자인이 맘에 들고 비슷한건 못봐서 사버렸는데 포장도 깔끔하게 오고 핏도 괜찮아서 맘에 들어요 주머니는 순간 페이큰줄알고 뭐지했는데 뜯는거였네여 무게도 생각보다 더 가벼워서 좋아요
#
# ----- 001001001 20번째 의류 -----
# 상품명: LESEIZIEME
# 평점: 4.7
# 리뷰수: 182
# 리뷰1: 한참 고민하다 주문했는데 만족스러워요!
# 좀 무거운거 빼곤 디자인도 기장도 만족합니다
# 리뷰2: 많은 분들이 리뷰에 남긴 것 처럼 무게는 꽤 나가는 편이고, 시큼한... 그런 좋지 않은 냄새가 나요. 냄새가 잘 빠지지 않는 부분이 조금...
# 디자인이나 다른 부분은 마음에 듭니다.
# 리뷰3: 빳빳한 캔버스 코튼 소재라서 불편할까봐 구매를 망설였어요. 후기에도 엄청 크다고 하구요.
#
# 그런데 막상 배송와서 입어보니 핏이 아방하고 귀엽게 이쁘구 소매도 접어 입으니 코튜로이 소매 안감이 보이고 체크 안감이 살짝 보이면서 더더 귀엽습니다. 소매 접으니 길지 않아 더 좋았어요.
#
# 캔버스 소재가 바람을 칼차단해줘서 초겨울까지 입을 수 있을 것 같아요. 마감도 좋고 다른 리뷰들처럼 이상한 냄새가 살짝 나긴해요. 금방 빠지길 바라며 가을을 기다려보겠습니다. 넘 맘에드는 쇼핑이었어요!
#
# ----- 001001001 21번째 의류 -----
# 상품명: IvanaHelsinki단독
# 평점: 5
# 리뷰수: 19
# 리뷰1: 진짜엄청편하고 날씬해보여요~~다른색도 사고싶어요~~!!
# 리뷰2: 마음에들어요!
# 리뷰3: 결혼식때 입으려고구매했어요 생각보다 두껍지않은 트위드..? 같은 소재이고 가격대비 괜찮은것같애서 좋아요 사진이 좀 뿌옇게 나왔어요
#
# ----- 001001001 22번째 의류 -----
# 상품명: LE ROMAN
# 평점: 4.9
# 리뷰수: 19
# 리뷰1: 어깨패드가 엄청 두꺼워요
# 그래도 어좁이라 부해보이진 않습니다
# 44반에서 55정도 입는데
# a컵 기준 아주 딱맞아요
# 가슴 좀 있으시면 타이트할 것 같네요.
# 리뷰2: 상견례때 입으려고 주문했는데
# 싼티 안나고 마감도 깔끔하구 어께 패드도 자연스러워서
# 어좁이 보완도 되고!! 잘입었어여!!
# 리뷰3: 결혼식 2부 겸 평소에도 입을만한 디자인을 찾고 있었는데 비슷한 디자인들이 많더라구요. 근데 비싸도 이게 계속 아른거려서 결국 구매했어요
# 넘 예쁜데 좀 작게 나온듯 해요 바스트 있는 분들은 단추 벌어질것 같아요 상체 좀 마른편인데 55사이즈 딱 맞네요!
# 근데 진짜 넘 예뻐요ㅎㅎ
# 봄 가을까지 잘 입을듯
#
# ----- 001001001 23번째 의류 -----
# 상품명: IvanaHelsinki단독
# 평점: 5
# 리뷰수: 92
# 리뷰1: 2부 원피스로 딱이에요 색감 완전 새색시 그잡채요
# 리뷰2: 좋ㅇ요
# 리뷰3: 배송도 무척 빨랐고 워낙에 크롭이라 아래 치마랑 세트로 입어야 이뻐요 얇은 트위드라 한여름에도 가능할듯 합니다 하객룩으로 이뻐요
#
# ----- 001001001 24번째 의류 -----
# 상품명: FRONTROW단독
# 평점: 5
# 리뷰수: 47
# 리뷰1: 좋습니다
# 리뷰2: 출근룩으로 입으려고 샀어요.
# 깔끔하니 예쁩니다
# 리뷰3: 옷 너무 이뻐요 잘산것같아여
#
# ----- 001001001 25번째 의류 -----
# 상품명: IvanaHelsinki단독
# 평점: 4.9
# 리뷰수: 13
# 리뷰1: 소재도 시원하고 허리에 라인이 들어가서 날씬해 보여요 M 사이즈가 좀 너무 딱 맞긴 하네요ㅎㅎ
# 리뷰2: 생각보다 사이즈가 많이 작아요
# 리뷰3: 이쁘다3
#
# ----- 001001001 26번째 의류 -----
# 상품명: FRONTROW단독
# 평점: 0
# 리뷰수: 0
# 리뷰1: 댓글 정보 없음
#
# ----- 001001001 27번째 의류 -----
# 상품명: MEMUA
# 평점: 5
# 리뷰수: 9
# 리뷰1: 회사 출근룩으로 깔끔하게 입기 좋아요! 셋업 또는 따로 입기에도 좋을거같습니당
# 자켓에는 어깨뽕이있는데 과하거나 부담스럽지는 않아요!
# 리뷰2: 살짝 큼 .화면느낌그대로..
# 스커트 슬릿이 길어서좋은데 슬릿 박음되어서 안쪽으로 접히는부분이 걸을때 펴져서 좀 보기가~~~~
# 리뷰3: 단정하고 여성스럽습니다
#
# ----- 001001001 28번째 의류 -----
# 상품명: LOOKAST
# 평점: 4.8
# 리뷰수: 446
# 리뷰1: 허리 스트링조일수있어서 여러코디에 입을수있어요.
# 팔이랑소매가 빵빵한편은아니고 공기빠진느낌?
# 드라이기로 부풀려서 걸어뒀어요.
# 자크.똑딱이 그외마감은괜찮은편.
# 목부분 벨벳소재였음 보플안나고좋았을듯.
# 66인데 s도 여유있어요.
# 리뷰2: 예쁜데 목부분 시보리 오염 주의해야할거 가타요
# 리뷰3: 겨울대비 미리 샀는데 출퇴근할때나 편하게 손 많이 갈것같아요
# 따뜻하고 좋습니다
#
# ----- 001001001 29번째 의류 -----
# 상품명: ETMON
# 평점: 5
# 리뷰수: 62
# 리뷰1: 노란기 없는 화이트인 색상이 마음에 드네요. 핏하지 않고 널널한 느낌이에요. 소재도 탄탐하고 좋아요.
# 리뷰2: 너무너무 예뻐요 엄청 고급스러워 보이고 핏도 예쁘고.. 올해 산 옷 중에 제일 마음에 들어요
# 리뷰3: 시원하게 포멀하게 입기 좋은 옷인 것 같습니다. 여름에 정장입어야 할 자리에 갈 때 좋으네요.
#
# ----- 001001001 30번째 의류 -----
# 상품명: LOEUVRE
# 평점: 4.8
# 리뷰수: 412
# 리뷰1: 입으니까 더더 이쁘네요 빨리 가을와서 입고 싶어요ㅜ 사진보다 실물이 더 예뻐서 만족합니당! 배송도 아주 빨랐어요!!
# 리뷰2: 예뻐요 초겨울에도 입을 수 있겠습니다 추천드려영
# 리뷰3: 핏이 정말 예술입니다!! 딱 내가 원하는 핏과 길이감과 소재입니다. 마감이나 디테일은 말모이고요! 봄가을, 초겨울에 잘 입겠습니다!!
#
#
# ========== 001001002 카테고리 여성의류==========
#
# ----- 001001002 1번째 의류 -----
# 상품명: LEMEME
# 평점: 4.9
# 리뷰수: 102
# 리뷰1: 택배 뜯고 옷 커버 보자마자 너무 당황했습니다. 뭐가 묻은건지 탄건지 사진처럼 돼 있어요. 닦이지도 않아요. 옷까지 묻기라도 했을까봐 순간 철렁 했습니다. 포장할때 무조건 보였을꺼 같은데.. 관리가 제대로 된 제품을 보낸걸까 의구심 마저 들었습니다. 옷은 예쁜데 담번에도 이 브랜드 구매할지 여부는 조금 망설여지네요.
# 리뷰2: 제가 찾고 있는 색감에 딱 맞는 버터색 자켓이어서
# 바로 겟했어요!!!
# 저한테 어깨랑 품이 많이 커서 수선해서 입고있어요!
# 소재도 폭닥해서 겨울에도 잘 입을 수 있을거같아요
# 리뷰3: 컬러가 지인짜 예뻐요!!!
#
# ----- 001001002 2번째 의류 -----
# 상품명: MUSEE
# 평점: 5
# 리뷰수: 5
# 리뷰1: 우오ㅏ 진짜 색감도 넘 좋구 착용감이며 핏 굿이에용 ㅎㅎ
# 리뷰2: 세일할때 잘샀어요
# 무겁긴 하지만 고급스럽고 너무 만족스러워요
# 리뷰3: 카라부분 너무 예쁘고 적당한 오버핏에 어깨핏도 마음에 들어요! 생각보다 두툼하고 무거운 코트예요.
# 소재 괜찮아보이긴 하는데 접힌대로 자국이 좀 남는 소재여서 접혀온대로 코트랑 코트끈에 좀 자국이 나있어요. 계속 걸어두면 좀 괜찮아질 거 같아요
#
# ----- 001001002 3번째 의류 -----
# 상품명: MUSEE
# 평점: 0
# 리뷰수: 0
# 리뷰1: 댓글 정보 없음
#
# ----- 001001002 4번째 의류 -----
# 상품명: LOEUVRE
# 평점: 5
# 리뷰수: 22
# 리뷰1: ㅍ
# 리뷰2: 확실히 헤어길이가있어 묻어남이 있네요 그러도 넘 이뻐용~ 요런소재로 하나 갖고팠는데 넘 맘에들어용~
# 리뷰3: 👍🏻😍👍🏻😍👍🏻😍👍🏻
#
# ----- 001001002 5번째 의류 -----
# 상품명: MOHAN단독
# 평점: 5
# 리뷰수: 10
# 리뷰1: 너무 잘 산거같아요
# 겨울에 코트입어도 춥지도 않을거같은 두께예요
# 만족합니다
# 리뷰2: 키 173에 어깨 넓은편이라 긴 코트 좋아하고 오버핏도 좋아하는데
# S사쥬인데도 코트가 생각보다 크고 깁니다. 무게도 엄청 무거워요 두꺼워서 그런듯 아주 추운날 입으려고 그냥 품어요
# 무게 말고는 맘에 들어요
# 체구 작으신분들은 비추
# 리뷰3: 다들 모한모한 하는 이유가 있네요!! 세일 중이라 저렴하게 샀는데 진짜 예뻐요,, 후기가 크다는 후기가 많아서 반신반의하면서 제일 작은 사이즈 삿는데 딱이에오! 키가 좀 작으신 분들은 입기 힘들 것 같아요 ㅠ
#
# ----- 001001002 6번째 의류 -----
# 상품명: BAU by Bride And You단독
# 평점: 5
# 리뷰수: 8
# 리뷰1: 핏 대박이예요 ㅠ 팔이 길어 한사이즈 크게 샀는데 맘에 들어요!
# 리뷰2: 서초동 문가영이 입은거 봤는데 그 옷이 여기옷이였네요 ㅎ
# 세일가로 엄청 저렴히 구매해서 너무 좋아요
# 기장이 좀 긴듯 하지만 오히려 더 맘에듭니다 ㅎ
# 리뷰3: 핏 너무 좋음
#
# ----- 001001002 7번째 의류 -----
# 상품명: on&on
# 평점: 4.8
# 리뷰수: 42
# 리뷰1: 살짝 얇긴해서 초겨울에 입기 좋을 것 같아요! 기장이 길고 디자인 예뻐서 좋아요
# 리뷰2: 팔이 길어서 66사이즈로 구매했는데 여유없이 팔기장 딱 맞아요
# 팔 통,몸통쪽은 크지만 여성스럽고 아주 예뻐요
# 다만 소재는 고급스럽지는 않네요~
# 그리고 허리띠는 코트에 허리띠 넣는 끈이 있을줄 알았는데 그런건 없고 그냥 코트위에 허리띠하는거에욥!
# 리뷰3: 아이 입학식에 너무 잘 입었습니다. 우아해보여요. 벨트는 한게 훨씬이뻐요
#
# ----- 001001002 8번째 의류 -----
# 상품명: on&on
# 평점: 4.9
# 리뷰수: 18
# 리뷰1: 사이즈가 살짝 애매하게 크긴한데 줄여서 입을려구요~
# 세일해서 좋은 가격에 구입했네요~
# 리뷰2: 기장감,핏,색상 모두 마음에 들어요.
# 특히 울 100%인데 가벼워서 너무 좋았어요.
# 얼른 겨울이 왔으면해요~
# 리뷰3: 키가 작은 편인데도 길이감 좋구요
# 색상이나 핏이 고급져보여요!!
# 어느 옷에나 색상이 잘 어울려서
# 잘입구 다니구 있습니당!!!
# 코트 좋아하시는 분들은 무조건 만족할 아이템
#
# ----- 001001002 9번째 의류 -----
# 상품명: YUTHENTIC
# 평점: 4.9
# 리뷰수: 43
# 리뷰1: 스트라이프가 촌스럽지않고 색배색이 너무좋은옷입니다
# 넥여밈이 단추가아닌 신발끈과같이 여밈이되어있어서
# 포인트가 되구요 결정적인것은 입엇을때 편하고 에어컨
# 밑에서 딱조쿠며 저한테 짱잘어울렸어요
# 다른사람들도 이쁘다고 물었습니디ㅡ
# 리뷰2: 생각보다 꽤 큽니다 길이가 길어요
# 리뷰3: 힙해보이고 유니크해보임 이뽀
#
# ----- 001001002 10번째 의류 -----
# 상품명: Lang&Lu
# 평점: 4.9
# 리뷰수: 207
# 리뷰1: 다크 브라운이라서 사실 거의 검정에 가깝다 싶긴 한데요
# 막입기 편하고 아주 좋았습니다!
# 리뷰2: 봄에 많이 입엇어요
# 리뷰3: 저렴해보이지 않아요 소재나 컬러나 예쁩니다 봄에 잘 입었어요
#
# ----- 001001002 11번째 의류 -----
# 상품명: RIDIFI
# 평점: 4.8
# 리뷰수: 12
# 리뷰1: 일단 엄청 기네요. 161인 저에겐 너어무길어요 따뜻은 하겠어요 다리를 다가려주니까..
# 색깔은 카키 느낌이없고 회갈색입니다.
# 숄 부분 애매해요. 멋스럽게 잘안되네요. 모델터럼...
# 리뷰2: 멋스러운 코트에요 잘 연출해서입음 갠찬을것같애요
# 리뷰3: 울코트라 두껍고 무거울까 고민했는데 롱코트임을 감안하면 생각보다 무거우편은 아닌 것 같아요. 소재도 부드럽고 길이도 롱하고 안쪽 마감도 맘에 듭니다.
#
# ----- 001001002 12번째 의류 -----
# 상품명: MUSEE
# 평점: 5
# 리뷰수: 3
# 리뷰1: 꼼꼼히 살펴봐도 왜 리퍼브인지 모르겠네요 예뻐요
# 리뷰2: 뮤제 옷 자주 사는데 세일해서 구매했어요.
# 뭐 옷은 말할것도 없고 티 한장 가격에 코트 사서 좋아요~
# 후면 디테일 좋구요
# 리뷰3: 겨울에 더플코트가 너무 예뻐 계속 보는데, 가격때문에 망설이다 찜만 해놓았거든요, 이번에 운 좋게 리퍼브 세일해서 득템했습니다. 포장도 박스에 고급지게 왔고, 사진에선 넘 어두워서 잘 안보이지만, 단추를 풀고 입어도 너무 예쁘네요. 기장은 무릎 정도까지이고, 도톰한 이너 입으면 편안하고 스타일리쉬 하게 잘 맞을 것 같습니다. 꼬까옷 입을 생각에 겨울이 기다려지네요~~~
#
# ----- 001001002 13번째 의류 -----
# 상품명: WEDNESDAYOASIS FOR WOMEN
# 평점: 4.8
# 리뷰수: 370
# 리뷰1: 좋아요
# 리뷰2: 클 줄은 알았지만 제가 생각한 것보다 훨씬 컸어요!! 덩치 좋은 제 신랑도 맞네요😂 그치만 편하게 입기 좋을 거 같아요~~
# 리뷰3: 오버핏 오버핏 하긴 했는데 세상에 이렇게 클줄은 몰랐어요ㅋ나름 오버핏 즐겨입는 사람인데 한단계 더 위인 느낌입니다. 옷은 색상이나 디자인이나 전체적으로 마음에 드는데 사이즈때문에 며칠 고심했어요....그나마 할인가로 구매해서 그냥 입어보려고 합니다!! 근데 진짜 커요...
#
# ----- 001001002 14번째 의류 -----
# 상품명: FRONTROW단독
# 평점: 4.9
# 리뷰수: 2,477
# 리뷰1: 코트 질보다 사이즈 관련해서 궁금하신 분들이 많으실것 같아서 (저도 그랬구요ㅎㅎ) 사진을 사이즈 보여드릴수있게 여러장 찍어봤습니다.
#
# 1. 제사이즈 : 160cm / 44사이즈 / 47kg / 하체보다 상체가 마른편이고 어깨 좁은편입니다. 저는 S랑 XS 중에 고민하다가 문의글올렸는데 너무 포대자루(?) 느낌 안날 정도의 멋스러운 박시핏으로 입기에는 XS로 추천받았습니다.
#
# 2. 길이
# (사진1,2) 이너로 붙는 원피스에 9cm 구두 신은컷입니다. 사실 코트의 품보다 길이가 걱정되었지만, 수선까지 감안하고 구입했어요. 근데 길이는 롱 코트 느낌으로 멋스러워서 저는 수선하지 않고 입고있어요. 복숭아 뼈보다 약 10cm~15cm 위까지 오는듯해요. 그리고 제 체형에 xs는 약간 박시하면서 소매는 안에 이너를 얇게입고 손을 내렸을때 손가락 1마디 정도 남기고 가리는 정도에요
# (사진3,4) 굽이 없는 단화에 걸친 사진입니다. 4번째 사진에서 길이를 다시 확인하실수있어요! 제 취향에는 160은 운동화에 걸쳐서 캐주얼하게 예뻤어요. 저는 길이는 수선 생각이 아예 사라졌습니다ㅎㅎ
#
# 3. 품
# 제 체형에 xs 사이즈는 너무 캐주얼하지 않은 박스핏이에요. 저는 이너를 두껍지않게 핏되게 입는 편이라 사실 xs가 딱 맞게 예쁜 박시핏같아요. 끈을 묶지 않았을때는 더 예쁘게 박시해보여요. 그런데 핸드메이드 코트의 두께상 이너를 두껍거나 박시하게 입으시는 분들은 한사이즈 크게 선택하시는것을 추천드려요. 제 체형에 이너를 두껍게 입으시거나 가오리핏, 박시핏으로 입으시는 분들은 s가 더 코디하기 훨씬 좋으실것같네요!!
#
# 4. 두께 및 보온성
# 두께는 딱 일반 핸드메이드 코트 정도이고 흐물거리지 않고 탄탄한 느낌입니다. 11월3일에 결혼식때 입고갔는데 이정도 날씨에는 바람 불지 않으면은 더울정도에요. 소재상 두께에 비해 보온성은 좋아요. 대신 한파까지는 커버 못할것같습니다.
#
# 5. 색상, 광택, 옷 마감 등등 그외
# 색상은 정말 밝지도 어둡지도 않은 카멜 색상입니다. 피부톤이나 피부밝기를 크게 안탈 예쁜 색상이에요. 그리고 옷의 흐름이나 광택 덕분에 같은 색상의 코트에 비해서 고급스러워 보입니다. 옷의 마감도 훌륭하구요, 안감이 허리 위까지 오기때문에 안에 입은 옷과 마찰되거나 하지 않아요
#
# 6. 총평
# 옷 자체는 정말 가격에 비해 훌륭하고 디자인이 정말 클래식하고 심플합니다. 대부분의 분들이 사이즈때문에 고민하실텐데 157 이하의 분들은 수선이 다소 필요하실수도 있겠지만 그 이상의 체형분들은 롱코트로 표현하실수 있어서 추천드려요! 대신 롱코트를 선호하지 않으시는 분들은 구매를 고민해보셔야겠지만, 아직까지 롱코트나 오버핏 코트가 유행이니까요ㅎㅎ 또 사이즈는 취향 및 평소 코디에 따라 선택하시는것을 추천드립니다.
# 리뷰2: (블랙이 촤르르? 가 안느껴진다고 해서 스노우로 한번 일반카메라로 한번 찍고 촤르르가 느껴지게 찍었어요. 전 이정도 촤르르에도 만족합니다!)
#
# 장점!
# 완전 쿨톤 코트
# 비록 흰색 코트 사고 싶었지만
# 사실코트는 어울리는 색깔별로 세개정도 있어야죠
# 안에 뭘입든 어울리는 색과 매치해야 하니깐
# 그중에 기본 블랙 컬러를 이런 좋은 아이템으로 픽하게 되어 넘나 타이밍 좋네요 ㅎㅎ
#
# 사이즈!
# 많은 후기 보다가 저랑 비슷한체형이 xs이 많아서 저도 xs하려다가 일이만원짜리도 아닌데 대충 사이즈 고르기 싫어서 매장가서 입어봤더니 직원분께서 저한테는 s가 더 핏이 어울린데요
# 저도 그게 무슨말인지 알았어요. 몬가 xs은 너무 딱맞아서 케주얼하게 입고 싶은 저한테는 몬가 몸을 옹졸하게 만드는 핏? 절대 작은 사이즈가 아닌데도 디테일땜에 핏이 정말 달라 보여요! 매장도 세일중이던데 꼭 인터넷으로 사이즈 고민 마시고 매장가서 핏봐달라고 해보세요:) 전 참고로 154,52인데 s한거 절대 후회 안함.
#
# 단점!
# 블랙코트는 사실 먼지 진짜 잘 붙는거 아시죠? 그래서 저는 그냥 블랙코트 입을때 돌돌이 가방에 가지고 다니려고요 부피는 있지만 가벼우니까 가지고 다니려고요 ㅎㅎ
#
# 활용!
# 전 얼죽코 절대 아닙니다 얼죽코하다가 얼어죽겠어요
# 그치만 가을 코트인거 같아서 11월까지 열심히 입으면 딱 좋을꺼같아요
# 꾸밀때도 좋지만 보통 실내 스타필드나 롯데월드몰 더현대 다니는거 좋아해서 꾸안꾸로 딱좋아욯
#
# 재구매 의사
# 맘에드는 디자인은 어울리는 색깔별로 사놓는 편이라
# 이것도 잘 입게 되면 내년에 다른 쿨톤 칼라도 수집할꺼에요
# 막스마라 하나살 돈으로 이거 색깔별로 수집할꺼에요
#
# 리얼후기
# 그리고 다른 사람들은 무조건 고급지고 싶어서 카멜색 사시는거 같은데 코트는 옷일뿐입니다 결국 어울리는 색이 더 예뻐 보이게 하는거 아시죠? 쿨톤분들은 오트밀이나 블랙 가세요. 쿨톤 색이랑 잘어울려요.
# 리뷰3: 작년에 카멜 컬러 너무 잘 입어서 동일 사이즈(S)로 블랙 컬러 새로 구매했어요! 역시나 소재와 핏 모두 만족스럽습니다:) (참고로 168, 어깨 직각에 넓은 체형입니다. 차분하고 흐르면서 어깨선이 떨어져서 되게 슬림하고 깔끔한 핏이에요. 사진은 아래서 대충 찍었지만 종아리 중간쯤? 까지 오는 기장입니다.)
#
# 어제 입고 나갔다가 땀나서 벗었지 뭐에요… 작년에 입고다닌 경험상 한파 시기에도 안에 여러 옷 레이어드하고 목도리까지 두르면 문제 없었어요. S사이즈임에도 팔이나 품이 여유로워서 안에 겹쳐 입기에도 좋더라구요. (팔이 긴 편인데도 손등 살짝 덮는 기장이에요) 완전 오픈 형으로 입을 수도, 단추 채워서 단정하게도, 허리 끈 묶어서 원피스처럼도 입을 수도 있는 디자인이라 오래 안 질리고 입을 수 있을 것 같아요.
#
# 대신 카멜 컬러는 진짜 고급스러운 광택이 도는 느낌의 컬러였는데, 블랙은 그렇진 않더라구요. 그래서 같은 소재맞나..? 살짝 의아했는데 부드러운 감촉이나 보온성은 여전해서 올해도 잘 입을 것 같아요. 은은하고 깔끔한 느낌의 소재라 카멜과 같은 디자인인데도 다른 느낌이 나는 게 신기하네요. 잘 입을게요!
#
# ----- 001001002 15번째 의류 -----
# 상품명: MOHAN단독
# 평점: 4.8
# 리뷰수: 191
# 리뷰1: 너무 예뻐요!
# 리뷰2: 무겁긴한데, 소재랑 핏 다 이뻐요. 고급스러워요~
# 리뷰3: 너무 이쁘네요
#
# ----- 001001002 16번째 의류 -----
# 상품명: on&on
# 평점: 4.6
# 리뷰수: 5
# 리뷰1: 분위기있는색이고 따뜻한데 좀 무거워요
# 리뷰2: 키작녀한테는 조금 오버핏이구 커요 ... 다만 따뜻해서 품아용 가격할인도조하요옹
# 리뷰3: 예뻐요 따뜻할것같아요
#
# ----- 001001002 17번째 의류 -----
# 상품명: Amour moier단독
# 평점: 4.9
# 리뷰수: 1,210
# 리뷰1: 직접 받아보니 더 디자인이 진짜 실물깡패 그자체네요! 여름 좋아하는 저인데.. 얼른 가을이 오면 좋겠어요. 이 옷입고.외출하게요.
# 참! 바느질 마감 잘봐주시겠어여?
# 오래 사랑받는 브랜드 되시려면 작은부분도 신경 써주세요. 별 하나 차감은 이것때문!
# 리뷰2: 키 158 기준 길어서 5센티 수선했는데 딱 예쁘네요 ㅎㅎ
# 리뷰3: 넘 맘에 들어서 색깔벌로 다 주문했어요~
# 할인 할 때 득템했네요ㅋㅋ
#
# ----- 001001002 18번째 의류 -----
# 상품명: The Raust단독
# 평점: 4.9
# 리뷰수: 83
# 리뷰1: 지난겨울부터 눈독들이다 이번에 구입하게 되었는데,,
# 포근한 질감과 세련된 색감이 맘에들었어요~
# 빨리 겨울되서 따뜻하게 입고싶네요^^
# 리뷰2: 옷이 여뻐요~~ 입었을때도 편하고 소재도 편하고 좋네요~다 잘어울릴것같아요~~
# 멋스럽고 예쁩니다~~
# 리뷰3: 늦은 후기입니다. 상품 받기까지 시간이 꽤 걸렸지만 받아보니 이쁘네요. 퍼 질감이 궁금했는데 몽글몽글한 느낌이 있고 촉감도 부드럽네요. 색상도 실제봤을때가 더 이쁜거 같습니다.
# 올겨울에 잘입어 보겠습니다~
#
# ----- 001001002 19번째 의류 -----
# 상품명: RIDIFI
# 평점: 4.7
# 리뷰수: 6
# 리뷰1: 사이즈 완전 루즈핏에 입음 엄청 따뜻하고 멋스러워요
# 리뷰2: 생각했던 차콜 색보다 좀 더 진한 느낌이에요. 다른 리뷰들처럼 좀 무겁긴 하지만 질감과 디테일이 좋습니다! 세일할 때 득템했어요. 입으면 머쨍이 도시 여성 느낌이 듭니다•••
# 리뷰3: 엄청 무거워요 s사이즈 구매하길 잘 한듯 디자인은 예뻐요 세일가로 사서 그냥 입으려구요
#
# ----- 001001002 20번째 의류 -----
# 상품명: MOHAN단독
# 평점: 4.8
# 리뷰수: 70
# 리뷰1: 무게감이 좀 있는 편이에요
# 끈으로 허리를 묶어야 덜 무거울것같고
# 더울때사서 입고나가본적은 없는데 따뜻할것같아요
# 리뷰2: 귯
# 리뷰3: 젤 작은 사이즈인데도 꽤 넉넉하네요
# 무겁긴하지만 소재도 좋아보이고
# 끈없이 입는게 더 이쁠듯
#
# ----- 001001002 21번째 의류 -----
# 상품명: L’H.A.S
# 평점: 5
# 리뷰수: 3
# 리뷰1: 좋아용~~~~ 소재가 고급스러워요^^
# 리뷰2: 사이즈가 정 55에게도 박시하긴한데 멋스럽고
# 재질도 좋은편입니다
# 멋스럽게 잘 입었습니다
# 리뷰3: 디테일이 쵝오에요
# 요즘 날씨에 딱 적합하고 부들부들 핸드메이드 같기도하고 자주 입고있어요
#
# ----- 001001002 22번째 의류 -----
# 상품명: LOOKAST
# 평점: 4.9
# 리뷰수: 265
# 리뷰1: 봄, 가을에 입기 적정하며, 초겨울까지는 입기에 적당한 두께감이에요. 다만, 옷 무게가 다소 있어서 입을 때는 모르지만, 들 때 참고해주시면 되세요.
# 리뷰2: 조금 크고 무겁지만 전체적으로 깔끔하고 예뻐요! 넉넉한 오버핏이고 안에 누빔도 들어있어서 한겨울에도 무리없이 입을 수 있고 재질도 마감도 나쁘지 않아서 맘에 들어요!! 허리끈 있는 코트를 좋아하는데 역시 귀엽고 이쁘고 무난하네요! 최고!
# 리뷰3: 생각보다 아이보리 느낌이 강해서 살짝 아쉽지만
# 안에 누빔되어 있어서 너무 따뜻해요 ㅎㅎ
#
# ----- 001001002 23번째 의류 -----
# 상품명: RIDIFI
# 평점: 5
# 리뷰수: 8
# 리뷰1: 코트 부드럽고 좋아요 색상도 무난하면서 이쁘네요 좀무거워요…..
# 리뷰2: 코트가 정말 많은편인데, 요런스탈은 또 같은듯 다른 디쟌이에요 ㅎ
# 이가격에 이컬리티라면 정말 굳쵸이스!!!!!
# 약간 무거운감은 , 없지않아 있긴해요
# 그러나, 이정도의코트라면 뭐 거져죠 ㅎ
# 맘에들어요~
# 리뷰3: 벌써 겨울이 기다려지네요!사진보고 완전 반해서 며칠 고민하다 마침 세일 기간이라 큰 맘 먹고 구매하규 받았는데 넘 맘에 들어요 색상도 재질도 고급지구 스타일도 멋지구요 아주 맘에들어요 단추 잠그면 여성스러워져요 완전 맘에 들어요!!
#
# ----- 001001002 24번째 의류 -----
# 상품명: MOHAN단독
# 평점: 5
# 리뷰수: 14
# 리뷰1: 색이랑 털표현이 사진이랑 똑같아요! 모자가 넘 귀여워서 구매했숩니다~~
# 리뷰2: 오버사이즈 좋아해요 적당한 오버사이즈고 너무 귀엽고 실제로 바람 많이 불때 모자쓰고 앞에 묶으면 따듯해여 지난
# 겨울잘 입고 다녔어오 그치만 가볍고 얇아서 한겨울에는 안에 패딩조끼 껴입거나 해야되요
# 리뷰3: 부들부들 좋은데 많이 얇아서 아쉽네요 하지만 핏은 예뻐요
#
# ----- 001001002 25번째 의류 -----
# 상품명: FRONTROW단독
# 평점: 4.9
# 리뷰수: 72
# 리뷰1: 161 50 기준 S 좀 커요. 근데 오버핏으로 곰돌이같아서 만족합니다. 비율이나 키 덩치 고려해서 사이즈 선택하시면 될 것 같아요. 소재는 부들부들해서 좋고 세일한 가격에 사서 더더 만족스러워요. 후기가 다 좋은 이유가 있었네요! 올 겨울에 꼭 입을거예요~~
# 리뷰2: 따뜻해서 윈만한 패딩보다 나아요.
# 리뷰3: 사진보다 실물이 나아요, 멋있다 싶으면 묵직한 코트 많은데 이건 생각보다 안무거워요, 옷몸살 날만한 무거운 옷도 포기 못하고 입는데 이건뭐 거기 비하면 깃털?
# 테디 따라한 느낌 너무 나면 어쩌지 했는데 아예 재질이 다르고 그냥 이것대로 느낌있어요, 오백만원짜리랑 같길 바라는게 더 이상한거고 이 금액에 이 옷은 참 잘 만들었어요~ 저도 덩치가 안큰데 s 너무 이쁜 오버핏이에요
#
# ----- 001001002 26번째 의류 -----
# 상품명: MOHAN단독
# 평점: 5
# 리뷰수: 13
# 리뷰1: 생각보다 무겁지 않았아요! 그리고 일자 핏이라 유행 크게 안탈거같아서 좋아요
# 리뷰2: 일단 코트 만족합니다
# 그런데 생각보다 길어서
# 기장 수선 살짝하니 더 만족합니다
# 팔 통이 커서 오히려 두꺼운 니트 소화 가능 하구요
# 어깨는 오버핏 아니라 좋구요
# 점잖은 스타일이지만 감각적으로 보여서 좋습니당
# 리뷰3: 좀 무거운데 핏이 괜찮아요 좀 보풀이 잘 보이고 묻기도해서 폴리 목도리랑은 같이 사용하긴 어려울듯
#
# ----- 001001002 27번째 의류 -----
# 상품명: YUTHENTIC
# 평점: 4.9
# 리뷰수: 86
# 리뷰1: 전 조금 디자인이 난해해서 아직은 코디를 못해 입지는 못했어요.
# 그래도 옷 자체는 예뻐요
# 리뷰2: 기장 길까봐 걱정했는데 종아리 반찍 딱 예쁘게 내려오고 예뻐요~~~ㅎㅎ 비싸다고 생각했는데 퀄리티가 좋긴히네요~!
# 어깨부분이 좀 넓은 느낌이라 살짝 아쉬워요
# 리뷰3: 평소 제 스타일은 아닙니다. 한번쯤 이런 스타일을 입고 싶어서 구매해봤는데, 손이 많이 가진 않아요. ㅎ 하지만 하나 정도는 소장해 놓으면, 여행가거나, 스타일을 좀 바꾸고 싶을 때 괜찮은 거 같아요. 전 와이드팬츠에 깔끔한 슬리브리스를 매치해서 코디해봤는데, 약간 힙합스타일이 나서 좋았던 것 같아요. 소재+마감은 좋습니다.
#
# ----- 001001002 28번째 의류 -----
# 상품명: RIDIFI
# 평점: 5
# 리뷰수: 12
# 리뷰1: 핏도 예쁘고 재질도 좋고 너무 마음에 듭니다... 올겨울 이옷을 입으려니.. 너무 기대됩니다!!
# 리뷰2: 세일 할 때 득템했네요..
# 빨리 날이 추워졌음 좋겠어요^^
# 근데 먼지는 좀 많이 붙어요^^;
# 리뷰3: 저렴한 가격에 잘 샀어요
#
# ----- 001001002 29번째 의류 -----
# 상품명: LOOKAST
# 평점: 4.9
# 리뷰수: 25
# 리뷰1: 흠...
# 인플루어선님 코디된 샷보구서 반해서 구매했는데
# 일단 전체적인 마감은 괜찮아요 ㅎㅎ
# 롱코트 특성산 코트자체만으론 무게감이 있는편인데 착용후에도 약간은 무게감이 있습니다
# 164기준 롱코트라서 기장긴 바지랑 신발 잘신어야 코디괜찮구 털빠짐은 거의 없는편인것 같아요
# 어깨라인 적당한 오버핏이라 괜찮긴하네요
# 살짝 애매한 코트지만 색이 잘빠져서 킾합니다
# 리뷰2: 키가 작아 길긴하지만 올겨울을 위해 할인가로 구매 ^^
# 리뷰3: 제일 구매잘한 코트에요 핏 완전 예쁘고 멋스러움
#
# ----- 001001002 30번째 의류 -----
# 상품명: LOOKAST
# 평점: 4.9
# 리뷰수: 1,679
# 리뷰1: 168cm / 52kg / 평소사이즈 M / 주문사이즈 S
#
# 깔끔한 일자핏 겨울코트를 찾다가 구매했는데 너무 만족스럽습니다 ㅠㅠ 평소 오버핏 코트처럼 편안한 핏을 선호하는데 그러다 보니 단정한 차림으로 입어야할 때 좀 애매하더라구요. 원래 ㄷㅅㅌ 코트를 눈독 들이고 있었는데 매니시한 핏이고 가격대가 높아 고민이 되었어요. 찾다보니 룩캐스트 코트가 딱 제가 원한 깔끔한 일자핏이더라구요. 소재도 좋고 가성비 훌륭한 코트라는 후기를 보고 구매를 결심했답니다. 혹시 고민 되시는 분들께 제 후기도 도움이 되었으면 좋겠어요!
#
# **무난하면서도 멋스러운 핏을 원하는 분들께 강력 추천합니다!! 격식있는 자리에는 물론 잘 어울리고, 캐쥬얼하거나 페미닌한 무드와도 부담없이 잘 매치할 수 있을 것 같아요 ㅎㅎ**
#
# -핏
# 깔끔한 일자핏, 툭 떨어지는 느낌, 허리에 라인이 들어가지 않아 페미닌한 느낌이 강조되지 않아 여러가지 룩에 매치하기 용이함, 식후에도 숨쉬기 편함 ^^,,,,
#
# -두께감
# 적당히 두껍고 울 100%임에도 많이 무겁지 않음, 겨울에도 패딩을 입지 않는 코트러버로서 한겨울을 제외하고 주궁장창 입을 수 있음, 물론 핸드메이드 코트보다는 무게감이 있음
#
# -촉감
# 피부 극예민한 편인데 거친 촉감이 아니라 목뒤 맨살에 닿아도 전혀 불편함이 없음, 당연히 울 100%라 약간 부직포 느낌의 촉감이지만 오히려 톡톡한 느낌이라 만족! 따듯하고 보풀이 잘 안 날 것 같은 재질, 먼지가 잘 안 붙음
#
# -색, 패턴
# 고급스러운 차콜그레이 색상, 상세페이지 색상과 유사함(첨부사진 중에서는 3번째와 비슷함), 패턴이 잔잔해서 부각되지 않고 민무늬보다 고급스러운 느낌
#
# -사이즈
# 가장 고민됐던 부분.. 본인은 일반적으로 s-m 사이에 걸쳐 있으며 스몰도 입을 수 있지만 넉넉하게 입는 걸 좋아해 평소에는 미디움 사이즈를 입음(둥근어깨, 약간 어좁) 너무 고민되서 매장가서 착장해봤는데 스몰도 여유있어서 스몰로 구매함. 완전 두꺼운 니트 아니면 이너도 별 영향 없을 정도로 사이즈에 여유가 있음. 미디움 입었으면 팔길이가 길었을듯..
#
# -Tip
# #사이즈
# 기장도 긴 편이라 저처럼 걸쳐 있는 사이즈라 고민되시면 일반적으로는 -> 스몰, 오버사이즈 원하면 -> 미디움 사이즈 추천드립니다!
#
# #스타일링
# 카라 부분에도 버튼이 있어 목까지 다 잠그면 새로운 스타일로 입을 수 있어요! (마지막 사진 참고) 상세페이지에서는 못 본 것 같은데 따뜻하고 매니시한 느낌까지 낼 수 있어서 오히려 반전매력으로 너무 마음에 들었어요. 몰랐던 분들도 꼭 참고해서 스타일링 해보셔요!
# 리뷰2: 제가 워낙 코트를 좋아하며 자켓류와 코트를 색깔별로 갖추고 있는 사람인데, 이번에 블랙을 자주 입기도하고 바꿀때가 되서 진짜 고민많이했었거든요 던스트를 살까 룩캐스트를 살까 진짜 한 30번 넘게 고민했을정도에요
# 근데 제옷장에 대부분 다 룩캐스트 뿐이여서 그동안의 룩캐스트의 합리적인 가격과 퀄리티를 믿고 구매하게 되었는데요 역시나를 외치게하는 코트 였습니다
# S를 살까했지만 두툼한 옷을 입어야해서 m사이즈를 샀고 사실 차이도 많이 안나더라구요~ 아무튼 일자코트가 요즘 많이 시중에 없어서 찾기도 힘들고 아쉬웠는데
# 룩캐스트에서 멋드러지게 만들어줘서 너무 기분이 좋습니다 사실, 색깔별로 다 사고싶었는데 좀 많이 참았습니다
# 브라운도 마음에 들었는데 비슷한게 있어서 아쉬웠어요!
# 일자라인 코트로 딱 떨어지게 많이 디자인해주세요
# 그리고 생각보다 무거울거라 생각했는데, 무게감 나쁘지않고 우선 진짜 일자로 툭 떨어지는 핏이 맛깔납니다
# 길에서 걸어다닐 맛 난다구요!!
# 참고로 저의 키는 168cm 입니다
# 리뷰3: 브라운 가지고 있어서 같은 사이즈로 주문했는데 뭔가 블랙은 좀 더 오버느낌나요!
# 어두워서 그런가?
# s사면 될듯
# 전 그냥 앞부분 싸매고 입어도 ㄱㅊ을 거 같아서 m하려구여
#
#
# ========== 001001008 카테고리 여성의류==========
#
# ----- 001001008 1번째 의류 -----
# 상품명: EIGHT DAYS A WEEK
# 평점: 4.9
# 리뷰수: 82
# 리뷰1: 여행내내 너무 이쁘게 잘 입었습니다 바지 치마 원피스 모든 옷에 너무 잘어울려요 사이즈도 적당한 오버핏에 카라가 포인트 됩니다
# 리뷰2: 적당하게 오버핏 돼서 좋아요
# 리뷰3: 넘 맘에듭니다 프리사이즈라서 66까지도 잘맞을듯해요 편하게 걸치기 좋은 스타일이에요 만족합니다
#
# ----- 001001008 2번째 의류 -----
# 상품명: TILLIDIE
# 평점: 4.9
# 리뷰수: 56
# 리뷰1: 소매 체크가 포인트인듯하고 환절기에 데일리로 자주 입을 듯 해요
# 리뷰2: 가을에 입으려고 세일할때 샀어요 너무 예뻐요
# 리뷰3: 서한테는 크지만
# 소매디테일이 넘 맘에들어
# 품어요
# 사이즈별러 나옴
# 옴마나 조을까요
# 마감도 완벽해요
#
# ----- 001001008 3번째 의류 -----
# 상품명: TILLIDIE
# 평점: 4.9
# 리뷰수: 122
# 리뷰1: 봄가을에 입기 좋은것같아요 제 기준 미디기장으로 입기 괜찮았어요
# 리뷰2: 심플하면서도 디테일이 이뻐요 소재도 좋은거같아요
# 리뷰3: 생각보다 크내료
#
# ----- 001001008 4번째 의류 -----
# 상품명: Amour moier단독
# 평점: 4.9
# 리뷰수: 1,210
# 리뷰1: 직접 받아보니 더 디자인이 진짜 실물깡패 그자체네요! 여름 좋아하는 저인데.. 얼른 가을이 오면 좋겠어요. 이 옷입고.외출하게요.
# 참! 바느질 마감 잘봐주시겠어여?
# 오래 사랑받는 브랜드 되시려면 작은부분도 신경 써주세요. 별 하나 차감은 이것때문!
# 리뷰2: 키 158 기준 길어서 5센티 수선했는데 딱 예쁘네요 ㅎㅎ
# 리뷰3: 넘 맘에 들어서 색깔벌로 다 주문했어요~
# 할인 할 때 득템했네요ㅋㅋ
#
# ----- 001001008 5번째 의류 -----
# 상품명: LEFTSEOUL
# 평점: 4.9
# 리뷰수: 797
# 리뷰1: 별로면 반품하려했는데 품의려구요
# 생각보다 이뻐요 인조느낌도 덜 나고
# 스타일리시하네요
# 리뷰2: 쿠폰적용해서 6만원대 구매했어요.
# 가을이 빨리 왔으면 좋겠어염.
# 리뷰3: 밑에 단이 주름없는거 찾기 은근힘든데
# 깔끔하고 핏도 너무 맘에들어요
#
# ----- 001001008 6번째 의류 -----
# 상품명: TILLIDIE
# 평점: 5
# 리뷰수: 9
# 리뷰1: 마감 깨끗하고 재질탄탄해서 좋아요 검은깃은 먼지도 잘 안 묻고요 다만 품이 꽤 넉넉하다는 점 감안하고사셨으면 좋겠어요
# 리뷰2: 출퇴근할때 입기 너무 좋아요
# 너무 캐주얼하지도않고 너무 격식차린느낌도 아니라
# 데일리템으로 입을 수 있어요
# 개인적으로 코튼소재의 옷을 좋아하는데
# 틸아이다이에는 코튼 소재의 아우터가 예쁘고
# 다양해서 간절기템으로 자주 구매하고있어요
# 보통의 트렌치와는 다르게 소매와 카라 포인트
# 컬러도 예쁘고 틸아이다이템은 역시 믿고 입어요~
# 리뷰3: 디테일이 예쁘고 요즘 날씨에 입기 좋아요~ 길이도 적당하고 사이즈도 넉넉해서 편해요~
#
# ----- 001001008 7번째 의류 -----
# 상품명: LETTER FROM MOON
# 평점: 0
# 리뷰수: 0
# 리뷰1: 댓글 정보 없음
#
# ----- 001001008 8번째 의류 -----
# 상품명: HANE
# 평점: 4.9
# 리뷰수: 29
# 리뷰1: 만족만족만족 만족만족만족
# 리뷰2: 트렌치코트 색상은 무난하고 스타일도 괜찮은데 구김은 어쯸수가 없네요.
# 리뷰3: 구김이 가도 자연스러워요. 사잔처러무소매를 걷어 입어야 이쁜것 같아요
#
# ----- 001001008 9번째 의류 -----
# 상품명: HOKUSPOKUS
# 평점: 4.9
# 리뷰수: 43
# 리뷰1: 디테일이 좋고 유니크해요!!
# 아주 예뻐요 사진과 동일하고 소재도 톡톡하고 무게감 있게 떨어지는 느낌이 좋아요
# 55인데 2사이즈 오버핏으로 맘에 들어요
# 리뷰2: 너무 맘에 들어요
# 사이즈가 크면 큰대로 아주 멋집니다
# 자켓중 최고예요!!!
# 리뷰3: 너무 맘에 들어요
# 롱스커트랑 입으니 이쁘네요
#
# ----- 001001008 10번째 의류 -----
# 상품명: MOHAN단독
# 평점: 4.8
# 리뷰수: 41
# 리뷰1: 아이보리 색상 구매하고 마음에 들어서 카키색도 구매했어요. 같이 구매한 옷 보관상태가 안좋았는데 카키색이라 보이지 않네요..여기에도 검은 때가 묻었을지 조금 걱정됩니다..
# 리뷰2: 생각보다 예쁘고 괜찮은 트렌치코트입니다. 사이즈는 많이 오버핏이지만 부해보이지않고 예쁩니다. 제가 팔이 짧아서 코트 소매가 많에 길지만 접어서 입으니 딱 좋구요, 벨트 묶어서 입는게 훨씬 예쁩니다..벨트 한쪽에 단추로 고정된 것이며 목 안쪽으로 박음질 꼼꼼한 것까지 모두 만족스럽네요
# 리뷰3: 구김이 잘 가는 소재에요 핏은 예쁩니다
#
# ----- 001001008 11번째 의류 -----
# 상품명: TILLIDIE
# 평점: 4.8
# 리뷰수: 43
# 리뷰1: 작년부터 살까말까 하던 건데 기본템. 이에요. 래글런 어깨에 낭낭한 일자 핏이고 소재도 탄탄하고 좋아요! 158인 제게 무릎 정도 길이고 색감도 좋고 활용도도 높고 입고 활동하기 좋으네요bb
# 리뷰2: 소재도 좋고 여유있는 사이즈. 편하게 걸치기 좋네요.
# 리뷰3: 좋아요
#
# ----- 001001008 12번째 의류 -----
# 상품명: L’oiE단독
# 평점: 4.9
# 리뷰수: 106
# 리뷰1: 다른 리뷰들처럼 생각한 거보다 무게가 더 무거운 감은 있지만 재질이 톡톡해서 좋은 거 같아요 핏도 갠찮고 크긴 하지만 나름 고급스러운 거 같아요
# 리뷰2: 생각보다 너무 연한 베이지라 아쉽습니다... 핏은 맘에 들어요
# 리뷰3: 오버핏 좋아하는데 너무 맘에 들어요~
# 툭~ 걸쳐도 멋스럽네요~ 굿굿
# 어여 쌀쌀해지면 좋겟어요 ㅎㅎ
#
# ----- 001001008 13번째 의류 -----
# 상품명: LEFTSEOUL
# 평점: 4.9
# 리뷰수: 891
# 리뷰1: 55싸이즈에겐 많이 큽니다 평소에 넉넉하게 입는편이라 옷이 예뻐서 입기로 했는데 자주 손이 가진 않습니다 잘 어울리는 스타일인지 고민하고 선택하세요
# 리뷰2: 저렴하게 구매해서 휘뚜루 마뚜루 잘 입었어요 어디에나 무난하게 잘어울려서 좋아요
# 리뷰3: 오버핏이구요 진짜 저렴히 잘산거같아요!!
#
# ----- 001001008 14번째 의류 -----
# 상품명: HACIE단독
# 평점: 4.9
# 리뷰수: 34
# 리뷰1: 디자인은 괜찮으나
# 구김이 너무 많이 가고 입을때마다 다림질이 필요해서
# 잘 안입게 돼요
#
# 처음 배송 왔을때도 다른 브랜드와 달리 구김이 많이 간 상태로 와서 좀 당황스러웠고 이 구김이 쉽게 다림질 되지 않는 상태라서 반품 고민하다가
# 대충 다림질 해서 입었는데 구매시 참고 하시면 좋을 듯 합니다.
# 리뷰2: 예뻐요 잘 입을게요
# 리뷰3: 55반이라 M사이즈랑 고민했는데, S도 충분하네요 ㅎㅎ 광택이 도는 질감이 넘 예쁘고, 고급져보여요!
#
# ----- 001001008 15번째 의류 -----
# 상품명: TORTE단독
# 평점: 0
# 리뷰수: 0
# 리뷰1: 댓글 정보 없음
#
# ----- 001001008 16번째 의류 -----
# 상품명: UNNOUT
# 평점: 5
# 리뷰수: 82
# 리뷰1: 진짜진짜 예뻐요 구김이가도 멋스럽고 밝은베이지라 쿨톤도 잘어울려요
# 리뷰2: 사이즈가 두 가지로 선택할 수 있어서 샀어요. 아무리 옷이 예뻐도 내 몸에 안 맞으면 꽝인데 160 기준 무난하게 잘 맞습니다. 잠그거나 묶는 방법에 따라 연출하는 느낌도 여러 가지로 낼 수 있고 원단이 부드럽고 색감이 누렇지 않아서 봄 내내 잘 입고 다녔어요.
# 리뷰3: 제가 찾던 밝안 색상이예요 얼굴도 환해 보이고 입었을때 핏이 멋집니당
#
# ----- 001001008 17번째 의류 -----
# 상품명: MOHAN단독
# 평점: 4.9
# 리뷰수: 61
# 리뷰1: 간절기에 입기 좋네요. 길이도 적당하고 좋아요!
# 리뷰2: 색상 화면이랑 똑같은 크림베이지색상이라서 너무예뻐요 트렌치 기본베이지색상은 너무안받아서 잘 안입었는데 얘는 잘 입을것같아요
# S사이즈 했는데도 왕 커요!!저는 44반인데 정말심하게큽니당 66도 s 쌉가능할것같아요
# 그래도 허리끈 있어서 묶어서 잘입을게요
# 할인가 9만9천원에 구매했고 합리적이면서 퀄 대비 가성비 괜찮은 가격이었습니다
# 리뷰3: 아주편하고아주귀엽고이쁘네요~
# 색감도봄봄합니다!
#
# ----- 001001008 18번째 의류 -----
# 상품명: GAYEON LEE
# 평점: 4.4
# 리뷰수: 11
# 리뷰1: 너무 예뻐요
# 트랜치코트중 젤예쁩니더
# 리뷰2: 색상은 베이지보다 카키에 더 가까워요 흔하지 않은 디자인이라 좋아요!
# 리뷰3: 디자인은 예쁘고 사이즈도 낙낙핏이어서 입기 편한데 마감이 황당할정도로 어이없는옷. 40만원이 넘는 가격인데 검정 배색부분에 카키색 실이 보이게 마감하다니 맙소사. 양심없음
# 마감 때문에 옷이 확 저렴해보임
#
# ----- 001001008 19번째 의류 -----
# 상품명: TORTE단독
# 평점: 5
# 리뷰수: 2
# 리뷰1: 빠른 발송, 감사합니다. 체구가 작아서 겉옷 사입는게 매우 힘든데.. 이 옷도 역시나 정핏이겠지만 저한테는 좀 크킨해요. 그런데 이 가격으로 안보일 고급스러움이 있고 하이넥과 레귤러 어깨로 체형이 보완되기에 너무 마음에 듭니다. 여튼 입으면 사람이 좀 예뻐보이네요 ㅋㅋㅋ 다만 키가 작아서 옆구리 허리 고정끈이 좀 더 높이 달렸음 비율적으로 더 좋게 보이지 않을까 하는데.. 이건 수선집에 수선을 맡겨볼까 해요. 구매 잘 한거 같고 이 옷으로 올가을과 초겨울 사이에 기분이 좋을거 같습니다. ㅎ
# 리뷰2: 옷 구매했다가 너무 맘에들어서 추가로 더구입했어요
# 자주이용할게요
#
# ----- 001001008 20번째 의류 -----
# 상품명: MOHAN단독
# 평점: 5
# 리뷰수: 7
# 리뷰1: 배송은 거의 하루만에 왔구요 164 51정도인데 기장감이나 핏이 적당히 길고 박시해서 멋스러워요 주름가공된 원단이 독특하고 예쁘네요
# 리뷰2: 트렌치코트,겨울코트는 거의큰사이즈만입어용
#
# 키가있다보니 ㅎ 디테일조쿠 세일가격에 득템.
# 선선한가을날 입고나갈생각에~빨리여름아 가라 ㅋ
# 리뷰3: 주름 신경 덜쓰이는 소재라 좋고요
# 광택과 소재 덕분에 포인트가 확실히 됩니다
# 팔기장은 다른 아우터들에 비해 길게 나왔네요
#
# ----- 001001008 21번째 의류 -----
# 상품명: MOHAN단독
# 평점: 5
# 리뷰수: 12
# 리뷰1: 주머니가 편하고 소재좋습니다
# 리뷰2: 예상했던대로 소재 디자인 너무 유니크하고 캐쥬얼룩에 자켓 하나만 걸쳐도 스타일리시해보여요 ㅎㅎ 잘샀습니다
# 리뷰3: 옷 디테일이 너무 예뻐서 마음에 들어요
#
# ----- 001001008 22번째 의류 -----
# 상품명: MANNON
# 평점: 4.3
# 리뷰수: 3
# 리뷰1: 어깨 패드가 두꺼워서 어깨가 좀 넓어보여요
# 평소에 66사이즈인데 많이 커보여서 스몰로 주문했는데 저에게 오버핏 과하지 않게 잘맞아요
# 허리 통 부분이 너무 크지 않아서 라인이 잡히고 옆에 트임이 있어서 옆통이 얇아보이고 이뻐요
#
# 전체적으로 어깨부분 아쉬운것 빼고는 라인이 이쁘고 색상도 저랑 잘맞고 소재도 고급스러워보여서 입으려구요. 세트 조끼도 살 예정입니다. 세트 하의는 품절인지 없던데ㅠㅠ 구입희망합니다
# 리뷰2: 세트로 사서 여행가서 너무 예쁘게 잘 입었어요
# 마감 깔끔하고 고급스러워서 오래 잘 입을것 같아요!
# 매넌은 언제나 믿고 삽니다
# 리뷰3: 모델핏이 엄청 커보여서 완전 오버핏인 줄 알았는데 그렇진 않아요. 어깨부분이 사이즈는 맞는데 패드가 있어 커보여 오버핏‘스러움’이 나와요. 전 66사이즈이고 완전 오버핏 제대로 입고싶어 미디움으로 샀는데 진동부분이 좀 타이트하게 느껴져서 오버핏만의 편안한 느낌은 조금 아쉬워요 ㅠㅠ… 소재는 탄탄하고 마감 깔끔하나 니트털이 잘 붙습니당! (이너로 니트입고 입어봤음)
#
# ----- 001001008 23번째 의류 -----
# 상품명: LOVLOV
# 평점: 5
# 리뷰수: 10
# 리뷰1: 색상은 좀 더 어둡네요 가을에 잘 어을려요 기본스타일이고 편하게 걸칠수있을것같아요
# 리뷰2: 색상이 약간 연한베이지인줄알았는데 살짝 짙은 카멜느낌. 톡톡한느낌면?느낌 .약간두꺼운 느낌.
# 믹스매치하기 좋고 롱기정이라키커보임
# 리뷰3: 편하고 색감이 예뻐요. 소재도 좋고, 구김이 많이 가지 않아 좋네요
#
# ----- 001001008 24번째 의류 -----
# 상품명: MangoManyPlease
# 평점: 5
# 리뷰수: 4
# 리뷰1: 소재도 탄탄하고 핏이 모델컷처럼 오버핏임에도 이쁘게 떨어져서 맘에듭니다
# 단추가 살짝 떨어지기 쉬울 것 같긴한데 여유분도 두개나 있고 따로 살짝 손보면 괜찮을 것 같아요
# 리뷰2: 폼은 크나 캐쥬얼하게 입기 좋습니다
# 리뷰3: MangoManyPlease
# DUNE TRENCH COAT 크림베이지 구입했는데
# 벙벙한핏될까 걱정했던게 민망할정도로
# 만족스러워요
# 이런 스타일에 긴 기장 찾고있던거라
# 잘 입고다니려고요
#
# ----- 001001008 25번째 의류 -----
# 상품명: LOEIL
# 평점: 5
# 리뷰수: 1
# 리뷰1: 백수 N개월차라 집 아니면 근처에 너무 츄리하게 입고 나가는 바람에 여태 구매하고 개시를 못했네요! 리뷰하는 김에 내일 입고 외출해볼랍니다
#
# ----- 001001008 26번째 의류 -----
# 상품명: Oui mais non
# 평점: 4.9
# 리뷰수: 20
# 리뷰1: 올 봄 너무 잘 입었어요
# 제가 찾던 디자인
# 리뷰2: 휘뚜루마뚜루 잘 입어져요 검정이라 먼지가 잘 보이긴하지만 올해 뽕뽑을거같아요
# 리뷰3: 검정색 구매 후 베이지 추가 구매입니다.
#
# ----- 001001008 27번째 의류 -----
# 상품명: kuho plus
# 평점: 5
# 리뷰수: 5
# 리뷰1: 좀 비싸긴해도 예뻐요 단점은 소매끈이 잘 고정되지 않는다는점 정도..
# 리뷰2: 출퇴근시 롱기장은 입기 불편해서 숏으로 구매 했는데요 귀엽고 좋아요
# 리뷰3: 배송 빠르고 좋아용 잘 입을게요
# 추천드립니다 ㅎㅎ 만족합니다
# 다들 사십시오! ㅋㅋ 굳입니다
# 사진이랑 실물이랑 똑같아오 ㅋㅋ
#
# ----- 001001008 28번째 의류 -----
# 상품명: LENAV
# 평점: 3
# 리뷰수: 1
# 리뷰1: 핏은 예뻐서 휘뚜루마뚜루 입기 좋아요 ㅎㅎ
# 요즘처럼 아침저녁 추울 때 좋네요
# 다만 실밥 정리가 좀 미흡하고 주머니가 한 달도 안되었는데 뜯어졌네요 ㅠ 아쉬워요
#
# ----- 001001008 29번째 의류 -----
# 상품명: MANNON
# 평점: 5
# 리뷰수: 1
# 리뷰1: 너무 멋지고 고급스러운 자켓입니다.
# 쓰리피스로 사서 여행때 너무 잘입었어요, 매넌은 정말 테일러링이 멋져요, 저만 입고 싶지만 추천드려요ㅎㅎ
#
# ----- 001001008 30번째 의류 -----
# 상품명: HANE
# 평점: 4.9
# 리뷰수: 29
# 리뷰1: 길이 사이즈 다 마음에 듭니다
# 배송이 너믜 오래걸린게 흠이지만 받고보니 마음에 들어요
# 리뷰2: 비싸지않은 가격에 휘뚤마뚤 입기 딱 좋아요 ㅎㅎ 귀여우면서도 깔끔한 느낌! 근데 좀 잘 구겨지는게 살짝 흠이긴 합니당
# 리뷰3: 살짝 탁한 네이비네요
# 간절기에 입으몀 좋을 것 같네요
#
#
# ========== 001001010 카테고리 여성의류==========
#
# ----- 001001010 1번째 의류 -----
# 상품명: FRONTROW단독
# 평점: 4.9
# 리뷰수: 631
# 리뷰1: 색은 보기와 같아요. 큼직한데 겨울이라 안에입는 소재도두꺼우니까 많이 클거같지는 않아요. 겨울코트를 보세보다 싸게아주 저렴하게 득템했어요
# 리뷰2: 더워서 사이즈 보려고 잠깐만 입어보고 걸어놨어요. 가격대비 괜찮아요. 한겨울 제외 잘 입을 것 같애요.
# 리뷰3: 너무이뻐요...!!! 핏도 원하던 핏이고, 컬러감도 밝고 원단이 정말 고급져요. 후회없는 선택이었어요!
# 얇은 코트라서 완전 한겨울에는 추울 것 같은데, 히트텍이랑 겹겹이 입으면 또 괜찮을 것 같아요~!
#
# ----- 001001010 2번째 의류 -----
# 상품명: MOHAN단독
# 평점: 4.9
# 리뷰수: 92
# 리뷰1: 키 160초반에 마른 체형이라 그동안 모한 코트는 입을 생각을 못했어요. 그런데 우연히 오프매장에서 이제품 시착해봤는데 너~~무 예뻐서 온라인으로 바로 구매했어요♡
#
# ☆ 핏
# 품과 길이 모두 여유가 많지만 어깨가 라그란소매이고 소재가 유연해서 어깨에 맞게 딱 떨어져요. 아빠옷 뺏어 입은 것 같은 느낌이 없어서 너무 좋았어요.
# 소매길이는 제 팔이 키에 비해 긴 편이라 검지와 엄지 갈라지는 부분까지 와서 적당해요.
# 뒤면이 플레어져있어서 허리끈 묶었을때 허리 아래로 A라인이 되어서 예뻐요. 단추 풀고 입을때는 허리끈을 뒤에서 묶어주면 핏이 예뻐요.
# 총장은 발목에서 한뼘 위 정도 오는데 조금 줄일 생각입니다.
#
# ☆ 소재와 색상
# 카멜헤어가 들어가서 일반 모직코트보다 텍스쳐가 있어 더 따뜻해보이고, 부드럽고 유연한 소재감이라 울 100%소재보다 더 마음에 들어요. 구김도 덜 해요.
# 색상은 사알짝 핑크끼가 도는 오트밀 색상이라 쿨톤인 저에게도 착붙이었어요. 네이비랑 고민했는데 오트밀색상이 소재결이 잘 보여 더 고급스러워 보이고 안색도 더 밝아보여 선택했어요!
#
# ☆ 디테일
# 트렌치코트 디테일이 있어서 단추를 잠그고 허리끈을 묶으면 단정하고 세련된 느낌을, 단추를 열고 입으면 캐쥬얼한 느낌을 둘 다 낼 수 있어 좋아요.
# 소매 끝에 5cm정도 트임이 있어서 그 부분을 접으면 소매단 느낌이 또 달라요. 소매가 너무 길다고 느끼시는 분들은 단을 접어 입으시면 좋을 것 같아요.
# 리뷰2: 66사이즈 엑스스몰 핏이 딱 이쁨. 옷 무거운 편임
# 단추구멍 박음질 안되어있으나 사이즈 품절로 교환불가
# 에스사이즈는 넘 클듯하여 세일가에 전체적으로 옷 괜춘해서 입을듯해요
# 리뷰3: 제 사진 삭제됐길래 다시 올립니다 상품들 구매하면서 평점 5점 아래는 한 번도 준 적 없었는데 실망스러웠습니다
# 옷 자체는 예쁜 오버핏입니다
# 하지만 마감이나 포장 상태는 잘 모르겠어요 처음 배송 올 때부터 택배상자가 오픈된 상태로 왔고 하자있는 제품이 와서 교환했었습니다 다른 부분은 개선됐는데 벨트는 다림질만 하시고 보내셨고 나머진 그대로더라고요 아무리 벨트라 하더라도 새상품인데도 오래 입어서 보풀 많이 일어난 촉감입니다 흰색검정 실밥 둘 다 나와있고요 시간만 오래 낭비했네요
# 배송 오기전 기대 많이 했었고 모한 아우터 다음 시즌에 사둘 것들 많이 봐뒀었는데 개인적으로는 마감이 깔끔한 편은 아닌 거 같아요 옷자체는 예쁘고 저렴하게 잘 구매했습니다
#
# ----- 001001010 3번째 의류 -----
# 상품명: BAU by Bride And You단독
# 평점: 5
# 리뷰수: 8
# 리뷰1: 핏 대박이예요 ㅠ 팔이 길어 한사이즈 크게 샀는데 맘에 들어요!
# 리뷰2: 서초동 문가영이 입은거 봤는데 그 옷이 여기옷이였네요 ㅎ
# 세일가로 엄청 저렴히 구매해서 너무 좋아요
# 기장이 좀 긴듯 하지만 오히려 더 맘에듭니다 ㅎ
# 리뷰3: 핏 너무 좋음
#
# ----- 001001010 4번째 의류 -----
# 상품명: L’H.A.S
# 평점: 5
# 리뷰수: 4
# 리뷰1: 진짜 이뻐요 촉감 넘 좋구요 진짜 가벼워요 모 백화점브랜드 울100코트보다 가격은 비슷한데 퀄리티 훨씬 좋구 가벼워서 너무 좋네요 디자인도 이쁩니다
# S사이즈 하세여 웬만하면
# 애낳고 77입는데 오버핏입니다 ㅋㅋ
# 163인데 거의 발목까지 옵니다 따뜻하겠어요
# 목욕가운핏 싫어하시면 좀 마니 길어서 별로일수도
# 저는 긴거 좋아해서 ㄱㅊ
# 어깨랑 가슴부분 디자인 이쁘고요 좋네요
# 허리끈 대박 가운처럼 묶는거아니고 벨트형식에 얇은거라
# 너무 이쁘게 연출됨 지금까지 다른옷들은 다 벨트 안썼거든요 묶는것들 근데 이건 이쁘고 얇아서 안 걸리적거리고 벨트형식이라 깔끔 ㅋㅋ 굿입니다 너무 만족
# 다른색으로 또 세일하면 더사고싶네요 ㅜ
# 리뷰2: 평소 55 or 때에따라 통통55 인데
# 옷이 넉넉하게 나와서 s 잘 맞아요^^
# 옷 너무 가볍고 소재좋고 이뻐요. 제가 원하던 스타일~~
# 마감도 너무 잘되어있구요.
# 리뷰3: 트렌치 형태의 코트를 좋아하는데 너무 이뻐요
# 코트치곤 가볍고 따뜻해요 같이 코디된 머플러도
# 같이 구입했는데 너무 따뜻하고 멋스럽네요
# 전 셋트로 있는벨트 보다 유하님 처럼 가죽벨트로
# 코디하니 더 이쁜것 같아요
#
# ----- 001001010 5번째 의류 -----
# 상품명: OLIVE DES OLIVE
# 평점: 5
# 리뷰수: 9
# 리뷰1: 고급지고 너무 예쁘네요!!
# 리뷰2: 사진컷과 같아요 블랙과 화이트가 조합되어 깔끔하고 심심하지 않은 자켓이예요 소재도 폭닥하고 겨울에 잘입어질것 같아요
# 아방한 디자인이 귀여워요
# 리뷰3: 사이즈는 좀 큰거 같지만 소재도 좋고 이뻐요
# 세일기간에 득템했네요
#
# ----- 001001010 6번째 의류 -----
# 상품명: MOHAN단독
# 평점: 4.8
# 리뷰수: 196
# 리뷰1: 방금 받았어요
# 이쁠거 같아요
# 할인가가 좋아서 구입했어요
# 올 겨울에 잘입을께요~
# 리뷰2: 너무이쁘네요~남친이 고급스러워 보인다고 해요
# 올 겨울이 기대가 됩니다
# 리뷰3: 매번 눈팅으로 보고 고민하다가 m사이즈 품절되서
# S사이즈와 얼마 차이가 안 나서 구매합니다.
# 옷 자체가 크게 나왔고 꽤 무겁네요
#
# ----- 001001010 7번째 의류 -----
# 상품명: MOHAN단독
# 평점: 4.9
# 리뷰수: 168
# 리뷰1: 오버핏이라 안에 두껍게 입으면 한 겨울에도 따뜻하겠어요~~
# 카멜색 예뻐요~~
# 리뷰2: 오마이갓 진짜 예뻐요
# 고급지고 색상도 넘 예쁘고요!
# 생각보다 무겁지도 않고, 빨리 입고싶어서
# 얼른 겨울 오면 좋겠어요ㅠㅠ
# 리뷰3: 누가 입느냐에 따라 분위기가 다를 것 같은 코트네요. 귀여워보일 수도, 럭셔리해 보일 수도 있는.
#
# ----- 001001010 8번째 의류 -----
# 상품명: OLIVE DES OLIVE
# 평점: 5
# 리뷰수: 2
# 리뷰1: 디자인, 소재, 착용감, 간편함까지~~ 너무 맘에 들어요. 별도의 머플러 타입이라 다른 코트에도 활용 가능성 높을것 같아요. 컬러도 멜란지한 그레이 느낌이 있고, 스티치로 가장자리를 마감처리해서 세련됬습니다. 알찐하게 두루두루 편하게 잘 입을께요.
# 리뷰2: 여름쿨톤에게 완전 강추
# 전 까만쿨인데도 착붙어요
# 사이즈도 좋고 재질도 폭닥합니다
# 디테일도 존귀
# 세일해서 반값이라 진짜 득템한 것 같아요 ㅋㅋ
#
# ----- 001001010 9번째 의류 -----
# 상품명: BAU by Bride And You단독
# 평점: 5
# 리뷰수: 11
# 리뷰1: 고민하다가 세일해서 구입했어요
# 운전하고 다녀서 두꺼운거는 오히려 불편한데 적당히 얇
# 아서 좋아요
# 여성스럽게 입는게 제일 예쁘고 캐주얼하게 입기에는 조금 애매하긴한데 청바지랑 입어도 나쁘진않네요
# 고급져보여요
# 리뷰2: 고급스러워보이고 허리 잘록해보여요 예뽀요 다만 단추색이 마음에 안 드는데 급해서 그냥 입었네용
# 리뷰3: 얇고 타이트해서 한겨울엔 어렵지만. 여성스러운 룩 시크한 룩 다 잘어울림.
#
# ----- 001001010 10번째 의류 -----
# 상품명: OLIVE DES OLIVE
# 평점: 5
# 리뷰수: 7
# 리뷰1: 생각했던거보다 품이 크고, 길이가 길어요. 아이보리에 약간의 연노랑빛이 섞여서 따뜻해보이는 색감입니다.
# 리뷰2: 어깨가 좁은 사람인데 어까라인 디자인이 참 이쁘게 나왔어요! 색깔도 화사하면서도 포근함이 느껴집니다.
# 길이가 살짝 긴듯하지만 그대로 입으려고요. 긴대로 이뻐요. ~~
# 리뷰3: 굿
#
# ----- 001001010 11번째 의류 -----
# 상품명: MOHAN단독
# 평점: 4.7
# 리뷰수: 40
# 리뷰1: 사이즈가 넘 커서 몇번을 고민하다 세일가에 소재가 넘 좋아서 품어요 … 겨울에 안에 두껍게 입으면 쫌 더 맞지 않을까 기대해요!
# 리뷰2: xs사이즈도 아주 넉네해요. 소재 너무 좋고 고급스럽습니다. 길이는 걱정했던것 보다 괜찮았어요
# 리뷰3: 기본 코트가 필요해서 구매했는데
# 유용하게 잘 입을 것 같아요:
# 좋습니다.
#
# ----- 001001010 12번째 의류 -----
# 상품명: OLIVE DES OLIVE
# 평점: 5
# 리뷰수: 2
# 리뷰1: 예전부터 사고싶었던 코트인데 세일할 때 저렴하게 사서 좋아요
# 리뷰2: r굿굿
#
# ----- 001001010 13번째 의류 -----
# 상품명: MOHAN단독
# 평점: 4.9
# 리뷰수: 161
# 리뷰1: 역시즌으로 구경하다가 유행안타고 폭닥폭닥한 코트 잘 구입했어요 제 키와 등치에는 크긴하지만 안에 많이 껴입을수 있을거 같아요
# 리뷰2: 색감 예쁘고 소재 너무 좋아요.
# 키가 작아서 길지만 긴맛으로 입기도 좋을것 같아요~
# 리뷰3: 모한 코트 좋아해서 4개째~!
# 모한코트의 허리끈없는 코트들의 핏을 좋아합니다.>_<
#
# ----- 001001010 14번째 의류 -----
# 상품명: VOIEBIT for WOMEN단독
# 평점: 5
# 리뷰수: 67
# 리뷰1: 기존 리뷰대로 생각보다 소재도 고급 스러워보이고 디자인도 아주 만족합니다 그레이코트 사려고 여러 브랜드 살펴봤는데 가격대비 퀄리티가 우수해 보여서 주문했는데 기대했던대로 대만족입니다!!
# 리뷰2: 약간 큰데 그래도 기본템 무스탕으로 잘 입을꺼 같애요
# 리뷰3: 옷이 편하고 생각보다 가벼워요~
# 겨울내 잘 입었어요
#
# ----- 001001010 15번째 의류 -----
# 상품명: MOHAN단독
# 평점: 4.4
# 리뷰수: 33
# 리뷰1: 사이즈를 s으로 쥬뮨해야할까 했는데 리뷰읽어보니 xs도 큰것 같아 sx로 주문했고 마음이 들어요
# 리뷰2: 와 완전 박시하네여 소재좋은데 무거운감이 있어요 그래서 아직 안입어븀 ㅠㅠ
# 리뷰3: 너무 맘에 들어요
# 소재감이 주는 고급스러움에 따뜻하기도 해요
# 최근 이 아우터만 입어요
#
# ----- 001001010 16번째 의류 -----
# 상품명: sisterhood
# 평점: 5
# 리뷰수: 22
# 리뷰1: 밝은색 코트 할인할때 잘 샀어요🥹 색감 화면이랑 거의 비슷해요 키가 작아서 그렇지 핏은 너무 마음에 들어요! 재질도 좋구요 잘 구매했어요..! 뿌듯뿌듯💛 보관 케이스도 주셔서 감사해요
# 리뷰2: 적당히 가볍고 심플해서 여기저기 매치하기 좋아요
# 리뷰3: 예뻐요 짱짱 따뜻하고 굿굿
#
# ----- 001001010 17번째 의류 -----
# 상품명: sisterhood
# 평점: 0
# 리뷰수: 0
# 리뷰1: 댓글 정보 없음
#
# ----- 001001010 18번째 의류 -----
# 상품명: MOHAN단독
# 평점: 4.9
# 리뷰수: 525
# 리뷰1: 안녕하세요? 저는 159cm/48kg/만 43세예요. 제가 패딩보다 코트를 좋아하는데 부한 느낌이 적고 이불처럼 감싸주어서에요. 제가 잘 입고 다니는 코트는 슬림핏의 검은색코트(영상 10도 전용; 안에 얇은 니트나 셔츠만 가능), 오버핏의 가벼운 베이지코트(0도까지 가능), 두껍고 정핏의 베이비핑크색 코트(0도까지 가능)예요. 그래서 이번에 영하 10도까지 가능한 울함량이 높고 진한 색상을 가진 오버핏의 발마칸코트를 장만하려고 11월부터 코트를 알아보았어요.
#
# 그러다 발견한 이 제품이 너무너무 예쁘더라구요. 하지만 모한의 연한 그레이 색상의 코트도 눈에 들어와서 엄청나게 고민하다 원래의 취지에 맞게 이 발마칸코트를 구매했어요.
#
# 저는 12월 15일에 배송 받았구요, xs를 구매했어요.
# 모델의 키는 180cm(구두포함). 저와 다리길이, 팔길이 모두 엄청나게 차이가 나지만 몸무게 차이는 별로 없을 것 같아요.
# 그래서 차이를 보시라고 아들한테 입혀보았어요.
# 아들은 180cm/54kg/만 15세 구요, 확실히 잘 어울려요.
# 아들과 같이 입어도 될 정도예요.
# 옷은 무겁지만 괜찮구요, 너무너무 따뜻해요.
# 땀나서 벗을 정도예요.
# 사진을 정리하다보니 아들이 주먹을 꽉 쥐고 있는데 혹시 불만 표출인가요? 어쨌든 따뜻하고 예쁜 코트를 사서 만족해요.
# 리뷰2: 이뻐요
# 헤링본도 그레이 색감도 ㅋㅋ
# 다만 팔이 너무길어서 긴팔원숭이 됨
# 리뷰3: 오버사이즈 코트로 말라보이진 않지만 재질 좋아요
#
# ----- 001001010 19번째 의류 -----
# 상품명: OLIVE DES OLIVE
# 평점: 0
# 리뷰수: 0
# 리뷰1: 댓글 정보 없음
#
# ----- 001001010 20번째 의류 -----
# 상품명: MOHAN단독
# 평점: 4.9
# 리뷰수: 127
# 리뷰1: 사이즈 때문에 너무 고민했는데… 예쁜 오버핏이에요 너무 마음에 들어요 고급지고 색상도 톤다운 되어서 딱 원하던 색상이고 아직 입고 나가보지는 못하지만 따뜻할 거 같아요 그리고 다른 코트보다 특별히 그렇게 무겁지 않아요 진짜 여기 브랜드 다른 코트도 더 사고싶네요!
# 리뷰2: 생각보다 크긴한데 옷김이나 디자인 너무 맘에 들어요
# 리뷰3: 고급지고 예뻐요! 쿨톤이라 베이지-갈색톤 안받아서 걱정했는데 얼굴톤 안죽이고 예뻐보입니다. 허리 묶는데 훨씬 이쁘긴해요 롱코트는 애매하고 패딩은 싫을때 딱입니당
#
# ----- 001001010 21번째 의류 -----
# 상품명: OSTKAKA
# 평점: 4.9
# 리뷰수: 76
# 리뷰1: 기본템 필요해서 삿는데 너무 잘 입었어요. 딱 원하는 적당한 핏에 길이여서 마음에 들었어요. 너무 무겁지도 않고 두께에 비해 따뜻해서 좋았어요
# 리뷰2: 너무 부드럽고 핏도 예뻐요 대만족입니다!
# 리뷰3: 저렴한 느낌 없이 깔끔해요
#
# ----- 001001010 22번째 의류 -----
# 상품명: OSTKAKA
# 평점: 5
# 리뷰수: 31
# 리뷰1: 살짝 아방해 보이고 품이 크긴 한데 재질도 좋고 초겨울에 너무 잘 입을 것 같아요!!
# 리뷰2: 작년가을쯤부터 봐두다가 샀는데 맘에들어요
# 색상은 모델사진보다 톤다운인데 이것도 나쁘진않아요
# 모델사진이 더 상큼한색 같긴해요
# 키작고 왜소해서 가슴쪽이 팔통이 많이 오버핏이긴한데
# 안에 껴입을수있어 나은거 같아요
# 옷두께도 막 너무 얇지도않고 나름 두툽하고 안감도 제대로 있어서 좋아요
# 리뷰3: 베이지 먼저 사고 세일할때 블랙도 샀어요 ~ 캐시미어가 있어서 고급져요~
#
# ----- 001001010 23번째 의류 -----
# 상품명: MOHAN단독
# 평점: 4.9
# 리뷰수: 22
# 리뷰1: 확실히 모델은 모델이네요.. 163이 입으니까 땅딸보가 되는 마법 ㅋㅋ ㅜㅜ 그래도 그렇게 안무겁고 질도 넘 좋고 따스해여! 빅세일일때 샀는데 이 소재에 좋은 가격에 샀네여 나름 귀엽고.. 근데 주머니가 막혀있는데 이건 스스로 째야하는건가요… 힘으로 뜯으니까 뜯기기는 하는데 실밥들이 괜시리 무서워셔..
# 리뷰2: 원단은 살짝 무게감은 있지만
# 따뜻합니다 원했던 느낌 그대로
# 모한 사랑이예여
# 리뷰3: 퀄리티도 좋고 귀여워요 흔하지 않은 디자인이라서 마음에 들어요
#
# ----- 001001010 24번째 의류 -----
# 상품명: sisterhood
# 평점: 5
# 리뷰수: 2
# 리뷰1: 스트레이트 체형에다가 키도 크고 팔도 길어서 겨울에 코트 고르는 게 정말 힘든데 상세 사이즈 보자마자 너무 잘 입을 수 있을 거 같아서 샀어요
# 후기가 별로 없어서 고민은 됐지만 그래도 용기 내서 사봤는데 이게 웬걸 제가 인스타 마켓, 백화점 등등 여러 곳에서 웬만한 유명한 코트 많이 사봤는데 제일 맘에 들어요
# 소재도 광이 살짝 나면서 진짜 너무 따뜻하고 보풀도 잘 안생기는 재질이라 만족스럽고 제일 맘에 들었던 건 코트 핏이에요
# 어깨 에서 팔까지 라인이 너무 예쁘고 제 넓은 어깨를 여리여리하게 만들어줘요 착용감은 말할 것도 없이 편한데 너무 예뻐서,, 맘에 안들 이유가 없어요
# 벨트는 해도 안해도 예쁜데
# 벨트를 안해고 허리 라인이 살짝 들어가보이는 게 아주 맘에 쏙 듭니다
# 키큰 여성분들에게 아주 매우 강추입니다 팔 길이가 이렇게 낙낙하게 나온 코트 정말 흔치 않거덩요,,
# 단추고 코트 색이랑 비슷하게 나와 고급스럽고 튀지 않아요
# 블랙이랑 아이보리로 나온 거 같은데 다음 시즌때는 다른 컬러 로도 나오면 좋겠어요 음,, 베이지도 좋고.,🤍
#
# 후기 진짜 잘 안쓰는데 단종 될까봐 무서워서 씁니다
# 사장님 제 허락 없이 단종시키지 말아주세요,, 아님 단종되기 전에 연락한번 주시면 제가 사재기 좀 미리 해두겠 습니다 이렇게 맘에 쏙드는 코트 너무 오랜만이라 두장은 더 쟁여놔야 마음이 편할거 같아요
# 예쁜 코트 만들어주셔서 감사해요 덕분에 올해 겨울 너무 예쁘고 따뜻하게 보낸 거 같아요
# 유명해지고 후기도 많아져서 아더컬러 나오면 좋겠어요!!!!!
# 리뷰2: 모델 착샷 보고 기장이 매우 길 것이라는 예상은 했는데 진짜 기네요ㄷㄷㄷ 바로 개시하고 싶은데 지나치게 길어 수선이 필요할것 같네요
#
# 색상은 다소 탁한 아이보리나 오히려 좋았고
# 재질은 부들부들하니 좋습니다.
#
# 기장 제외하면 만족이에요
#
# ----- 001001010 25번째 의류 -----
# 상품명: sisterhood
# 평점: 5
# 리뷰수: 4
# 리뷰1: 질감도, 색상도, 디자인도 모두 다 맘에 듭니다.
# 실물이 훨씬 예쁜 제품이에요.
# 잘 입겠습니다.
# 리뷰2: 소재와 컬러가 너무 이뻐서 구입했어요. 스티치 바늘땀도 고급스럽구요 일단캐시미어 소재가 차르르떨어지는 옷이라 누가봐도 고급옷처럼 느껴져요. 사이즈나 품은 큰편이네요 카멜코트 갖고싶었는데 잘샀어요
# 리뷰3: 배송이 엄청 빨랐어요!!
# 소재도 부들부들하고 좋았습니다
#
# ----- 001001010 26번째 의류 -----
# 상품명: MOHAN단독
# 평점: 5
# 리뷰수: 7
# 리뷰1: 코트 역시즌으로 샀네요. 캐시미어 20%라 윤기가 달라요.
# 촤르르합니다. 사진보다 실물이 더 소재가 좋아보여요.
# 라글란 소매, 넉넉한 사이즈로 멋스럽게 입기 좋아요.
# 모한 코트만 일고여덟벌 있어요. 코트 맛집
# 검정 코트는 소재가 생명인데 사세요
# 리뷰2: 캐시미어 20% 치고는 좀비싸긴한데 고급스러운ㄴ낌은있어서 잘입을게요. 내추럴 체형인데 딱어깨 각이잡혀있지않어서 무심한듯한 핏이 이쁘네요
# 리뷰3: 넉넉한 옷이라 xs 주문했더니
# 딱~~좋습니다. 따뜻하고요 기장도 좋구요
# 단점은..쬠 무겁습니다
#
# ----- 001001010 27번째 의류 -----
# 상품명: GRACE U
# 평점: 5
# 리뷰수: 1
# 리뷰1: 케이프 고리도 고급스럽고 기장도 길어서 따뜻하게 입을 수 있을 것 같아요
#
# ----- 001001010 28번째 의류 -----
# 상품명: Amour moier단독
# 평점: 4.7
# 리뷰수: 9
# 리뷰1: 세련된 디자인과 도톰한 두께감이 맘에 들어요. 좀 큰 듯하지만 루즈핏으로 코디 잘할 수 있을 거 같아요. 맘에 듭니다~
# 리뷰2: 색상이 좀 달라요
# 더 누리끼리한 아이보리네요
# 화이트에 더 가까울줄 알았는데
# 그냥 품습니다
# 리뷰3: 검은털이 섞여있는듯한 아이보리 니트
# 이너로 니트류 입음 털이 계속 묻어나서 돌돌이해야함
# 하지만 벌룬느낌의 소매와 기장 하이넷이 너무 예쁨
#
# ----- 001001010 29번째 의류 -----
# 상품명: CC collect
# 평점: 0
# 리뷰수: 0
# 리뷰1: 댓글 정보 없음
#
# ----- 001001010 30번째 의류 -----
# 상품명: KELLY DONAHUE
# 평점: 5
# 리뷰수: 23
# 리뷰1: 고급스럽습니다 이뻐요 이뻐
# 리뷰2: 오오 색감 재질 다 맘에 들어요ㅎㅎㅎ 인기있는 템들은 다 이유가 있죠^^ 오버사이즈라 편하게 입을 것 같고 얇은 핸드메이드코트 딱 그런 느낌입니다ㅎㅎ 너무 맘에 들어용
# 리뷰3: 이뻐요 편하게 잘입어져요
#
#
# ========== 001001003 카테고리 여성의류==========
#
# ----- 001001003 1번째 의류 -----
# 상품명: TILLIDIE
# 평점: 5
# 리뷰수: 5
# 리뷰1: 날이 점점 더워져서 얼마 못입을 것 같지만 가을에 입죠 뭐 ㅎㅎ 품도 낙낙하고 아무때나 툭 걸쳐 입기에 좋아요 옷이 너무 예쁩니다
# 리뷰2: 소재랑 디자인 모두 마음에들어요 최고!
# 리뷰3: 제 체구에도 딱 좋은 오버핏으로 예쁘게 입을 수 있어요! 체구가 워낙 작아서 오버핏으로 나온 옷은 입기 어려웠는데 딱 좋습니다~ 이염은 약간 있는 거 같아요
#
# ----- 001001003 2번째 의류 -----
# 상품명: The Raust단독
# 평점: 5
# 리뷰수: 3
# 리뷰1: 소재가 맘에들어요
# 소매를좀 접어야 핏이사는거같아요
# 리뷰2: 라우스트옷 믿고 삽니다. 색상이 항상 뮤트한게 오묘하게 예뻐요. 초가을에 멋스럽게 잘 입을듯요. 배송도 총알배송이라 좋아요.
# 리뷰3: 아니 너무 이뻐요!!!!! 간절기에 휘뚜루마뚜루 입으려고 샀는데 재질도 뻣뻣 이런재질 아니고
# 색감도 고급지네요 눔 이뻐요 엄마듀 탐냄
#
# ----- 001001003 3번째 의류 -----
# 상품명: OLIVE DES OLIVE
# 평점: 4.8
# 리뷰수: 6
# 리뷰1: 키가 158이라서 저한테 좀 길긴하지만 패딩 자체는 넘 맘에 들어요. 입었을때 몸에 감기는 느낌도 좋고 가볍고 넉넉해서 안에 껴입기도 편할것 같아요.
# 리뷰2: 생각보다 큽니다 교환할까했는데 겨울엔 스웨터 등 많이 껴입을테니 커도 걍 입으려구요. 색상은 사진보다 살짝어두워요 가볍네요 한겨울에 입으면 될거같아 세일할때 샀어요.
# 리뷰3: 엄마 선물로 샀어요
# 오버핏이라 엄마한테도 잘 맞아서 좋아요
# 만족합니다
#
# ----- 001001003 4번째 의류 -----
# 상품명: OUR NOSTALGIA단독
# 평점: 4.8
# 리뷰수: 48
# 리뷰1: 좋아요 ! 디자인 좋고 소재 부드럽고 간절기나 살짝 싸늘할대 너무 좋아오
# 리뷰2: 삼고초려 끝에 간신히 산 재킷입니다(..) 여름이라도 비온뒤 사늘한 때에는 걸칠수있을 것같아요. 색감도 여리한 느낌의 카키고 등뒤의 레이스 달린 로고가 포인트가 돼서 예쁩니다^^
# 리뷰3: 좋아요
#
# ----- 001001003 5번째 의류 -----
# 상품명: J.Chung
# 평점: 5
# 리뷰수: 1
# 리뷰1: 제이청 옷을 입어보고 좋아서 자켓류로 하나 더 사봅니다
# 역시 옷을 잘 만드는 브랜드네요 제이청
#
# ----- 001001003 6번째 의류 -----
# 상품명: EIGHT DAYS A WEEK
# 평점: 4.9
# 리뷰수: 82
# 리뷰1: 여행내내 너무 이쁘게 잘 입었습니다 바지 치마 원피스 모든 옷에 너무 잘어울려요 사이즈도 적당한 오버핏에 카라가 포인트 됩니다
# 리뷰2: 적당하게 오버핏 돼서 좋아요
# 리뷰3: 넘 맘에듭니다 프리사이즈라서 66까지도 잘맞을듯해요 편하게 걸치기 좋은 스타일이에요 만족합니다
#
# ----- 001001003 7번째 의류 -----
# 상품명: TILLIDIE
# 평점: 4.9
# 리뷰수: 130
# 리뷰1: 실물이 사진보다 귀여워요 길이도 딱 좋아요
# 리뷰2: 제가 정말 몇달 전부터 갖고싶던 건데 할인할때 사야지 하고 엄청 기다렸었어요!! ㅎㅎ 역시나 제가 생각한 핏과 맞았고 가을이 없다고는 하는데 여행가서 입어보기를 ㅠㅠ 출근룩으로 휘뚜ㅜ마뚤 입기 좋아요 데일리, 여행 룩으로 모든 오케이!
# 리뷰3: 아주아주 예쁩니다 소재도 좋고 디자인도 예뻐요 추천합니다!!!
#
# ----- 001001003 8번째 의류 -----
# 상품명: OLIVE DES OLIVE
# 평점: 4.9
# 리뷰수: 14
# 리뷰1: 예전부터 사고싶었는데 할인해서 샀어요
# 디자인 독특하고 너무 귀여우ㅏ요
# 리뷰2: 핏이 귀여워요 따뜻할지는 아직 모르겠는데 먼가 따뜻할 거 같은 느낌이 들어요(!?) 톤다운된 베이지 색상이 특히 맘에 드네요 고민하다가 할인하길래 사봤는데 만족스러워요
# 리뷰3: 부드럽고 포근한 패딩이에요.
# 겨울에 잘 입을것 같아요.
# 세일 쿠폰적용해서 저렴하게 잘 구매했어요.
#
# ----- 001001003 9번째 의류 -----
# 상품명: LOEUVRE
# 평점: 4.9
# 리뷰수: 120
# 리뷰1: 올해 제일 잘산템! 휘뚜루마뚜루 입기 너무 조음 ㅎㅎ 한여름 에어컨 바람에 취약해서 이런 옷 진짜 필요한데 이쁘고 가볍고 완벽스
# 리뷰2: 블라우스 스타일이라서 귀여워요! 가볍고 실내에서 에어콘바람 쎈 실내뿐 아니라 비 오는 날에도 입기 괜찮아서 만족합니다!
# 리뷰3: 디자인은 맘에 들어요. 여성스럽고 귀여운 점퍼네요..옷감은 얇긴 한데 그렇게 질이 좋은 것 같진 않네요..생각보다 옷 품이 크진 않은데 저한텐 팔이 많이 길어요..셔링 잡을수 있어서 좋아요
#
# ----- 001001003 10번째 의류 -----
# 상품명: LENAV
# 평점: 5
# 리뷰수: 7
# 리뷰1: 디자인이 귀엽네요 냄새도 별로안나요 ㅎ
# 리뷰2: 무광택이라 더 고급스러워보여요 착용감좋고 마감처리 도 좋아요
# 리뷰3: 스타일과 소재가 화면 그대로 마음에 듭니다~
# 날씨가 조금씩 더워져 이제는 못입지만
# 가을에 고고 하려구요~
#
# ----- 001001003 11번째 의류 -----
# 상품명: FACADE PATTERN
# 평점: 5
# 리뷰수: 127
# 리뷰1: 생각했던 것보다 가볍고 냄새도 없는 편이었습니다.
# 매우 만족합니다, 아이템을 하나씩 늘려가야겠어요 !
# 번창하세요 :-)
# 리뷰2: 예뻐요
# 깔끔하고 여성스럽고 가볍고 좋아요
# 리뷰3: 핏 소재감 다 마음에 들어요!!
# 봄 가을 잘 활용할 수 있을것 같아요
#
# ----- 001001003 12번째 의류 -----
# 상품명: MOHAN단독
# 평점: 4.8
# 리뷰수: 378
# 리뷰1: 입었을때 핏이 적당히 넉넉하고 예뻐요~ 소재도 고급스러워보이고 적당히 두께감이 있어서 봄가을에 잘걸칠듯해요~ 다만 지퍼부분이 좀 걸리네요 투웨이지퍼인데 손쉽게 잠기고 열리진 않아요~ 그거빼고 만족합니다!!
# 리뷰2: 디테일 이쁘네요
# 근데 소매에얼룩이있어요
# 물티슈로 지우ㅝ보고 안지지면 교환부탁합니다
# 리뷰3: 봄가을에 잘입게 될 바람막이에요 생각보다 도톰하고 사이즈 여유가 있어서 좋습니다.
#
# ----- 001001003 13번째 의류 -----
# 상품명: ETHOS
# 평점: 4.9
# 리뷰수: 230
# 리뷰1: 올 가을 아우터 딱 1개만 산다면 에토스 가죽자켓을 구매하세요!
# 사진보다 실물이 100배 예쁘네요. 반품이 안 된다고 해서 받아보고 별로면 어떡하나 고민했는데 괜한 고민이었습니다.
# 오버핏이고 어깨에 패드가 들어있는데도 전혀 부해보이지 않네요. 딱 제가 원했던 핏입니다.
# 포멀과 캐주얼 사이 어디엔가 있는 블루종 디자인이고요,
# 색상이 블랙이긴 블랙인데 색이 오묘하고 고급져 보입니다.
# 치마, 바지, 원피스 다 잘 어울릴 것 같아요. 어떻게 코디할지 벌써부터 너무 설레네요...♥
# 그냥 기본 티셔츠, 바지에 툭 걸쳐도 코디 완성이에요.
# 보온성이 너무 좋아서 초겨울까지 입을 수 있을 것 같습니다.
# 지금 입기엔 무리고 10월 쯤 되면 입을 것 같아요ㅎㅎ 에토스 첫 구매인데 너무 만족스럽습니다.
# 오래오래 잘 입겠습니다.
# 리뷰2: 멋지네요 남자용이 품절이라 이걸로 샀는데 괜찮게 오버핏입니다. 여자용으로 사길 잘했어요. 가죽재킷은 처음 사봐요. 그동안 입었던 합성가죽 재킷들이 ㅋㅋㅋㅋㅋ 귀여워지네요.
# 디자인이며 퀄리티며 마감이며 다 넘 맘에 들어요. 평생 입을 수 있을 거 같아요 ㅎㅎㅎ 무겁긴 해두.
# 리뷰3: 예전에 구매하고 후기를 너무 늦게써요..
# 잘 입고 잘 보관해뒀습니다 ㅎ
# 지금은 덥지만 가을되면 또 입어야죠. 간절기때 좋아요
#
# ----- 001001003 14번째 의류 -----
# 상품명: TILLIDIE
# 평점: 4.9
# 리뷰수: 107
# 리뷰1: 카라가 반대로 접혀져 있어서 맘에 걸리지만
# 잘 피면 모양이 나올거라고 믿고 품었어요
# 리뷰2: .
# 리뷰3: 한여름인데 예뻐보여서 사고 말았습니다
# 실물이 더 이쁩니다..!
#
# ----- 001001003 15번째 의류 -----
# 상품명: TMAKER
# 평점: 5
# 리뷰수: 126
# 리뷰1: 은은하 광으로 예뻐요
# 편하게 입기 좋아요
# 리본 포인트도 예쁘고 선선해지면 빨리 입고 싶어요
# 리뷰2: 어쩜 너무 예쁘네요 세일할때 잘 샀어요 최고입니다
# 리뷰3: 색상도 예쁘고 사진과 거의 같아요
# 지금은덥지만 곧 가을되면
# 자주입고 다닐듷
#
# ----- 001001003 16번째 의류 -----
# 상품명: MangoManyPlease
# 평점: 4.9
# 리뷰수: 93
# 리뷰1: 여성스러운 디테일이 있어서 마음에 듭니다. 너무 오버핏이 아니라서 활용도 좋습니다!!
# 리뷰2: 요즘 가죽자켓들이 다 길거나 크게 나와서 키작녀인 저한테 어울리는걸 찾기가 힘들었는데, 이상품 너무 만족해요!!
# 가볍고 재질도 고급진 느낌이고 살짝 아방해서 귀여운느낌도있습니다. 스커트랑 매치해도 잘어울려요!
# 리뷰3: 롱기장이랑 고민하다 키작녀서 짧은걸로 샀는데 탁월한 선택이었어요
# 체구가 작아서 큰옷입음 남에옷 입은거 같은데 이건 너무 예쁘네요
# 봄에 구매해서 한철 뽕빼며 입었어요
# 블랙색상이 시켜먼 블랙이 아니라 더 예뻐요
#
# ----- 001001003 17번째 의류 -----
# 상품명: on&on
# 평점: 5
# 리뷰수: 10
# 리뷰1: 아방하고 입으면 너무 귀여워요!!
# 가볍구요!!
# 리뷰2: 옷태는 후드끈?을 묶으면 더 예쁜것같아요
# 좀 바스락 거리는 소리가 거슬리네요
# 세일 많이해서 좋네요
# 리뷰3: 배색이 남색인줄 몰랐는데 남색이네요 검은색보다 남색쪽이 깔끔해서 이쪽으로 더 많이 입을거 같아요
#
# ----- 001001003 18번째 의류 -----
# 상품명: INJIACTIVE
# 평점: 4.6
# 리뷰수: 55
# 리뷰1: 아직 입어보진 않았는데 좋아하는 브랜드라 사고싶어서 결국샀어요 ㅎㅎ
# 리뷰2: 그냥 쏘쏘합니다 이 가격은 쫌 아닌듯ㅠ 세일해서 구입했어요
# 리뷰3: 지금까지 구매한 것 중에서 가장 잘 맞는 사이즈예요! 편안하게 입을 수 있어서 좋습니다."
# - "인생 핏이에요! 정말 예쁘게 떨어지는 라인 덕분에 만족스럽습니다."
#
# ----- 001001003 19번째 의류 -----
# 상품명: on&on
# 평점: 4.8
# 리뷰수: 51
# 리뷰1: 처음에 입어보고 너무 부해서 잘못 샀나 순간 생각했는데
# 스타일 잘 잡으면 입을만 해보여서 따뜻해서 품어요
# 리뷰2: 오~~ 정말 맘에 들어요
# 살짝 카키빛 한방울들어간 진~한 크림칼라 라고 해야할까요? 오히려 너무 밝은 크림칼라가 아니어서 저는
# 더 좋아요
# 길이도 저에게는 딱 좋습니다
# 옷자제가 도톰하고 안감은 안에입은옷과 좀 감길것같긴하지만 그래도 거슬릴정도는 아닌것같아요
# 아주 추운날 아니면 요즘에 입어도 괜찮을듯해요
# 리뷰3: 생각보다 노란끼가 많은 색이에요....!
#
# ----- 001001003 20번째 의류 -----
# 상품명: FACADE PATTERN
# 평점: 4.9
# 리뷰수: 296
# 리뷰1: 눈팅만 하다 질렀어요. 레자 ㅎㅎ 이가격에 사기가 좀 아까운 생각도 들고 세일하길래 맘에 안들면 반품할까 해서 시켜봤는데 초겨울? 아니 한겨울에도 이너를 여러겹 입고 입음 문제 없겠더라구용~~워낙 오버핏을 좋아해서 맘에듭니다.
# 리뷰2: 기대 이상으로 만족스러워요! 적당한 오버핏 덕분에 스타일리시하면서도 편하게 착용할 수 있어요.
# 가볍게 걸쳐도 멋이 살아나고, 계절감도 적당해서 간절기에는 데일리로 손이 자주 갈 것 같아요.
# 디테일 하나하나 신경 쓴 느낌이라 퀄리티에 한 번, 핏에 또 한 번 감동했어요. 블랙 컬러라 어디에나 매치하기 좋고, 오래 두고 입을 수 있을 것 같아 더만족스럽습니다!
# 리뷰3: 역쉬는 역쉬입니다.
# 다만 소매가 쪼매 길어서 접고 다니지만 그것 또한 괜춘!
#
# ----- 001001003 21번째 의류 -----
# 상품명: TILLIDIE
# 평점: 4.9
# 리뷰수: 142
# 리뷰1: 바스락 거리는게 기분좋네요! 선선해지면 가지고다니면서 잘 입을 거 같아요! 저렴해 보이지않고 소재도 좋아요
# 리뷰2: 장마철가볍게 입기좋습니다
# 리뷰3: 장마시즌이나 에어컨바람에 좋을꺼같아 구매했는데 만족합니다 안에 안감도 있고 싼티나는 바람막이 아니에요
#
# ----- 001001003 22번째 의류 -----
# 상품명: MIND BRIDGE women
# 평점: 4.9
# 리뷰수: 65
# 리뷰1: 가을에 입기 딱좋을것 같아요 적당히 톡톡한 소재예요 잘입을게요~
# 리뷰2: 요즘 다른 브랜드 대비 사이즈가 작는거 같아요 저는 체구가 작아서 괜찮습니다 예뻐요
# 리뷰3: 진작 살껄 왜 고민했지
#
# ----- 001001003 23번째 의류 -----
# 상품명: LENAV
# 평점: 4.9
# 리뷰수: 12
# 리뷰1: 여름에 아우터로 입기 좋아요 소재도 좋고 디자인도 이쁘고 살안타템으로도 너무 좋아요
# 리뷰2: 얇고 가볍고 구김 잘 안 생겨서 좋네요. 비 올 때나 실내에 있을 때 에어컨 바람 막기에 적당한 것 같아요.
# 리뷰3: 여름에 살 타는거 싫어하는데 소재가 가벼워서 착용하기 좋아요. 코디하기도 너무 예뻐요. 무조건 추천입니다!!
#
# ----- 001001003 24번째 의류 -----
# 상품명: OLIVE DES OLIVE
# 평점: 4.9
# 리뷰수: 180
# 리뷰1: 가성비 좋아요
# 리뷰2: 목까지 높이 올라와서 따뜻할거 같은데 하관이 부각돼요
# 리뷰3: 다른제품을 크림으로 주문했는데 색이 너무 밝아서 아이보리는 무슨색일까 하고 주문해봤어요
# 사진에서 너무 밝아보여서 걱정했는데 딱 좋은거 같아요 많이 밝지도 않고 어둡지도 않고 딱 베이지색으로 넘어가기전?
# 살이 좀 찐상태인데 사이즈도 괜찮아요
#
# ----- 001001003 25번째 의류 -----
# 상품명: WOOALONG
# 평점: 5
# 리뷰수: 2
# 리뷰1: 너무 예뻐요 ㅠㅠㅠ 색상도 화면 그대로 쨍한네이비고
# 마감처리도 엄청 좋아요 박시하게 입고싶어서 일부러
# 사이즈업 해서 샀는데 넘 맘에들어요 힙해!
# 리뷰2: 가격이 저렴하고 편하게 잘 입을 것 같아요
#
# ----- 001001003 26번째 의류 -----
# 상품명: TILLIDIE
# 평점: 5
# 리뷰수: 13
# 리뷰1: 색상도 밝아서 화사하고 휘뚜루마뚜루 입기좋아요.
# 다만 살짝 핏이 잡혀있어 사각거리긴합니다.
# 리뷰2: 매장에서 입어보고 구매했는데
# 베이지도 네이비도 마음에 들어서 고민하느라 힘들었어요
# 카라 배색이 예쁘고
# 기장도 아주 크롭하지 않아 좋아요
# 리뷰3: 환절기에 입기 좋은 두께감 입니다. 적당한 길이감이라 어떤 하의라도 잘 어울릴듯 합니다. 다만 안감이 면이라 조금 불편함이 있습니다
#
# ----- 001001003 27번째 의류 -----
# 상품명: Saint James
# 평점: 5
# 리뷰수: 3
# 리뷰1: 알고 있는거처럼 옷 질이 되게 좋아요
# 지금보다는 가을 봄에 입는게 좋을것 같습니다
# 리뷰2: 예뻐요
# 리뷰3: 실물이 더 예뻐요
#
# ----- 001001003 28번째 의류 -----
# 상품명: on&on
# 평점: 5
# 리뷰수: 22
# 리뷰1: 작년인가 겨울에 눈여겨 봤던 제품인데 그때는 가격대가 비싸서 망설이다가 안샀는데 지금은 가격대가 좋아서 구매했는데 만족스럽습니다. 안에 털은 많이 안들어있는거 같은데 가볍게 입기 좋아요! 토글도 저렴해보이는 느낌없어서 좋아요. 귀엽습니다. 겨울 되면 열심히 입을것 같아요.
# 리뷰2: 오프라인에서 입어 보고 샀어요.. (오프라인 매장이랑 가격 차이가 너무 큼;;) 가볍고 따뜻하고 핏도 너무 귀여워요~~
# 리뷰3: 토글장식이 너무 귀여워요
# 가볍고 따뜻하니 좋아요
#
# ----- 001001003 29번째 의류 -----
# 상품명: TMAKER
# 평점: 5
# 리뷰수: 67
# 리뷰1: 뒤에 달린 리본이 너무 예쁘네요
# 입어보니 맘에 들어요
# 리뷰2: 이런소재의 힌색 여름 자켓을 찾다가 적당한 가격에 세일할때 구닙했어요~ 휘뚜르 마뚜르 입기좋고
# 캠핑갈때 밤에 입기 좋아요
# 이 자켓은 뒷태가 포인트네용
# 리뷰3: 핏이 루즈하게 잘 떨어지고 디테일이 이뻐요~
#
# ----- 001001003 30번째 의류 -----
# 상품명: FRONTROW단독
# 평점: 5
# 리뷰수: 14
# 리뷰1: 대학생 큰애랑 같이 옷을 입어서~ 사는데 항상 심려를 기울입니다. 젊은 친구들한테도 잘 어울리겠지만, 간이로 백팩에 넣고 다니다가 에어컨 바람이 찰때 입기도 좋을것 같아 구매했어요. 옷이 맵시있고 예브네요. 먼족합니다. ^^
# 리뷰2: 한개 구입해서 너무 마음에 들어 하나더 구매했어요 얇아서 들고다니기도 좋아요
# 리뷰3: 매장에서 입어보고 이뻐서 주문했어요. 입으면 조금 더운 재질이에요. 그래도 이뻐서 입어요. 근데 조금 비싼감이 있어요.
#
#
# ========== 001001011 카테고리 여성의류==========
#
# ----- 001001011 1번째 의류 -----
# 상품명: WOOALONG
# 평점: 5
# 리뷰수: 8
# 리뷰1: 158 기준 엉덩이 반정도 덮는 기장이었고 팔부분이 길어서 좋았어요! 기모라서 날씨 쌀쌀해지면 입기 좋을 거 같아요! 컬러도 이쁘고 S여도 오버핏이어서 좋았어요!
# 리뷰2: 남자도 L사이즈 잘 맞아요
# 색상 생각보다 이뻐용
# 위아래 셋뚜쎗뜌
# 리뷰3: S사이즈 딱 오버핏이에요
# 기모에 소재도 탄탄한데 이가격이라니
# 안 살 수 없죠ㅠㅠ 다른색도 구매 예정!
#
# ----- 001001011 2번째 의류 -----
# 상품명: WOOALONG
# 평점: 5
# 리뷰수: 8
# 리뷰1: 폼이 이쁘게 떨어지는 옷이에요!!
# 리뷰2: 가을부터 겨울까지 막 입기 좋아보여요! 가장 작은 사이즈도 넉넉해서 편할것같아요.
# 리뷰3: 무거운감이 있지만 싸게 사서 좋어요
#
# ----- 001001011 3번째 의류 -----
# 상품명: WOOALONG
# 평점: 5
# 리뷰수: 6
# 리뷰1: 커플템으로 샀어요
# 핏이 예뻐요
# 리뷰2: 적당한 오버핏이라서 편하고 예뻐요
# 리뷰3: 많이 무겁긴한데 가성비로 좋아요
#
# ----- 001001011 4번째 의류 -----
# 상품명: WOOALONG
# 평점: 5
# 리뷰수: 8
# 리뷰1: 저는 44반사이즈라 xs사야하는건 알지만.. 겨울에 추운데 심한 크롭은 배로 바람이 솔솔 들어와 도저히 못입겠더라구요ㅠ그냥 사지말아야겠다 생각했다가 세일을 왕창하니 아잇그럼 s사이즈로 기장 조금 더 길게 입어보자 하고 샀습니다
# 역시나 입어보니 크긴하지만 다른건 괜찮은데 소매만 엄청 긴거라 많이 어색하진않고 그냥 좀 크구나 하면서 예쁘게 잘 입을수있을거같아요
# 리뷰2: 좋은 가격에 좋은 제품 너무 잘샀어요!
# 핏도 너무 예쁘고 톡톡해서 잘산템!
# 리뷰3: 많이 짧은듯 하지만 적당하고 좋아요 셋트로 입으려구 일자핏 팬치랑 함께 구매했어요
#
# ----- 001001011 5번째 의류 -----
# 상품명: WOOALONG
# 평점: 5
# 리뷰수: 7
# 리뷰1: 집업후드수니인데요 핑크색 이쁘고 재질 좋아영
# 리뷰2: S사이즈인데도 무겁고 크네요
# 리뷰3: 조아요조아요 세일할때 잘 샀어요 색깔별로 두개 샀어요
#
# ----- 001001011 6번째 의류 -----
# 상품명: WOOALONG
# 평점: 5
# 리뷰수: 11
# 리뷰1: 남편이랑 같이 커플로 입으려고
# L사이즈 ,M사이즈 구매했어요.
# 두가지 다 입어보니
# M사이즈는 살짝 여유있게 예뻤고
# L사이즈는 오버핏스타일로 예뻤어요
# 옷자체가 핏이 너무너무 예뻐서
# 크게입어도 딱 맞게 입어도 그냥 예쁘네용!
# 재질도 너무 좋구요!
# 리뷰2: 남편이랑 같이 커플로 입으려고
# L사이즈 ,M사이즈 구매했어요.
# 두가지 다 입어보니
# M사이즈는 살짝 여유있게 예뻤고
# L사이즈는 오버핏스타일로 예뻤어요
# 옷자체가 핏이 너무너무 예뻐서
# 크게입어도 딱 맞게 입어도 그냥 예쁘네용!
# 재질도 너무 좋구요!
# 리뷰3: 블루랑 블랙 둘다 샀어요^^
#
# ----- 001001011 7번째 의류 -----
# 상품명: WOOALONG
# 평점: 5
# 리뷰수: 6
# 리뷰1: 제가 원하던 핏이에요
# 허리 부분은 들어가서 날씬해보이고 기장이 짧아서 다리가 길어보이고 쉐입은 귀엽습니다
# 질도 좋아요!
# 리뷰2: 네이비 색상 집업이 필요했는데 너무 이쁘고 가을에 입으면 좋을것같아요
# 리뷰3: 시보리가 되게 짱짱해요 그리고 팔이 되게 깁니다! 키 158에게 xs 잘 맞습니다
#
# ----- 001001011 8번째 의류 -----
# 상품명: WOOALONG
# 평점: 5
# 리뷰수: 9
# 리뷰1: 모자가 커서 촤르륵 흘러내리는 핏이 너무 예뻐요 색상도 흔하지 않고 편하게 학교 다니면서 입을 후드집업이라 만족합니다
# 리뷰2: 좀 크긴한데 색감 예쁘고 맘에 들어요ㅎ
# 리뷰3: 엠사이즈할까 햤지만 s사이즈가 더 좋네요 55-66한테 좋아요
#
# ----- 001001011 9번째 의류 -----
# 상품명: WOOALONG
# 평점: 5
# 리뷰수: 6
# 리뷰1: 핑크사면서 하늘색도 너므이뻐서 샀어오ㅋㅋ
# 리뷰2: 올가을겨울에 잘입을것 같아요
# 편하고 예쁘고 휘뚤하뚤템입니다ㅎ
# 리뷰3: 스몰시켰는데 겁나 커서 라지온 줄
# ㅣㅇㅇ입는 아들에게 맞아요
# 리뷰 딴데보니 마른분도 미디움했던데ㆍ ㆍ와 진짜 어마어마하게 커요
# 두장이나 시킴 ㅜㅜ
#
# ----- 001001011 10번째 의류 -----
# 상품명: WOOALONG
# 평점: 4.9
# 리뷰수: 23
# 리뷰1: 겨울에 기모 츄리닝 위주로 입는데 할인해서 미리 준비 했어요~ 이뻐요
# 리뷰2: 오! 완전 이뻐요!
# 재질도 좋고 기모 보들하니 입었을때 적당한 길이감에 적당히 멋스러운 루즈핏!
# 뭣보다 믿을수없는 가격이죠!!
# 세일기간 득템했어요
# 리뷰3: 생각보다 팔 길이가 좀 길어요 널널해서 편하게 입을 수 있어서 좋아요
#
# ----- 001001011 11번째 의류 -----
# 상품명: VOIEBIT for WOMEN단독
# 평점: 4.9
# 리뷰수: 89
# 리뷰1: 세일해서구매했는데 그가격이적정가인듯
# 리뷰2: 엄청 보들보들하고 도톰해서 따뜻하게 잘 입을 거 같아요
# 그런데 아쉬운 건 팔 길이가 좀 짧아서 핏이 애매한 느낌이 들어요
# 리뷰3: 추워지면 잘 입을거 같아요 넘 예뻐요
#
# ----- 001001011 12번째 의류 -----
# 상품명: WOOALONG
# 평점: 5
# 리뷰수: 7
# 리뷰1: 무난한 티셔츠입니댜
# 할인되서 좋네요
# 사이즈가 살짝 애매 하네요 팔길이 넉넉한데 옷길이 2센티만 길었으면 L는 팔이 너무 길거 같고 암튼 가까운데 갈때 요긴할거 같아요
# 리뷰2: 너무 오버핏도 아니고 타이트하지않아서 편하게 입기 좋을것같아요! 두께도 적당해서 가을부터 겨울까지 잘 입을 듯 해요.
# 리뷰3: 너무 저렴하게 질좋은 옷 잘삿어요
# 이번 가을 휘뚜루마뚜루 템이ㅔ오
#
# ----- 001001011 13번째 의류 -----
# 상품명: WOOALONG
# 평점: 4.8
# 리뷰수: 19
# 리뷰1: 가을 겨울에 입으려고 기모로 미리 주문 했어요~ 크롭인데 너무 날씬해 보이고 세트로 입으면 이뻐요
# 리뷰2: 기장이 짧을까봐 s사이즈구매했는데 소매가 많이깁니다. 디자인 예뻐요
# 리뷰3: 겨울에 따뜻하게입기좋아요. 핏도 이뻐요. 지퍼도 ykk 지퍼로 튼튼해요
# 안에 털빠짐이 쫌 있어서 검정색옷은 입으면 안될듯요. 아니면 한번 세탁해서 털제거 후 입거나..ㅎㅎ
#
# ----- 001001011 14번째 의류 -----
# 상품명: WOOALONG
# 평점: 5
# 리뷰수: 3
# 리뷰1: 남편이 3xl 입는데 딱 맞게 맞아요! 저는 평소 상의는 s 입는데 넉넉하게 큽니다. 가격에 비해 질이 더 좋은 제품이네요 ㅎㅎ 잘 입을게요!
# 리뷰2: 우알롱 시그니처 릴렉스 와이드 팬츠 라이트 그레이 색이 있어서 같은 색으로 주문했는데 이게 더 진해요! 그래도 이뻐서 마음에 들어요 세일 기간때 저렴하게 구입했는데 다른색도 사고 싶어요ㅎㅎ
# 리뷰3: 첨에 받고 베이지를 주문한 줄 알았어요ㅜ 그래도 예뻐요
#
# ----- 001001011 15번째 의류 -----
# 상품명: WOOALONG
# 평점: 5
# 리뷰수: 7
# 리뷰1: 소재도 탄탄하고 기모도 있고 허리도 꽉 쨍기지 않아서 좋아요 모자도 넉넉합니다 소매가 길긴 한데 알고사서 괜찮아요
# 리뷰2: 편하고 따뜻해요 ^^
# 감사합니다 !!!
# 리뷰3: 이가격대에 이 퀄리티 👍
# 처음 사보는 브랜드인데 감탄해봅니다
# 겨울에 입을 옷 퀄리티 좋은거 쟁겨놔서 든든해요
# 좀 작으면 어쩌지 했는데 잘 맞구요 겨울 두꺼운옷읃 안될거같고 ㅎㅎ 팔은 무쟈게 길어요 소재나 마감처리 다 좋아요 다른것도 또 사고 싶네요^^ 짝꿍이라 세트로 입게
#
# ----- 001001011 16번째 의류 -----
# 상품명: WOOALONG
# 평점: 4.9
# 리뷰수: 7
# 리뷰1: 우오ㅏ 진짜 색감도 넘 좋구 착용감이며 핏 굿이에용 ㅎㅎ
# 리뷰2: 도톰하고 생각보다 더 따뜻할것 같아요. 크롭이라서 귀엽고 색상과 많이 과하지 않아서 무난해요
# 리뷰3: 색깔도 이푸고 핏도 넉너한듯 허리는 잡아줘서 마음에 들어요
#
# ----- 001001011 17번째 의류 -----
# 상품명: WOOALONG
# 평점: 5
# 리뷰수: 5
# 리뷰1: 44반에서 55사이즈인데 살짝 큼
# 그래도 낙낙하니 이쁨
# 상체 작은 사람은 클 수 있음
# 리뷰2: 너무 예쁜데 무거워서 깜놀했어요!! 진짜 두터워서 한겨울도 가능할꺼 같아요. 사이즈보다 크게 나온거니까 감안하고 구매하시면 될ㅋ거 같아요
# 리뷰3: 무게감은 좀 느껴지지만 속 기모나 탄탄함이나 세일 가격에 구매한거 생각하면 완전 득템이네요!!
#
# ----- 001001011 18번째 의류 -----
# 상품명: WOOALONG
# 평점: 5
# 리뷰수: 5
# 리뷰1: 넘 이뻐요 세트로 구매햇서요 ㅠㅠㅠ 할인할때 잘 산거같아요
# 리뷰2: 고퀄의 옷을 세일가로 겟해서 기분좋아요
# 얼른 가을 왔으면 좋겠어요!!!
# 리뷰3: 부드러워요 사이즈는 적당히 크지도 작지도않게 나온것같아요 ~
#
# ----- 001001011 19번째 의류 -----
# 상품명: Siyazu
# 평점: 4.8
# 리뷰수: 523
# 리뷰1: 부드럽고 따뜻해요. 보풀만 덜 일어났으면 좋겠어요
# 리뷰2: 진짜 인생 가디건이에요. 캐주얼하게 이쁘고 조직감도 좋고 부드러워요
# 리뷰3: 보풀이 너무 잘나서 생각보다 아쉬움
#
# ----- 001001011 20번째 의류 -----
# 상품명: WOOALONG
# 평점: 5
# 리뷰수: 2
# 리뷰1: 이뻐요 편하구요^^
# 감사합니다 !!!
# 리뷰2: 생각한 그대로였어요! 니트 짜임과 데미지 디테일이 잘 어울려용
#
# ----- 001001011 21번째 의류 -----
# 상품명: HANE
# 평점: 0
# 리뷰수: 0
# 리뷰1: 댓글 정보 없음
#
# ----- 001001011 22번째 의류 -----
# 상품명: WOOALONG
# 평점: 4.8
# 리뷰수: 56
# 리뷰1: 크롭 엄청 이뻐요 까만 실밥같은 거나 까만 보풀이 좀 묻어있긴 한데요 그렇게 심하진 않아요 왜 묻어있는진 모르겟음
# 리뷰2: 소매가 짱짱하고 길어서 손목에 착 붙어서 잘 안흘러내리고, 안에 얇은 티 입고 입으면 딱 지금 입기 좋아용 기장은 딱 허리정도까지? 됩니당
# 리뷰3: 가을 겨울에 입기 좋아요
# 크롭의 기장이며 딸아이 사줬는데 너무 좋아 합니다
# 청바지 스키니 다 어울립니다
#
# ----- 001001011 23번째 의류 -----
# 상품명: FACADE PATTERN
# 평점: 4.8
# 리뷰수: 135
# 리뷰1: 소재도 좋고 핏도 예쁘네오 잘입을게요
# 리뷰2: 재질이 탄탄한걸로 찾았는데
# 보는거랑 실물 받았을때 같았어요
# 디자인이 찾던거랑 같아서 너무 마음에 들었어요~~!
# 숏기장이면서도 너무 숏하지않아 적당하고
# 늘어짐 없이 입을수있을것 같아요~
# 리뷰3: 각이 딱잡힌 소재임
# 벙벙한 코트안에 겹쳐입기 좋은 디자인이고
# 엣지있는 스타일의 후디점퍼임
# 싼티안나고 나름 고급미가 느껴짐
#
# ----- 001001011 24번째 의류 -----
# 상품명: WOOALONG
# 평점: 5
# 리뷰수: 1
# 리뷰1: 로고도 자주고 진짜 컬러며 핏이며 뭐하나 안빠지고 감동적으루다가 예쁩니다😍😍
# 너무 너무 맘에 쏙들어요❤️
# 잘입겠습니다 우알롱 쵝오❤️
#
# ----- 001001011 25번째 의류 -----
# 상품명: ADIDAS
# 평점: 4.8
# 리뷰수: 12
# 리뷰1: 크롭으로 리본이 예뻐서 샀눈데 맘에 들고 편하게 입을 수 있겠습니다.
# 리뷰2: 얇고 후들후들해서 넘 좋아요
# 리본은 한쪽씩 매듭져서 묶었는데 예쁘네요🤍
# 리뷰3: 디자인은 정말 맘에 들어요. 정말 얇은 홑겹이라 모자가 무거워ㅜ뒤로 젖혀집니다. 리본으로 매면 유니크합니다. 디자인이 다한 옷입니다. 바지는 다른 곳에서 구매했는데 바지가 상당히 큽니다. 바지는 모델핏나오려면 한사이즈 작게하세요.
#
# ----- 001001011 26번째 의류 -----
# 상품명: Siyazu
# 평점: 4.9
# 리뷰수: 528
# 리뷰1: 고민했는대 사길 잘했어요~ 편하게 잘 입을 것 깉아요 아주 좋습니디~=
# 리뷰2: 귀여워요 ㅎㅎ
# 더워서 못입지만 날 선선해지면 바로 입을예정!
# 리뷰3: 길이가 좀 짪으나 입기좋고 겨울엔 안에 입기좋음
#
# ----- 001001011 27번째 의류 -----
# 상품명: WOOALONG
# 평점: 0
# 리뷰수: 0
# 리뷰1: 댓글 정보 없음
#
# ----- 001001011 28번째 의류 -----
# 상품명: Touche Songe단독
# 평점: 5
# 리뷰수: 1
# 리뷰1: 미쳐땨냐요..... 패턴 무슨일이세여... 안감도 있고.... 가을 봄 바람 막이이지만...... 진짜 느으무 이뻐요 ㅠㅠ 레이스 패턴 살랑하는데 개인적으로 이렇게나 이쁜 옷은 간만이에요~ 품도 넉넉하여 힙합니다!
#
# ----- 001001011 29번째 의류 -----
# 상품명: alvinclo
# 평점: 5
# 리뷰수: 17
# 리뷰1: 그냥 인터넷에서 맘에 쏙 드는 후드를 샀는데 품절로 좌절 폭풍 검색하다 여기 브랜드 알게되서 홀린듯 주문 했습니다 가격 진짜 저렴하게 구매했어요 제가 원하던 핏은 아니었으나 오버핏으로 미듐 사이즈 맞았어요 지퍼도 아주 튼튼 재질은 제가 원하던 재질
# 모자도 무겁지 않구요 요즘은 보세에서도 후드끈 부분은 스텐???처리로 깔끔하게 잘 나오던데 그 부분은 좀 아쉽네요 포장도 배송도 쿠폰 주셔서 가격두 엄청 좋게 만족한 소비였어요
# 리뷰2: 편하게 입기 좋아요. 크게 입는 게 더 예쁜 것 같아요.
# 리뷰3: 루즈핏 편해요
#
# ----- 001001011 30번째 의류 -----
# 상품명: MONOHA
# 평점: 5
# 리뷰수: 4
# 리뷰1: 촉감이 부들부들해서 입기 편하구오. 생각보다 사이즈는 많이 안커요. 특히 어깨. 마른편인데 잘 맞아요ㅎㅎㅎ
# 리뷰2: 굿
# 리뷰3: 여름에 에어컨이 있는 실내에 들어가면 추위를 많이 타서.. 그럴 때 입을려고 구매했는데 적당한 두께감이 입기에 너무나 좋습니다.
#
#
# ========== 001001007 카테고리 여성의류==========
#
# ----- 001001007 1번째 의류 -----
# 상품명: OLIVE DES OLIVE
# 평점: 4.9
# 리뷰수: 141
# 리뷰1: 55사이즈 했는데 품이 크긴해요.
# 하지만 겨울에 두꺼운 옷 입고, 입기에는 나쁘지 않을거 같고, 다들 말씀하신것처럼 끈 묶으면 예뻐요 😀 때도 안타서 편하게 입기 좋을거 같아요
# 리뷰2: 클까봐 걱정했는데 싸이즈 딱좋아요.낙낙한 느낌쓰
# 너무 가볍다는 아니고 적당한 무게!
# 리뷰3: 작년에 눈여겨 본 점퍼인데 오버핏이라 고민했는데 44사이즈가 있어서 구매했네요. 역시즌 가격으로 좋은 가격에 구매해서 만족해요.
#
# ----- 001001007 2번째 의류 -----
# 상품명: WEDNESDAYOASIS FOR WOMEN
# 평점: 4.8
# 리뷰수: 370
# 리뷰1: 좋아요
# 리뷰2: 클 줄은 알았지만 제가 생각한 것보다 훨씬 컸어요!! 덩치 좋은 제 신랑도 맞네요😂 그치만 편하게 입기 좋을 거 같아요~~
# 리뷰3: 오버핏 오버핏 하긴 했는데 세상에 이렇게 클줄은 몰랐어요ㅋ나름 오버핏 즐겨입는 사람인데 한단계 더 위인 느낌입니다. 옷은 색상이나 디자인이나 전체적으로 마음에 드는데 사이즈때문에 며칠 고심했어요....그나마 할인가로 구매해서 그냥 입어보려고 합니다!! 근데 진짜 커요...
#
# ----- 001001007 3번째 의류 -----
# 상품명: IT MICHAA
# 평점: 0
# 리뷰수: 0
# 리뷰1: 댓글 정보 없음
#
# ----- 001001007 4번째 의류 -----
# 상품명: BAU by Bride And You단독
# 평점: 4.9
# 리뷰수: 70
# 리뷰1: 핏이 이뻐여
# 리뷰2: 너무나 맘에 들어요^^ 옷 정말 예쁘고요, 겨울에 이거 하나 있음 추위 걱정 끝일 듯요!
# 리뷰3: 너무 예뻐요 좋은 가격에 잘 모셔왔어요 감사 굿굿
#
# ----- 001001007 5번째 의류 -----
# 상품명: ADIDAS
# 평점: 5
# 리뷰수: 2
# 리뷰1: 할인해서 좋은 가격으로 구매했는데 너무 이뻐요
# 색도 살짝 빛나는데 연보라 회색빛이고 스트링조절도 되고
# 안쪽 안감색도 이뻐요✨
# 리뷰2: 아주나이스한 가격으오 샀어용
# 맘에 쏙 들어영
# 이번 겨울에 뽕뽑아야지 히히힣
#
# ----- 001001007 6번째 의류 -----
# 상품명: ADIDAS
# 평점: 0
# 리뷰수: 0
# 리뷰1: 댓글 정보 없음
#
# ----- 001001007 7번째 의류 -----
# 상품명: LOEUVRE
# 평점: 5
# 리뷰수: 5
# 리뷰1: 쌩화이트가 아니고 아이보리라 너무 맘에 들구요 사실 아우터는 크게입는편이라 m할까했는데 s하길 너무 잘했어요 커요!ㅋㅋ 롱패딩인데도 가볍지만 부해보이는건 어쩔수없어서 허리 무조건 졸라매야 이뻐요 같이 온 패딩 목도리하면 꼭 한복 목도리 같은데 너무 귀여워서 좋습니다ㅎㅎ 일단 가볍고 부드러워서 좋고 40만원대 제품 클리어런스로 싸게사서 너무 기분좋네요👍👍👍 대만족입니다
# 리뷰2: 포장도 잘 되어왔구요 옷도 예쁘고 맘에 들어요. 여름에 좋은 가격으로 사서 만족합니다.
# 리뷰3: 루에브르 클리어런스 세일 행사로 겨울코트 두개 득템 완전 대박.
# 옷장에 있던 코트들이 전부 못나보임ㅋㅋ
# 아.
# 너무맘에들어요.
# 이 더운날씨에 겨울에 입을생각하면서 행복해졌다는ㅋㅋㅋㅋㅋㅋㅋ
# 최고♡
#
# ----- 001001007 8번째 의류 -----
# 상품명: MOHAN단독
# 평점: 4.7
# 리뷰수: 16
# 리뷰1: 모델은 완전 블랙인데 실제로 받으니까 차콜이라서 엄청 고민했는데 핏이 예뻐서 품기로 했어요
# 리뷰2: 사이즈 좋네요~~~ 뽕실뽕실한 느낌
# 세탁 전에 한번 입어봤어요, 겨울이 기대되요
# 할인된 가격으로 구매하니 더 좋아요^^
# 집엔 롱패딩밖에 없었는데 오랜만에 패딩 구매했네요!
# 리뷰3: 세일이라 우연히 봤는데 너무 맘에 들어요
# 원하는 디자인에 색상 생각보다 가벼워요
# 아직 보기만해도 덥지만 겨울에 유용템이 될것 같습니다
# 예쁘당
#
# ----- 001001007 9번째 의류 -----
# 상품명: ADIDAS
# 평점: 5
# 리뷰수: 1
# 리뷰1: 고등딸 주려고 할인 많이 해서 바로 겟했어요
# 바스락거리는거 없이 부들부들 재질 좋아요
# 다만 팔 관절부분 털이 많이 없는것 같아 아쉬움이 있네요
# 그래도 무난히 잘 입을수 있을 것 같아 만족합니다
#
# ----- 001001007 10번째 의류 -----
# 상품명: Saint James
# 평점: 5
# 리뷰수: 4
# 리뷰1: 앞뒤 다른 느낌으로 모두 맘에 들어요~~😊
# 리뷰2: 매장에서 보고 한눈에 반해서 바로구매
# 양면이지만
# 제기준 하늘색부분은 그저그렇고
# 남색부분 너무 이쁩니당♡
# 리뷰3: 베이지색만 입다가 이런 색 처음 구입했는데
# 너무 귀여워요
#
# ----- 001001007 11번째 의류 -----
# 상품명: on&on
# 평점: 4.8
# 리뷰수: 75
# 리뷰1: 솜이 많지는 않지만 따듯하고 편해요~
# 리뷰2: 겨울 내내 교복처럼 있었습니다. 귀여운 스타일이고 편하게 입을 수 있는데 조금 얇은 편이라 한겨울에는 단독으로 입기는 어려울 듯 합니다.
# 리뷰3: 제키에는 한 무릎 한뼘 위 정도 오네요!
# 따로 패딩허리띠 사서 코디 해서 입는데 귀여워요!
#
# ----- 001001007 12번째 의류 -----
# 상품명: CC collect
# 평점: 0
# 리뷰수: 0
# 리뷰1: 댓글 정보 없음
#
# ----- 001001007 13번째 의류 -----
# 상품명: FRONTROW단독
# 평점: 5
# 리뷰수: 7
# 리뷰1: 딱 생각했던 색상에 너무 가벼워서 좋아요
# 잘 산 것 샅습니다 ㅎㅎㅎㅎ
# 딸기우유 색상에 브드라운 촉감이에요 넘넘 맘에 듭니다
# 리뷰2: 이 패딩 대박 이뻐요 컬러도 과하지 않고 귀염뽀짝합니다 가볍고 너무 예빠요
# 리뷰3: 때 탈까봐 조심히 입어야겠지만
# 디자인이 너무 이뻐요 최고..
# 엄청 가벼워요, 혹시나 모르니까 이너 잘챙겨입어야겠어요!!
#
# ----- 001001007 14번째 의류 -----
# 상품명: MOHAN단독
# 평점: 4.8
# 리뷰수: 33
# 리뷰1: 입자마자 너무 예뻐서 놀랐어요! 글로시한 소재에 베이지 색도 예쁘고 셔링 디자인이 진짜 특이한데 예뻐요! 사이즈가 약간만 더 작았으면 싶기는 한데 겨울에 두껍게 입을거 생각하면 제 체형에는 m사이즈가 맞는것같아요!
# 리뷰2: 전에 구입한 코드들이 맘에 들어서 패딩도 본건데 역시즌여서 할인도 많구 좋은가격에 구매했네요
# 셔링이 있다보니 부해 보이는 것도 없구 좋아요
# 가벼워요
# 따뜻해요
# 리뷰3: 셔링 모양이 진짜 이뻐요
#
# ----- 001001007 15번째 의류 -----
# 상품명: HACIE단독
# 평점: 4.9
# 리뷰수: 165
# 리뷰1: 보통 상의 M(55)이나 90입습니다. 모델 스펙보고 S시켰는데 딱 좋아요. 안에 두꺼운 니트 입으면 좀 빵빵하겠지만 예쁜 핏으로 입을 수 있을 것 같아요. 친구가 제작년에 비슷한 디자인으로 인스타 메이드 상품 20넘게 주고 샀는데 몇번 입으니까 부자재도 떨어지고 소매 보풀에 구스 부피감도 죽는 등 퀄리티 떨어지는 것 보고 좀 놀라서 구매 못하고 있었는데 좋은 상품 발견한 것 같아요.
# HACIE 상품은 첫 구매인데 만족합니다. 여기저기 디테일도 좋고 마감도 훌륭하고 싼티 안나서 좋아요. 특히 모자 털이 눌려서 배송되지 않게 박스포장인거 정말 좋았습니다. 모자 털의 부피감이나 은은한 광택, 부드러움이 고급지게 보여서 젤로 맘에 드는 부분입니다. 그리고 이미 허리 선이 잘록하게 들어가 있어서 벨트 채웠을 때 풍선에 고무줄 묶은 느낌 없이 그냥 딱 허리 라인에 감기는 느낌이 좋습니다.
# 올 겨울 제 교복 확정ㅎㅎㅎ 흰색도 지를까 고민중이에요~~
#
# - 모자털 탈부착 가능
# - 모자 깊이는 썼을 때 모자 털이 얼굴 라인을 감싸는 정도(딱 좋음)
# - 안에 속주머니 하나 있음
# - 소매단 깊게 잘 되어 있음
# 리뷰2: 긴가민가 고민하다 주문했는데 너무 마음에 들어요. 가볍고 따뜻합니다.
# 리뷰3: 가볍고 따뜻하고 너무 잘 입었어요!
#
# ----- 001001007 16번째 의류 -----
# 상품명: IT MICHAA
# 평점: 5
# 리뷰수: 7
# 리뷰1: 길이도 적당하고
# 세일해서 잘산것같아요
# 겨울 내내 이리저리 잘입어질것같아요
# 리뷰2: 페미닌한 숏패딩을 찾던중에 세일하길래 구매완 너무 맘에들고 잘맞아용ㅎㅎ
# 리뷰3: 제 키에도 딱 맞고 너무 예뻐요. 가볍고 고급스럽고 따뜻하고! 그런데 검정색이 좀 연해요. 사진만큼 선명한 검정색이엇으면 좋았을 것 같아오.
#
# ----- 001001007 17번째 의류 -----
# 상품명: IT MICHAA
# 평점: 5
# 리뷰수: 3
# 리뷰1: 전반적으로 은은한 레몬빛?? 아이보리함이 있는 화이트 컬러에요~~ 아주 맘에 드는 숏패딩 입니다!! 배송 빨라서 좋앗어요 ㅎㅎ
# 리뷰2: 생각보다 따뜻하지는않아요~ 너무 추울때는 안될듯~ 영하1~2도까지는 괜찮을듯~ 추위마니타는스탈이에요~가벼워요~
# 리뷰3: 색상 너무 이쁘고 귀엽네요 자주 입을것 같아요 ㅎㅎ
#
# ----- 001001007 18번째 의류 -----
# 상품명: THETIS
# 평점: 4.9
# 리뷰수: 154
# 리뷰1: 검정색 사고 예쁘고 편해서 흰색도 샀습니다. 사이즈 편하고 따뜻해요.
# 리뷰2: 저한테는 팔 길이랑 어깨가 조금 길고 큽니다. 예상했던 것보다 너무 유아틱하지 않아서 좋네요. 할인 된 금액이 아니면 구매를 조금 망설일 것 같긴 합니다. 예뻐서 품 어요. 잘 입을게요. 감사합니다.
# 리뷰3: 너무 이쁘네요 만족스러운 쇼핑입니다.
#
# ----- 001001007 19번째 의류 -----
# 상품명: MOHAN단독
# 평점: 4.8
# 리뷰수: 21
# 리뷰1: 예뻐요 할렐루야 조아요 재구매 가능 합니다
# 리뷰2: 얇은데 엄청 따뜻하다는 후기 그대로이네요. 어깨가 생각보다 크지만 오버핏으로 입으면 되니까 만족합니다
# 리뷰3: 통통한편인데 스몰도 딱여유있기 맞아요!! 퀄리티 좋고 예쁩니다! 생각보다 두터워서 초겨울? 영하5도까지는? 입어도될것같아요!!
#
# ----- 001001007 20번째 의류 -----
# 상품명: SISTINA
# 평점: 4.8
# 리뷰수: 36
# 리뷰1: 완전 마음에 듭니다 ~~ 넘 귀여운 옷 최고 !
# 리뷰2: 약간 바스락거리는데 신경쓰일정도아니고 소재가 이뻐요
# 혹시나하는맘에 마감처리 살폈는데 깔끔하네요.
# 검은롱패딩은 김밥될거같고 흰색은 금방 더러워져서 망설였는데 색상이 베이지로 딱좋아요ㅎㅎ
# 옷이 크게나왔지만 무겁지않고 부하게보이지도 않아서 이쁘고 따뜻하게 잘입을거같아요~겨울교복되겠어요^^
# 리뷰3: 리뷰보고 휘뚜루마뚜루 입으려고 샀는데 정말 잘산것같아요
# 귀여워요
#
# ----- 001001007 21번째 의류 -----
# 상품명: IT MICHAA
# 평점: 5
# 리뷰수: 6
# 리뷰1: 반품하는게 진짜 일인데 오자마자 입어봤는데 생각했던 그대로 딱이네요!! 너무이쁘고 길이감 핏 전부 다 맘에들고 할인까지해서 너무 좋습니다~!!
# 리뷰2: 요즘 매일 입고 있어요! 근데 생각보다 따뜻하진 않아요
# 163기준 무릎 덮긴 하는데 길이가 쫌만 더 길었으면 좋겠고
# 모자 부분에 단추같은게 없어서 너무 잘 벗겨져요
# 리뷰3: 저처럼 벨트가 자세히 보고싶었던 분들이 보시면 도움이 될거에요.
# 너무 예쁘네요.
#
# ----- 001001007 22번째 의류 -----
# 상품명: on&on
# 평점: 5
# 리뷰수: 6
# 리뷰1: 재질이 좀 좋아보이지는
# 않아요
# 할인가격이니 겨울에 잘 입을거 같아요
# 리뷰2: 사이즈는 일부러 살짝 널널하게 시켰는데 딱 좋고 패딩 너무 가볍고 따뜻하고 귀여워요ㅠㅠ
# 리뷰3: 사이즈 정 사이즈이고 엄마가 마음에 들어하시네요
#
# ----- 001001007 23번째 의류 -----
# 상품명: MOHAN단독
# 평점: 4.9
# 리뷰수: 12
# 리뷰1: 크기가 커서 생각보다 예쁜 핏은 러니지만 편하게 입기 좋을 듯 합니다
# 리뷰2: 여유로운 사이즈라 안쪽에 껴입어도 편합니다
# 허리끈으로 다른 분위기 연출도 되고 좋네요
# 리뷰3: 사이즈가 여유있어서 두꺼운 옷에 입어도 편하게 입기 좋아요 소재도 부드러운 소재
# 넥 부분 올라와서 따로 머플러 안해서 좋고
# 기장도 길어서 따뜻하게 입기 좋아요
#
# ----- 001001007 24번째 의류 -----
# 상품명: REPERE
# 평점: 4.8
# 리뷰수: 144
# 리뷰1: 따뜻하며 원단이 포근하며
# 기장이 마음에 들어서 자주 입을듯 해요
# 리뷰2: 엄청 따뜻해요 목 부분 단추 잠그는게 힘들지만 따뜻해요ㅠ 크기에 비해 가벼워요
# 리뷰3: 최고입니다 따뜻
#
# ----- 001001007 25번째 의류 -----
# 상품명: JJ JIGOTT
# 평점: 5
# 리뷰수: 1
# 리뷰1: 색이 이것만 남아있어서 샀는데 오히려 마음에 들어요! 이쁨니다!!
#
# ----- 001001007 26번째 의류 -----
# 상품명: MOHAN단독
# 평점: 4.9
# 리뷰수: 51
# 리뷰1: 좋아요 예쁘네요
# 리뷰2: 올해 산 옷 중에 가장 잘 산 옷 같아요.
# 사이즈 넉넉해서 추위 많이 타는 사람은 안에 많이 껴입을 수도 있고 길이도 엉덩이 덮어서 너무 좋아여... 따숩
# 색상도 딱 원했던 버터베이지에 소재 버튼 다 고급지고 예뻐요. 목까지 잠가 입어야 옷의 느낌이 제일 예쁜 것 같고요. 허리 버튼만 채워서 입어도 예뻐요. 데일리 휘뚤마뚤인데 적당히 꾸민 느낌도 나고. 여성스러우면서도 너무 막 여자여자 그런 것도 아니구... 출근룩도 되고 캐주얼도 되고 조아.. 다 조아
# 체격 많이 작거나 루즈핏 안입어 보신 분들은 좀 클 수도 있을 것 같은데 저한텐 진짜 최고의 아우터임당 너무 맨날 입어서 사진 많음ㅋㅋㅋㅋㅋㅋ
# 리뷰3: 너무 이쁘고 좋어요. 세일할때 구매 잘 했어요 굿뜨
#
# ----- 001001007 27번째 의류 -----
# 상품명: FACADE PATTERN
# 평점: 5
# 리뷰수: 21
# 리뷰1: 좋아요 배송 빠르고 좋아요 맘에들어요좋아요 배송 빠르고 좋아요맘에들어요 좋아요 배송 빠르고 좋아요 맘에들어요 ㅎㅎ 좋아요 배송빠르고 좋아요 맘에들어요
# 리뷰2: 아 커요 대따 커요
# 고릴라핏 어떤건지 알거같아요
# 근데 전 좋아요
# 다들 남편옷이냐고 물어보지만
# 전 좋아요 ㅋㅋㅋ
# 리뷰3: 매우.매우.큽니다 181남편이 입어보니 팔길이 어깨빼고는 몸통길이와 품은 적당히 맞을 정도에요 ㅎㅎ
# 아무도 제 옷이라고 안보고 남편옷 입었냐고 할 정도 ㅎㅎ
# 근데 진짜 따뜻하고 옷크기에 비해 가벼워요
# 디자인이 원래 그런거겠지만 팔 품만 작았더라면 좋앗을거같네요
#
# ----- 001001007 28번째 의류 -----
# 상품명: YAN13
# 평점: 5
# 리뷰수: 14
# 리뷰1: 팔이 작긴하지만 트렌치형태라 여기 저기 잘 입을 수 있을 것 같아요
# 리뷰2: 샐각보다 가벼워서 올겨울 휘뚜루로 입을수 이ㅛ을것같아요 따뜻해요ㅎㅎ
# 리뷰3: 이런 스타일 사고 싶어 여러 브랜드 보았는데 가격 대비 퀄리티가 우수한 것 같아요. 부담스럽지 않고 편하게 휘뚜루마뚜루 입을 수 있을 것 같습니당~세일 기간 할인된 금액으로 구입해서 더 만족스럽네용
#
# ----- 001001007 29번째 의류 -----
# 상품명: ADIDAS
# 평점: 0
# 리뷰수: 0
# 리뷰1: 댓글 정보 없음
#
# ----- 001001007 30번째 의류 -----
# 상품명: FACADE PATTERN
# 평점: 5
# 리뷰수: 15
# 리뷰1: 크고 벙벙하긴 한데, 예상했던 점이라 괜찮아요.
# 무엇보다 정말 너무너무 따뜻해요.
# 모자까지 쓰면 무적이에요. 잘 입고 있습니다.
# 리뷰2: 한파에도 등뒤로 땀이 흐르게 해주는 판타스틱 구스패딩..
# 여러분 겨울엔 무조건 구스패딩 하세요
# 한 번 입어보면 돈 아깝다는 생각 안들음
# 핏이 여유있게 나와서 평소 엠사이즈 입는 분들 스몰사이즈 사도 충분해요
# 겉감은 방수도 잘되고 은은한 광택있는 베이지컬러라 여기저기 입기 좋아요
# 모자도 별거 아닌데 일반 패딩이랑 모양이 달라서 더 고급러운 너낌
# 패딩이 음청 빵빵해서 좋긴 한데 단점은 꼬마미쉐린이 되어버린 다는 것.. 그리고 소매 모양도 반달모양이라 덩치가 쪼꼼 커보여요 ㅎ
# 리뷰3: 일단 무지 따뜻하긴 합니다. 그런데 뭔가 옷 재질이 퍼석거리는 느낌이라고 해야 되나 약간 한지 같은 그런 느낌이 드네요. 저는 매끈매끈한 소재를 기대하긴 했어서 약간 당황하긴 했지만, 워낙 박음질 퀄리티도 좋고 색상도 기대하던 그대로라 열심히 입어보려 합니다. 단추가 자석인 게 특이하지만 나름대로 편하네요.

# %%
pip install mysql-connector-python pandas
# Out:
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-9.4.0-cp313-cp313-win_amd64.whl.metadata (7.7 kB)
# Requirement already satisfied: pandas in c:\users\pmj96\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\pmj96\anaconda3\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pmj96\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pmj96\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pmj96\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\pmj96\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading mysql_connector_python-9.4.0-cp313-cp313-win_amd64.whl (16.4 MB)
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    -------------- ------------------------- 5.8/16.4 MB 31.0 MB/s eta 0:00:01
#    -------------------------------------- - 15.7/16.4 MB 39.4 MB/s eta 0:00:01
#    ---------------------------------------- 16.4/16.4 MB 37.1 MB/s eta 0:00:00
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from webdriver_manager.chrome import ChromeDriverManager
import time
import mysql.connector


conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="asdf1122"
)
cursor = conn.cursor()

# 데이터베이스 생성
cursor.execute("CREATE DATABASE IF NOT EXISTS wconcept CHARACTER SET utf8mb4 COLLATE utf8mb4_unicode_ci;")
conn.database = "wconcept"

# 테이블 생성 (리뷰 최대 3개 포함)
cursor.execute("""
CREATE TABLE IF NOT EXISTS performances1 (
    id INT AUTO_INCREMENT PRIMARY KEY,
    category VARCHAR(50),
    title VARCHAR(100),
    rate VARCHAR(100),
    review_num VARCHAR(100),
    review1 TEXT,
    review2 TEXT,
    review3 TEXT,
    UNIQUE KEY unique_performance (title, rate, review_num)
) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4;
""")
conn.commit()

# ==============================
# 2. DB 저장 함수
# ==============================
def save_to_db(category, title, rate, review_num, reviews):
    # 리뷰 3개 맞추기 (없으면 "댓글 정보 없음")
    reviews += ["댓글 정보 없음"] * (3 - len(reviews))
    sql = """
    INSERT IGNORE INTO performances1
    (category, title, rate, review_num, review1, review2, review3) 
    VALUES (%s, %s, %s, %s, %s, %s, %s)
    """
    cursor.execute(sql, (category, title, rate, review_num, reviews[0], reviews[1], reviews[2]))
    conn.commit()

# ==============================
# 3. Selenium 설정
# ==============================
service = Service(ChromeDriverManager().install())
options = Options()
options.add_argument("--window-size=1920x1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/139.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")
driver = webdriver.Chrome(service=service, options=options)

# ==============================
# 4. 크롤링
# ==============================
categorys = ["001005","001002","001008"]

for category in categorys:
    url = f"https://display.wconcept.co.kr/category/women/{category}"
    driver.get(url)
    time.sleep(2)

    print(f"------ {category} 크롤링-------")

    idx=0
    while idx <30:
        try:
            buttons = driver.find_elements(By.CSS_SELECTOR,"button.area-img")
            if idx >= len(buttons):
                break
            driver.execute_script("arguments[0].click();",buttons[idx])
            time.sleep(3)

            print(f"\n---- {category} {idx+1}번째 의류")
            try:
                title = driver.find_element(By.CSS_SELECTOR,"h2.brand").text.strip()
            except NoSuchElementException:
                title = "NOTHING"
                
            try:
                rate = driver.find_element(By.CSS_SELECTOR,"p.grade_num").text.strip()
            except NoSuchElementException:
                rate = "0"
                
            try:
                review_num = driver.find_element(By.CSS_SELECTOR,"#reviewCnt1").text.strip()
            except NoSuchElementException:
                review_num = "0"

            try:
                driver.execute_script("window.scrollBy(0,300);")
                time.sleep(1)
                review_button = driver.find_element(By.CSS_SELECTOR,"#detail > li:nth-child(2)")
                review_button.click()
                time.sleep(2)
                review_elements = driver.find_elements(By.CSS_SELECTOR,"p.pdt_review_text")
                reviews = [r.text.strip() for r in review_elements[:3]]

                if not reviews:
                    reviews = ["NO reviews"]
            except NoSuchElementException: 
                reviews = ["NO reviews"]
            print("상품 : ", title)
            print("평점 : ", rate )
            print("리뷰수 : ", review_num )

            for i, review in enumerate(reviews,1):
                print(f"리뷰{i}: ", review)

            driver.back()
            time.sleep(1)

            driver.back()
            time.sleep(2)
            
            driver.execute_script("window.scrollBy(0,200);")
            time.sleep(1)

            idx+= 1
        except StaleElementReferenceException:
            print(f"{idx+1}번째 요소 stale 참조 발생, 재시도")

            time.sleep(1)
            continue


# ==============================
# 5. 종료
# ==============================
driver.quit()
cursor.close()
conn.close()
# Out:
# ------ 001005 크롤링-------
#
# ---- 001005 1번째 의류
# 상품 :  PAUL&ALICE
# 평점 :  5
# 리뷰수 :  76
# 리뷰1:  눈여겨보던 옷인데 할인해서 좋은가격에 산거같아요 일단 흰피부가 아닌데도 어색하지않고 잘 어울려요. 길이는 길다는거 알고 사긴했는데 어우 정말길더라고요ㅎ 일단 수선하지않고 입어보고 불편하다싶으면 수선을 하려구요 팔뚝 살많고 부유방 있는데도 어느정도 커버가 되네요 긴것 빼고는 다 마음에 들어요
# 리뷰2:  아주 맘에 들어요
# 엄마 이모 다 이쁘다고 칭찬ㅋㅋ
# 리뷰3:  원피스 너무 예뻐요
# 핑크색상 완전 러블리하고 원단이 주름져도 그다지 밉지않아
# 편하게 잘 입어질 것 같아요
#
# ---- 001005 2번째 의류
# 상품 :  Amour moier단독
# 평점 :  4.9
# 리뷰수 :  1,474
# 리뷰1:  왜인기가많은지알거같아요
# 어느장소에든잘어울리고
# 좀추워져도자켓이나가디건이랑잘입어질거같아요
# 리뷰2:  구입한지 좀 됐는데 저는 목 부분이 좀 답답해서 잘 안입어지네요
# 베이직한 디자인이라서 유행 타지않고 입어질 것 같음
# 리뷰3:  소재가 부드럽고 좋습니다
# 길이도 적당하고, 편하게 입기도 갖춰입기도 좋은 원피스네요
# 후기가 좋은 이유가 있네요!
#
# ---- 001005 3번째 의류
# 상품 :  slowlolli
# 평점 :  5
# 리뷰수 :  257
# 리뷰1:  이뻐요 ~~하늘하늘한 소재에 시원해 보이고 이븝니다.
# 리뷰2:  시원한 여름에 딱 맞는 원피스였어요. 얇고 가벼운 소재라 땀 차는 느낌도 없고, 피부에 닿는 촉감이 부드러워서 하루 종일 입어도 편했어요. 특히 체형도 보완되는 원피스라 더 마음에 들어용 ㅎㅎ 화이트 컬러라 얼굴 톤이 화사해 보이고, 어디에나 매치하기 좋아요.여름에 데일리룩이나 휴양지룩으로 정말 잘 입을 것 같아요 🤍
# 리뷰3:  상세페이지 사진과 똑같아요! 휴양지 룩으로 좋을 것 같네요
#
# ---- 001005 4번째 의류
# 상품 :  IvanaHelsinki단독
# 평점 :  4.9
# 리뷰수 :  144
# 리뷰1:  사이즈 딱 좋고 뱃살도 완전 코버되고 엄청 날씬해 보입니다.길이는 좀 긴듯하지만 그냥 입어도 될듯하고 너무 맘에 듭니다.
# 리뷰2:  핏도 예쁘고 날씬해보여요 중요한 자리에 입고가기 좋을 것 같아요.
# 리뷰3:  중요한날 입으려고 구매했고 사이즈는 아주 잘맞습니다 ㅋㅋ 큰건 아닌데 적당히 잘 맞아요 베이지인데 크림느낌이 더 강해서 더 이뻐요
#
# ---- 001005 5번째 의류
# 상품 :  ZEROSTREET
# 평점 :  5
# 리뷰수 :  189
# 리뷰1:  너무 길지도 너무 짧지도 않아 좋았어요!
# 소재도 좋구 편하지만 이쁘게 입었습니다 :)
# 리뷰2:  하늘하늘해 보이고 좋아요
# 가을에도 잘 입을 것 같아요
# 리뷰3:  가을에 레이어드 하려고 샀어요
#
# ---- 001005 6번째 의류
# 상품 :  ANGELO BIANCO
# 평점 :  4.9
# 리뷰수 :  141
# 리뷰1:  입으니 훨씬 예뻐요 너무 포멀하다 싶으면 모델컷처럼 가디건과 코디하면 더 예뻐요 만족합니다
# 리뷰2:  이 옷은 정말 핏 자체가 감동이예요~
# 제가 바스트는 있는데 골반은 없는 편인데, 입는순간 골반을 확~살려주면서 허리가 얇아보이는 효과까지 있어요.
# 세상에~~~!! 왜 사람들이 2개씩 사는 줄 알겠어요.
# 저도 너무 예뻐서 블랙 하나 더 사러 왔다가 후기남겨요~
# 이 원피스 꼭 사세요~명품 수준의 고퀄리티입니다.(명품관 근무중~) 라인,소재,디자인,포장 모든게 완벽!
# 리뷰3:  예쁘고 고급스러워요
#
# ---- 001005 7번째 의류
# 상품 :  FLOWOOM
# 평점 :  4.9
# 리뷰수 :  805
# 리뷰1:  안녕하세요 사장님?? 이번에 리본드레스 받았는데 이거 진짜 미쳤어요ㅠㅠㅠ 사장님 왜이렇게 호들갑을(?) 안 떨어주신건가요..??? (제가 대신 떨고 다닐게요..) 왜 이런 옷을 몇 개월씩이나 고민하고 샀는지 고민한 시간이 원망스러울(?)정도에요?? 원래 하체보다 상체가 살집이 있고 어깨가 넓은 체형이라 하체로 시선 분산시키려고(??) 블루밍드레스처럼 미니 원피스 즐겨입고 에이라인으로 퍼지는 원피스 많이 입는 편인데..! 특히나 머메이드라인과 종아리기장의 애매한 기장은 절대절대 기피하는 편인데 이거 뭔가요ㅠㅠ 왜 자동으로 몸매를 만들어주죠..? 저 다이어트 안했는데 왜 자동보정해주져..! 이름 포토샵원피스로 지었어야하는 거 아닝가요ㅠㅠ 최고에요 증말,, 늘 느끼는 거지만 플로움은 허리부터 골반으로 떨어지는 라인이 정말 예쁜 것 같아요 블루밍 드레스 허리라인도 너무 마음에 들었었는데! 울퉁불퉁하거나 꺾이는 부자연스러운 부분없이 매끄럽게 몸매를 보정해주는 라인으로 잘 뽑아내신다구 해야할까,,(그저 칭찬밖에..) 이게 사실 정면에서만 예쁜 옷은 만들기 쉽지만 측면 후면 어디에서봤을 때도 옷의 라인이 예쁘려면 정말 많은 가봉과 샘플을 봐야하는데ㅜㅜㅜ 정말 얼마나 고생하셨을지 옷 하나로 너무너무 잘 보여요 옷 하나하나 세심하게 신경쓰신 게 잘 느껴집니다!그리구 트위드 원단이 쉬운 원단이 아닌데.. 봉제도 너무 깔끔하고!! 돈이 절대로 안 아까워요!!!!! 맞춤옷 같아요ㅠㅠ 늘 느끼지만 택부터 패키지, 부자재, 원단, 실루엣 하나하나 얼마나 많은 애정과 관심으로 챙기시는 지 알것 같아요 덕분에 지금의 플로움이 있는거겠죠..!!!♥?요새 논문준비로 편한옷만 입고 나갈 일이 없어 옷을 전혀 안사다가 고민끝에 사본건데 논문때문에 갑갑했던 기분이 너무 행복해져서 이건 알려야 할 예쁨이다!!!!싶은 맘에 열후기 씁니당
# 아!!!! 그리고 팔 암홀 시접이 바이어스 테잎으로 마감되어 있다니 보고 세세한 작은 부분까지 놓치지 않은 디테일에 한 번 더 기절이요,,
# 그리구 사이즈 작게 나오셨다고 하는데, 저는 플로움 평소에 스몰 입으면 허리부분은 낙낙하고 바스트는 따악 맞는 편이고, xs입으면 바스트는 작고 대신 허리는 잘 맞는 편인데
# 이 드레스는 스몰 예쁘게 맞았어요! 바스트가 약간 타이트하긴 한데, 70c 기준 흉통은 불편함없이 잘 맞아요. (캡 거의 없는 브라렛 착용하고 입었어요) 네크라인이 맞춤복처럼 들뜸없이 잘 맞아서 더 큰 사이즈하면 덜 예쁠 거같아 딱맞게 입으시는 것 추천! 허리가 여유있긴 한데, 머메이드 라인이라 앉았을 때랑 활동할 때 감안하면 오히려 좋은 것 같아요~
# 리뷰2:  완전 급하게 다이어트해서 들어감 일단 들어감
# 몸매보정 싹 되고 다들 살빠졌다고 해줌
# 벗 팔뚝은 어쩔 수 없읍니다 상비지만 팔뚝 포기하고 다 이쁘게 입었어요 허하하
# 가슴 사이즈 좀 크신 분들 저랑 체격비슷하시면 누브리착용하면 지퍼 잘 올라갈것입니다
# 브라착용하니 안 올라갔거든요 하핫 살 좀만 더 빼면 이쁘게 잘 입을 것 같아요 옷 자체는 넘이뻐서 후회없음!
# 리뷰3:  후기보고 흉통 작게 나왔대서 S했다가 등이며 가슴,어깨, 흉통 모두 너어무 커서 화들짝 놀라고 XS 급히 시켰어요. 원래 흉통 작으셨던 분들은 고민말고 XS 사이즈 하시는 게 맞습니다.
# 옷은 너무 예쁘고 맞춤옷이냐는 소리 진짜 많이 들었네요! 검은색도 사고 싶어요 ㅎㅎ
#
# ---- 001005 8번째 의류
# 상품 :  HAE BY HAEKIM
# 평점 :  4.9
# 리뷰수 :  42
# 리뷰1:  그레이에이어...블랙도 구매했어요
# 시원하고.가볍고.편하고...
# 근데 너무이쁘고!!!!!!
# 가격착하고!!!!!!!!!
# 리뷰2:  몸뚱아리가되지 옷이야 이뻐요
# 날씬언니들이 이쁠듯하네요
# 아줌마는 팔뚝도그렇구 배도그렇구 힘줘야할곳이 많은옷인거깉네요
# 리뷰3:  입었을때 날씬해보여요. 신축성이 있어서 77사이즈까지 입을수 있을것같아요.
#
# ---- 001005 9번째 의류
# 상품 :  BAU by Bride And You단독
# 평점 :  4.8
# 리뷰수 :  19
# 리뷰1:  BAU 제품은 정상가로 구매하기엔 조금 가격대가 있지만
# 재고 있을 때 사야되기 때문에!!! 핏이 너무 예쁘기에!!!
# 텅장이 될지라도 일단 품습니다ㅠ
# 리뷰2:  동생 결혼식때 입으려고 삿어요.
# 힙 부분이 아주 아슬하게 여유가 있어서, 강제 바른자세 룩입니다ㅋㅋㅋ
# 신발은 이것저것 매치해보니,
# 룩북처럼 슬링백이나 아예 샌들처럼 오픈이 많은 신발을 신는게 잘 어울리더라구요.
# 고상하니, 얌전한 언니룩으로 좋은거 같아요
# 리뷰3:  실제로 보는 게 훨씬 예뻐요 옷 자체에 라인이 들어가있어서 옷이 타이트하지 않아도 선이 예뻐보여요 시스루이지만 그렇게 튀지 않고 자연스러워요
#
# ---- 001005 10번째 의류
# 상품 :  DEHEVE
# 평점 :  4.9
# 리뷰수 :  69
# 리뷰1:  기대보다 너무좋은 착상감
# 길이가 길어서 좋아요
# 원단도시원하고 핏도 이뻐요
# 리뷰2:  시원해서 좋아요
# 리뷰3:  옷이 길고 엄청 편하게 나온 디자인입니다. 엄청 날씬해보이는 스타일은 아니지만 속에 이너 걱정없이 입을 수 있어 잘 입어볼 생각입니다.
#
# ---- 001005 11번째 의류
# 상품 :  BAU by Bride And You단독
# 평점 :  4.9
# 리뷰수 :  368
# 리뷰1:  약간 노란가 싶긴한데, 색 고급지고 이쁘네요
# 디자인 괜찮고 돈값하긴해요.
# 근데 비싸기도 함..
# 할인할때 잘샀어요
# 리뷰2:  다들 이쁘다고 하네요.
# 편하고 시원합니다.
# 리뷰3:  여리여리 공주로 만들어주는 옷이랍니다~근데
# 리본이 넘 잘 풀려요 ㅋ
#
# ---- 001005 12번째 의류
# 상품 :  HAE BY HAEKIM
# 평점 :  4.9
# 리뷰수 :  45
# 리뷰1:  164기준 길이감이 꽤 긴 편입니다. 허리부분이랑 복부부분이 붙는 디자인이라 감안해서 구매하는게 좋을듯 싶습니다. 플리츠와 소재와 색상이 고급스럽습니다. 키크고 날씬 하신 분들한테 너무 잘어울릴 원피스입니다. 추천드려요~
# 리뷰2:  넘 이쁩니다 요즘 제일 잘입어요 ㅋㅋ
# 리뷰3:  넘 이쁩니다 요즘 제일 잘 입어요ㅋㅋㅋ
#
# ---- 001005 13번째 의류
# 상품 :  FLOWOOM
# 평점 :  4.9
# 리뷰수 :  152
# 리뷰1:  55에서 66으로 넘어가는 중으로 평소보다 벌크업 상태인지라, 상품평보고 쫄아서 라지하려했는데 품절이더군요.
# 작으면 아쉬워도 반품하자 했는데 이게 왠걸~ M 편하면서도 예쁘게 라인 나옵니다.^^ 적당한 여유가 되려 넘넘 좋아요
#
# 원래보다 살 찌신분들...일단 쫄지말고 한사쥬만 크게 주문하시길요. 소재가 매우 탄탄하여 다른컬러도 추가주문하려 합니다.^^
# 리뷰2:  천도톰하고 동생결혼식에 입었는데 딱좋았어요 하체보다 상체 통통족이라 상체가 딱맞긴해요
# 리뷰3:  핏도 예쁘고 단정해서 2부 드레스로 괜찮을것같아요!!
# 강추합니당
#
# ---- 001005 14번째 의류
# 상품 :  FLOWOOM
# 평점 :  4.9
# 리뷰수 :  50
# 리뷰1:  이거 진쨔 존예탱탱 친구하객룩으로 입었는데 너무 만족스러워서 남편이랑 기념일 사진까지 찍엇어요 가슴부분만 조금 타이트했고 이외 다른 부분은 편하게 잘맞았습니다 비슷한 스펙을 가진 후기보고 xs할까햇는데 전체적으로 타이트할까봐 s로 주문했어요 가슴쪽 타이트함을 느끼고 s로 주문하길 다행이엇어요 진짜 이원피스는 길이길이 잘입을거같아요 쨩
# 리뷰2:  딱 핏되는 느낌은 아니지만 그런대로 수선없이 입을 수 있을 것 같아요
# 체구가 조금만 더 크면 더 예쁘게 입을 수 있을것 같아요
# 리뷰3:  가격이 비싸서 조금 망설였는데, 직접 입어보니 너무 맘에들어서 후기 쓰러 왔습니다
#
# 우선 제 체형에 xs랑 s중 진짜 고민 많이 했는데, 어느분이 체구 작은분은 xs시키라고 하셨던거같아서 주문했고 입어보니 딱 맞아요! 기장은 허벅지 중간쯤오고 상체가 핏하게 붙어서 날씬해보여서 좋아요
# 다만 겨드랑이부분이 좀 많이 파여있어서 신경이 좀 쓰이긴합니당...
# 소재도 좋고 마감도 깔끔한편이고, 남편도 보자마자 이쁘다고해서 맘에듭니당
#
# 이번주 주말 결혼식에 입을거라 배송문의드렸는데, 친절하게 응답해주시고 배송도 주말이후 바로 보내주셔서 주말전에 늦지않게 받았습니다 처음알게된 브랜드인데 전반적으로 맘에들어용!!
#
# ---- 001005 15번째 의류
# 상품 :  BAU by Bride And You단독
# 평점 :  4.9
# 리뷰수 :  36
# 리뷰1:  디자인이 정말 예뻐요. 색상이 티파니블루여서 선택했는데 역시 그대로네요. 고급스럽게 예쁩니다.
# 리뷰2:  제가 블랙을 주문했는데 네이비가 왔네요 ㅠㅠ
# 바로 교환을 해야했는데
# 그냥 네이비도 나름 괜찮아서 그냥 입기로했어요.
# 옷자체는 예뻐요 .
# 리뷰3:  옷 고급스럽고 이뻐요! 중요한 자리에 입기 딱이에요 ~ 스판끼없이 굉장히 불편한 옷이긴 하지만ㅠㅜ 감안하고 입으랴구요!
#
# ---- 001005 16번째 의류
# 상품 :  GRACE U
# 평점 :  4.9
# 리뷰수 :  146
# 리뷰1:  해외 스냅 사진 촬영용으로 샀어요. 촬영은 나름 잘 마쳤고.
# 넥 라인이 정말 예뻐요. 그런데 목 뒤에 묶는 끈이 원피스 소재랑 같은 거고 길이가 상당히 길어서 굉장히 무겁습니다.
# 안 묶으면 누가 뒤에서 목을 잡아 당기고 있는 것 같아요. 묶으면 그래도 걸어다닐만 해요.
# 길이는 160인데 7-8센티 굽 신으면 딱 바닥에 안 끌릴 정도에요. 수선은 안 했습니다.
# 지퍼 저도 처음에 너무 힘들었고 위치가 위에서 한손으로 잡아당길 수도 없는 곳에 있어서 혼자 입고 벗기는 힘들어요.. 출장 헤메쌤한테 부탁했습니다 ㅋㅋ 진짜 다 좋은데 어떻게 지퍼를 이렇게 만드셨지..? 사람 몸이 안에 들어가 있는 상태라는걸 생각 안 하신거 같아요. 벗은 상태에서 그냥 열었다 닫았다는 되거든요 ㅋㅋ 지퍼 양쪽이 11자로 나란히 서 있어야만 잠김.. 근데 사람 몸이 그렇지 않쥬? ㅎㅎ
# 사실 평소에 입기는 좀 어렵고, 재고 가격 방어가 잘 된다고 해서 샀는데, 가슴부분 올이 살짝 튿어져서 재판매도 어려울 것 같고 곤란하네요 ㅠㅠ
# 리뷰2:  기장이 생각했던것보다 길지만 옷자체는 너무 이쁘네요.
# 리뷰3:  164기준 7센치 구두 신고 딱 안끌려요.
# 기장은 확실히 기네요.
#
# ---- 001005 17번째 의류
# 상품 :  FLOWOOM
# 평점 :  4.9
# 리뷰수 :  697
# 리뷰1:  플로움 뉴비입니다! 이 옷은 이너로 뭘 입느냐에 따라 느낌이 확확 다르고 새로운 옷을 입는 것 같은 재미가 있네요. 소재도 기대했던 것보다 고급스러워요!
# 사이즈 고민을 몇주동안이나 하느라 내 흉통이 큰지 작은지 생전 처음 생각해보고, 너무 머리가 아파서 걍 사지말까 했었는데 사길 잘한 것 같아요!!
# 평소 55사이즈(마른55지만 44는 어깨안맞음)이고 로만 홀리데이 원피스가 숨을 크게 쉬지 않는 것을 권한다고 할 정도로 🤣 흉통 작게 나온 걸로 악명(?)이 높아서 S사고 싶었었는데 가슴부분이 뜬다는 얘기때문에 마지막까지 정말 고민이 많았어요. 결론적으로 가슴뜨는 옷 정말 싫고 수선은 더 귀찮아서 XS선택했는데, 신의 한 수 였고 정말 맘에 들어요.
# 단독으로 입으면 여유있게 맞고 이너를 입으면 불편함없이 핏되게 맞아요. 숨쉬기 불편하거나 그런거 없고 밥을 많이 먹어도 배는 풍성한 자유구간에 있어서 흉통은 괜찮을 것 같습니다ㅎ
# 후기를 길게 적는 편이 아닌데 사이즈 고민을 인생극장마냥 심각하게 했어서 도움이 되고 싶어 길게 적어보았습니다🙂
# 신체가 제 스펙이랑 비슷하신분들 중에 핏되는 옷을 좋아하시는 분들은 XS을 추천드려요:)
# 리뷰2:  고급진데 좀 작은 느낌이어서 힘주고 입어요
# 리뷰3:  코디대로 주문했는데 단정하면서도 귀여운 느낌이라 만족해요 >< 고민하던 시간이 아까울따름!!! 잘입을게요!!!
#
# ---- 001005 18번째 의류
# 상품 :  FRONTROW단독
# 평점 :  4.8
# 리뷰수 :  43
# 리뷰1:  샤랄라 시원한 소재 좋습니다. 추천해용!!
# 리뷰2:  세일할때 잘 산거같아여!!
# 160에 50이고, 허리얇고(26) 승마살부터 하체가 통통한 스타일인데, s사이즈하면 편안하고 이쁜핏으로 가능가능!!
# 제키에 총기장 110이 딱 이쁜거같네요 ㅎㅎ
# 다만 제가 키작녀라 허리선이 조금만 더 올라갔다면 싶긴해요!
#
# 구김안갈거같고 착용감 안덥고 너무 좋아여!!!!
# 리뷰3:  옷은 너무 마음에 들어요! 마감도 잘 되어 있고 적당히 촤르르 떨어지는 소재라 부해보이지 않고 날씬해 보여요!
# 근데 택배 상태가 최악이였어요.. 이런 상태의 택배는 처음 받아봐서 처음에 제 택배가 아닌줄 알았어요
# 업체에서 개선이 되는 부분이라면 꼭 개선 해야할 것 같아요~
#
# ---- 001005 19번째 의류
# 상품 :  BAU by Bride And You단독
# 평점 :  5
# 리뷰수 :  121
# 리뷰1:  다른 사람 리뷰처럼 옷이 예쁘네요 치마폭이 넓어서 활동하기에도 좋아요 근데 재질이 많이 두껍네요 반팔인데 9월 말이나 입어야 할 것 같네요
# 리뷰2:  스트레이트 체형은,, 무조건 사시라 이거예요,,
# 개말라인간... 나도 할 수 있을지도,,
# 이거 입으면 예쁘다는 얘기 개마니드름...
# 리뷰3:  백화점 갈 시간은 없고 동생 결혼식에 입으려고 찾아보다 예뻐서 주문했어요. 원래 어깨가 넓은 편이고 살이 쪄서 상의는 66을 입는데, 카라와 어깨라인 부분이 넓은 제 어깨를 커버해주고 치마가 퍼지는 라인이라 숨은 살들을 잘 가려주었습니다. 한여름 결혼식에 입기 약간 두껍지만 어차피 실내에서 있으니 상관없었고, 원단이 고급스러운 느낌이 나서 잘 입었습니다. 여름 결혼식에 종종 입을 것 같아요. 아주 대만족한 상품입니다!^^
#
# ---- 001005 20번째 의류
# 상품 :  BAU by Bride And You단독
# 평점 :  5
# 리뷰수 :  18
# 리뷰1:  여름 트위드라 하나도 안더워요 다만 어깨가 너무 커서 어때 수선 했오요
# 리뷰2:  사이즈가 타이트한 편이구요
# 원피스는 단정하고 고급스러워요
# 리뷰3:  결혼식 피로연복으로 구매했어요~ 비슷한 디자인이 많은데 제일 고급스럽고 예쁜것 같아요
#
# ---- 001005 21번째 의류
# 상품 :  HACIE단독
# 평점 :  4.9
# 리뷰수 :  614
# 리뷰1:  좀 무거워도 좋아요 옆트임이 좀 덜 했음 더 좋았을 것 같아요
# 리뷰2:  길이 때문인지 무게감이 좀 있어요 두께가 살짝 도톰한 편이라 아직 입기는 더울것 같아요 소재는 괜찮아요
# 리뷰3:  편하고요
# 자주 입고 있습니다
# 사고 나서 세일 많이 해서 속상해요
#
# ---- 001005 22번째 의류
# 상품 :  slowlolli
# 평점 :  5
# 리뷰수 :  115
# 리뷰1:  딱 기대했던 색감이에요. 길이도 적당하고 소재도 보들보들 넘나 좋고 남은 여름 정말 잘 입을 거 같아요. 마음에 쏙 듭니다^^
# 리뷰2:  시원하지만 어깨 라인이 과하게 드러나지 않아 부담 없어요!!
# 허리 라인이 살짝 잡혀 있어 길어 보이고,
# 롱 드레스라 편하면서도 우아해 보이는 게 장점이에요ㅋㅋ
# 특히 하늘색 컬러가 피부 톤을 환하게 밝혀줘서 외출할 때 기분까지 좋아집니다
# 바닷가 여행용으로 챙겨갔는데 사진도 잘나와서 좋앗슴당
# 리뷰3:  스카이블루 컬러가 은은하면서도 화사해 여름에 입기 딱이에요
# 롱 기장이라 체형 커버도 자연스럽고,
# 단정하면서도 고급스러운 분위기가 나요
# 소재가 시원하고 가벼워서 더운 날씨에도 답답하지 않고, 린넨 느낌처럼 바람이 솔솔 통해서 하루 종일 편하게 입을 수 있습니당
#
# ---- 001005 23번째 의류
# 상품 :  IT MICHAA
# 평점 :  4.9
# 리뷰수 :  31
# 리뷰1:  깔끔하고 단아하고 라인 적당히 괜찮아요 다만 좀 두꺼워서 지금 입긴 더울 듯해요
# 리뷰2:  경조사용으로 정말 딱이에요~ 벨트까지 세트라서 너무 좋아요
# 리뷰3:  결혼식때 너무 예쁘게 잘입엇어요!! 원래 체중보다 날씬하게 만들어주는 것 같아요😊
#
# ---- 001005 24번째 의류
# 상품 :  BAU by Bride And You단독
# 평점 :  4.9
# 리뷰수 :  201
# 리뷰1:  실제로보니 작고 소재와 디자인 대비 비쌉니다 촌스럽고
# 리뷰2:  와이프 입으려고 샀는데 너뮤 이쁘네요! 와이프도 너무 맘에 들어해요!
# 리뷰3:  작아여 여러분 편하게입으려면 넉넉하게 2 사세요 옷은 너무이쁩니다
#
# ---- 001005 25번째 의류
# 상품 :  Lamerei
# 평점 :  4.9
# 리뷰수 :  204
# 리뷰1:  가슴 등이 좀 뜨는것 빼곤 좋아요
# 리뷰2:  8월 결혼식에 입을려고 구매했어요 후기가 아주 좋더라구요 단정하면서 목부분 디자인이 좋네요
# 가격대도 괜찮았어요 잘산거같네요
# 리뷰3:  뱃살 조금이라도 있는 분들은 앉으면 다 티날거에여 ㅠㅠ 엠사이즈 샀는데 몸매좋아보야용 근데 앉으면 뱃살 나와서 슬퍼요 ㅋㅋ 스판 없어요
#
# ---- 001005 26번째 의류
# 상품 :  THECHEMI
# 평점 :  4.9
# 리뷰수 :  30
# 리뷰1:  라인이 잡혀있고 소재가 탄탄해서 단정하게 잘 있었어요, 다만 여름옷으로 보기엔 좀 덥네요,,
# 힙이 작은편이라 아랫쪽은 넉넉해서 편하게 입었어요
# 리뷰2:  너무 예뻐요
# 다른 후기대로 가슴들뜸이 있어요 골반 라인대로 옷이 생겨있어서 골반 좁으신분들은 배쪽 천이 남다보니 옆에서 보면 아랫배가 살짝 튀어나온것처럼보일수있습니드
# 그래도 너무 이쁘고 비싸보이는옷이에요 잘 샀어요
# 리뷰3:  돌잔치때 입으려고 구매했어요~ 길이는제가 키가 작아서 좀 줄여야 할 것 같지만 핏이 예뻐요~ 착용감도 착 감기는느낌이에요!
#
# ---- 001005 27번째 의류
# 상품 :  TOWAV단독
# 평점 :  4.9
# 리뷰수 :  27
# 리뷰1:  돌잔치할때 입었어요!
# 다들 이쁘다고 말씀해주시더라구요!
# 디자인 핏 넘 이쁘고 제가 팔뚝에 살 이 많은편인데
# 예쁘게 가려주더라구요❤️
# 제 몸무게 57정도이구 정말 딱! 맞았습니다!
# 진심으로 추천해요!
# 리뷰2:  엄청 예쁘고 고급진 원피스입니다!! 진짜 사진으로 보는 것보다 실물이 훨씬 예뻐요~~
# 리뷰3:  베이지는 사진보다 어둑하더라구요
# 너어무 성숙 해 보이더이다.
# 가슴 비대칭이 연속 3번이나 있어서 반품.
# 흰 옷이 그나마 대칭이라 품어요.
# 원래 가슴라인 어느정도 비대칭이 잇다 하는데 이 가격에, 브랜드라 하면서 이런 답변은 말이 안 되죠.
# 흰 거는 입고 나가면 반응최고. 조명판 그 자체.
# 가디건 세탁기 돌렷다가 줄어듬...하아...
#
# ---- 001005 28번째 의류
# 상품 :  MOONEED단독
# 평점 :  5
# 리뷰수 :  20
# 리뷰1:  159기준 치마가 좀 많이 길어서 줄일까 고민중~
# 셋트로 잘 어울리고 예뻐요
# 리뷰2:  티셔츠가 많이크지만 힙하게 입기좋음
# 기장이 좀 길어 티셔츠와 스커트 줄일예정임
# 리뷰3:  세트로 구매했는데 넘 마음에 들어요 꾸안꾸로 잘입을게요!
#
# ---- 001005 29번째 의류
# 상품 :  MIND BRIDGE women
# 평점 :  4.9
# 리뷰수 :  165
# 리뷰1:  심플하고 입기도 쉬워서 좋아요! 무난하게 잘 입을 것 같아요!
# 리뷰2:  바스락소재라 시원하고 편안해서 막입기도 좋아요
# 리뷰3:  리뷰가 좋아서 별 기대없이 구매했는데요, 생각보다 괜찮고 꾸안꾸로 예쁘게 입을 수 있어서 좋습니다.
#
# ---- 001005 30번째 의류
# 상품 :  FLOWOOM
# 평점 :  5
# 리뷰수 :  574
# 리뷰1:  좋아요 잘맞어요
# 리뷰2:  정말 너무예쁩니다 ~ 재질도 고급수럽고 하객룩으로 최고에요
# 리뷰3:  격식차린 자리에서 입으려고 샀는데 너무너무너무 예쁘네요... 우아함 고급스러움 끝판왕.. 몸매도 너무 좋아보이고 진짜 예뻐요.. 가격값 하는 옷ㅠㅠ 재질이 좋아서 오래입을수 있을거 같아요 ㅎㅎ
# ------ 001002 크롤링-------
#
# ---- 001002 1번째 의류
# 상품 :  lettera
# 평점 :  4.9
# 리뷰수 :  4,925
# 리뷰1:  아이보리랑 그레이 두 개 주문했어요.
# 밝은 그레이가 잘 안 받는편인데
# 적당히 어두운톤 느낌도 나고
# 길이도 마음에 들어요.
# 여름 살 안 타 템으로 굿
# 리뷰2:  길이가 너무 짧지도 너무 길지도 않아서 좋아요
# 하늘하늘하고 적당히 비치는 게
# 여름에도 잘 입고있습니다.
# 원피스에 특히 잘 어울려요
# 리뷰3:  가디건 깔별로 수집하는 느낌...잘입어서 다른컬러 또 구입하네요
#
# ---- 001002 2번째 의류
# 상품 :  ANGELO BIANCO
# 평점 :  4.9
# 리뷰수 :  911
# 리뷰1:  색깔이 차분해서 좀 더 성숙한 분위기가 나네요~ 소재도 좋고 참 잘 산 것 같아요
# 리뷰2:  작은느낌이잇고
# 기장이짧아요ㅜㅜ
# 그점이아쉽네요ㅜ
# 리뷰3:  생각보다 원단이 두껍고 사이즈도 작습니다
# 한 여름엔 입기 힘들것 같아요
# 초가을 바람부는 여름 끝자락에 입어볼까 합니다
#
# ---- 001002 3번째 의류
# 상품 :  FRONTROW단독
# 평점 :  4.9
# 리뷰수 :  283
# 리뷰1:  비비드한 색감에 반해서 구매했습니다
# 소재 탄탄하고 시권하고 좋어요!!!
# 리뷰2:  한여름엔 좀 더울거 같아요 간절기에 입으면 깔끔할거 같아요 소재가 힘이 있어서 고급져 보이고 마감도 좋아요 예쁘게 입어 볼께요
# 리뷰3:  얇아서 여름에 입기도 좋고
# 피부에 닿는 촉감도 좋아요
# 핏도 예쁘고 대만족입니다
#
# ---- 001002 4번째 의류
# 상품 :  VOIEBIT for WOMEN단독
# 평점 :  4.9
# 리뷰수 :  234
# 리뷰1:  체형에 따라 다르겠지만
# 저한테는 팔뚝이 얇아보이는 것 같아요
# 소재는 살짝 두께감이 있지만
# 오히려 이너 잘 안 챙겨 입어도 티가 잘 안 나서 좋아요
# 리뷰2:  너무 이뻐요 입으니까 더 이쁘네요
# 소재도 시원 할거 같아요 ~!
# 리뷰3:  작을줄은 알았지만 정말작네요 ㅋㅋ
#
# ---- 001002 5번째 의류
# 상품 :  CITTA
# 평점 :  4.9
# 리뷰수 :  864
# 리뷰1:  재질이 찹찹한게 입으니 느낌이 좋아요. 다른 컬러도 추가구매하고 싶어요ㅎㅎ
# 리뷰2:  색상도 이쁘고 편하고 좋아요
# 겨드랑이 부분이 좀 넉넉해서 통통해도 편하게 착용 가능해용
# 리뷰3:  올여름 필수템으로 늘 들고다닙니다.
# 에어컨 바람에 딱 맞는 소재.
# 길이감도 품도 적당합니다
#
# ---- 001002 6번째 의류
# 상품 :  MangoManyPlease
# 평점 :  4.9
# 리뷰수 :  911
# 리뷰1:  여리여리 사람이 이뻐 보입니다 차콜도 구매할까 고민 하고있네요
# 리뷰2:  기본입다가 예뻐서 크롭도 샀어요!
# 컬러오묘해서 맘에 둘어요. 근데 기본이 더 날씬해 보여요 ㅎ 다른컬러도 살까 고민중이예요!
# 리뷰3:  여리여리 하면서 예쁘네요
# 키가 작아서 길이감이 짧은게 더 이쁜거 같아요
# 살짝 더 시원해지면 잘 입고 다닐거 같아요
# 만족합니다
#
# ---- 001002 7번째 의류
# 상품 :  MangoManyPlease
# 평점 :  4.9
# 리뷰수 :  1,462
# 리뷰1:  할인 기간에 구매했는데 부들부들 모달 소재를 이제서야 알게 되다니! 면 소재 보다 훨씬 좋은 거 같아요. 가격대가 좀 있지만 만족합니다.
# 리뷰2:  성글성글한 짜임의 여름 니트입니다
# 일상생활에서 올나감에 주의해야할것 같으나
# 목라인이 여리여리하게 보이고 소매가 길어
# 너무 좋습니다 ㅠㅠ
# 리뷰3:  제품이 아주 마음에 듭니다.
#
# ---- 001002 8번째 의류
# 상품 :  leathery
# 평점 :  4.9
# 리뷰수 :  779
# 리뷰1:  여름동안 너무너무 잘 입었어요!! 단독으로 또는 가디건 느낌으로 스커트에도 바지에도 너무 잘 입고 있습니다. 초가을까지 충분히 입을거 같아요!
# 리뷰2:  시원하고. 입기. 편해요
# 리뷰3:  여름에 이너입고 위에 있기 좋아요 그레이컬러 있고 만족해서 라벤더도 쟁였어요
#
# ---- 001002 9번째 의류
# 상품 :  TMAKER
# 평점 :  4.9
# 리뷰수 :  39
# 리뷰1:  두가지 레이어드 해서 입는 재미가 있네요
# 다른컬러도 사고 싶어요
# 리뷰2:  뷔스티에와 가디건 세트라서 주문했어요. 근데 뷔스티에 어깨끈이 없어서 입다보면 내려갈 것 같아요. 가디건만 봐도 이뻐서 괜찮아요. 지금 입기엔 덥겠고 조금 서늘해지면 바로 입어야 겠어요. 마감처리도 깔끔한 편이에요. 데일리로 편하게 입기에 좋아요.
# 리뷰3:  살짝 도톰하고 빳빳한 느낌의 반팔 가디건이에요! 시원하지는 않지만 편하게 입기 좋고, 뷔스티에는 잘 흘러내리는 편이에요
#
# ---- 001002 10번째 의류
# 상품 :  WEDNESDAYOASIS FOR WOMEN
# 평점 :  4.9
# 리뷰수 :  140
# 리뷰1:  아이보리예쁘고 여리여리해요
# 다른색도 사고싶네요
# 가성비 짱입니다
# 리뷰2:  마음에 듭니다 무난하게 입을 수 있고 너무 아이보리 아니라 좋아요
# 리뷰3:  검정색 구매하고 또 사요
# 여름에 에어컨 시원한 곳에서 입으면 덥지도 춥지도 않아요. 건조기 막 돌려도 멀쩡해요
#
# ---- 001002 11번째 의류
# 상품 :  GRACE U
# 평점 :  4.9
# 리뷰수 :  756
# 리뷰1:  세트로 입으면 너무 예쁩니다!! 에어컨 쎈 실내에서 여름에 입기에 정말 좋아요!
# 리뷰2:  이거 진짜 예뻐요 얼굴 화사해보이고 말라보이고 다하는 예쁜 템
# 리뷰3:  나시 구매 후 가디건 구매했는데 구매하길 잘한것같아요. 너무 예쁩니다!! 소매도 예쁘고 구김 잘 가지 않아요
#
# ---- 001002 12번째 의류
# 상품 :  eune단독
# 평점 :  4.9
# 리뷰수 :  132
# 리뷰1:  요 니트는 그야말로 만능니트에요 여기저기 착착착붙이네요
#
# 1. 활용도
# 블랙앤 화이트라 클래식에도 진에도 유색에도 다 잘 어울려요 활용도 면에서 정말 최고인 것 같아요 모든 으네&하이버넷 템이랑 다 코디해보려고 착착 꺼내다가 으네 하의가 너무 많아 실패해버렸지만.. 어지간한 신구으네 모두 다 조화롭게 잘 붙네요
#
# 미니랑 입으면 약간 귀여운 느낌이 나고 정장 슬랙스랑 입으면 바로 오피스룩이 되는데 진을 매치하면 또 금방 나들이룩이 되어버려요 여름에 즐겨입던 민소매 원피스랑 같이 입기에도 좋아서 활용도가 넘나 굿굿입니다!! 기본템이지만 블랙 라이닝 배색이 있어 킥이 되고 또 묘하게 여성스러운 느낌이 있어서 그야말로 착붙템!
#
# 2. 사이즈
# 정 66입으시는 분들한테는 약간 크롭느낌 있어요 그치만 과하지 않고 오피스룩으로도 매치 가능할 정도라 부담스럽지는 않습니다!
#
# 3. 착용감
# 피부 간지러운 걸 싫어하고 한 겨울에도 목티를 못입으며 스카프도 답답해서 하지 못하는 타입인데 딱 쇄골까지만 덮고 그 위로 올라오지 않아 목 답답함 없구요 소재도 부드러워서 간지러움 전혀 없어요 진짜 니트 안 입는 타입이고 부드럽다고 광고하는 소재들도 까스럽게 느꼈는데 이건 정말 면티 같은 느낌이에요 간지럼부자분들께도 추천!
#
# 4. 슬픈 사연
# 배송 받자마자 뜯고픈 마음 꾹꾹 눌러담고 제주도에 가서 개시했는데 짐을 풀던 남편이 그대로 세탁과 건조를 시켜버려 한번 입고 약간 줄어든(그래서 조오금 더 크롭같은 느낌이 들어버린) 슬픈 아이인데요..ㅠㅠㅠ
# 많이 줄지는 않았어요 첨부한 착용샷들도 모두 건조기 들어간 후의 모습입니다....;ㅁ; 그러니 실수로 한두번 정도는 건조기를 돌리게 되더라도 입으실 수 있을 거라는 하지만 가급적 그런 실수는 하시지 마시라는 말씀을 함께 남겨드려요 엉엉
# 리뷰2:  니트를 즐겨 입어요
# 디자인은 비슷 소재 다르게
# 소재 다르게 디자인 비슷하게
# 입으면 예쁜 니트네요
# 검은색 사고 색깔별로 또 주문했어요
# 너무 맘에 듬.
# 리뷰3:  사이즈 적당하고 이뻐요
#
# ---- 001002 13번째 의류
# 상품 :  Amour moier단독
# 평점 :  4.9
# 리뷰수 :  1,399
# 리뷰1:  우아하고 편하고 좋아요! 추천합니다.
# 리뷰2:  아직 입어보진않았지먼
# 사진그대로의 소재감과 컬러네요
# 브라운이나 베이지 계열 슬랙스에도 어울릴거같고
# 화이트진에도 잘어울릴 것 같아요
# 출근룩으로 손이 자주갈 듯?
# 리뷰3:  후들후들한 소재라서 마음에 들어요
# 세일해서 저렴하게 구매했습니다
#
# ---- 001002 14번째 의류
# 상품 :  MURMURE단독
# 평점 :  4.8
# 리뷰수 :  117
# 리뷰1:  소개 특이하고 너무너무 예뻐여
# 리뷰2:  생각보다 가격대비 별로예요
# 기장도 많이 짧아요
# 리뷰3:  얇고 하늘하늘한 가디건 나시 드레스에 아주 잘어울려서 이뻤어요!@@
#
# ---- 001002 15번째 의류
# 상품 :  LOVLOV
# 평점 :  5
# 리뷰수 :  1,651
# 리뷰1:  와 이가디건 진짜 대박이에요..👍🏻👍🏻
# 쫀쫀하면서 촉감도 좋고~!! 색감도 너무 맘에듭니다~!!
# 기본 가디건으로 정말 최고!! 계속 여름이라 가디건 입을날이 짧아서 너무 아쉽지만~~ 간절기아이템으로도 좋을거구 나중에 코트안 레이어드용으로도 손색없을듯 해요~ 좋은 가격에 정말 굳퀄리티 가디건🙂
# 리뷰2:  받아보고 생각보다 소재가 좋아 놀랐어요
# 광택도 약간 있으면서 보들보들하고 두께감도 컬러도 사이즈도 원하던대로였어요
# 찬바람 불기 시작하면 바로 꺼내입으려고 기대중입니다
# 리뷰3:  소재는 흐물거리지 않고 탄탄하고 두께감 있어서 꽤 따뜻하게 입을 수 있을거 같아요. 몸통은 적당한 폼인데 팔부분은 여유가 꽤있어서 날씬해 보이진 않더라구요. 그치만 그만큼 여유가 있어서 안에 껴입을 수 있을거 같아요.
#
# ---- 001002 16번째 의류
# 상품 :  ouie단독
# 평점 :  5
# 리뷰수 :  149
# 리뷰1:  바지에 넣어입으면 따끔따끔해요
# 부유방 잘 가려줘요
# 겉에 얇은 시스루 흰 셔츠입으면 여뤼여뤼
# 리뷰2:  엄청 얇은데 엄청 부드러워요 땀자국 남지 않을 소재 같음 길이도 길지 않아서 맘에 듦
# 리뷰3:  소재가 상당히 좋습니다. 디자인도 너무 좋고 가슴도 많이 파이지 않고 부담스럽지 않고 너무 만족합니다. 다른 컬러로 또 구입하고 싶어요. 완전 만족합니다.
#
# ---- 001002 17번째 의류
# 상품 :  MEMUA
# 평점 :  4.9
# 리뷰수 :  10
# 리뷰1:  소재아주좋습니다 깔별로 구입
# 길이도좋고 소재가 얇아 오래못입을까봐 걱정 ㅋㅋ
# 리뷰2:  소재아주좋습니다 깔별로 구입
# 길이도좋고 소재가 얇아 오래못입을까봐 걱정 ㅋㅋ
# 리뷰3:  소매가 길어서 너무 좋네요 ㅎ 요즘 크롭이 너무 많이 나오는데, 기장도 적당해 넘 맘에 들어요
#
# ---- 001002 18번째 의류
# 상품 :  ADIDAS
# 평점 :  4.9
# 리뷰수 :  91
# 리뷰1:  엄청 싸게 샀어요
# 리뷰2:  저렴한 가격에 잘샀습니다. 실밥 마감이 이태리 장인 뺨때리는 퀄리티에요.
# 리뷰3:  약간의 섬유 냄새가 나긴 하는데 예쁩니다. 가을에 예쁘게 입을 수 있을 것 같아요. 크롭한 기장일 줄 알았는게 의외로 넉넉해요!
#
# ---- 001002 19번째 의류
# 상품 :  GRACE U
# 평점 :  4.9
# 리뷰수 :  836
# 리뷰1:  세트로 입으면 너무 예쁩니다! 뜨지 않고 몸에 잘 붙어서 편해요
# 리뷰2:  이거 진짜 예뻐요 얼굴 화사해보이고 말라보이고 다하는 예쁜 템
# 리뷰3:  저에게 조금 딱맞는 사이즈였어요. 바스트가 크신분들은 출근룩으로는 어려울수도...! 사진상으로 좀 부하게 나오기도해서 사진찍기어렵고 셔링잡기 까다롭지만, 그래도 입으면 예쁜옷이에요. 소재가 은근 두꺼워서 한여름보단 초가을 더울때입으면 좋을거같아요.
#
# ---- 001002 20번째 의류
# 상품 :  VOIEBIT for WOMEN단독
# 평점 :  4.9
# 리뷰수 :  514
# 리뷰1:  브라운 느낌보다는 약간 카키 컬러에 가까운느낌이에요 아직 날이 더워서 입을 수는 없지만 세일하길래 후다닥 주문했어요 가을되면 잘 입고 다닐거 같아요
# 리뷰2:  굳
# 리뷰3:  예뻐요 잘 입을게용
#
# ---- 001002 21번째 의류
# 상품 :  The Raust단독
# 평점 :  4.8
# 리뷰수 :  132
# 리뷰1:  후기에 많이 루즈하진 않다고해서 딱 맞을까봐 걱정했는데 적당하게 루즈해서 두루 잘 입을거같아요 기장이 짧은편인데 저는 키가 작아서 저한텐 잘 맞네요 좀 까슬거리긴하지만 많이 거슬릴것같진 않아요
# 리뷰2:  생각보다 얇은 소재에요. 까슬거리는 느낌이 강해서 맨살에 입기는 힘들어요.
# 리뷰3:  실물이랑 같아요! 너무 잘입는중
#
# ---- 001002 22번째 의류
# 상품 :  EVMOIU
# 평점 :  5
# 리뷰수 :  165
# 리뷰1:  깔끔하고 편하게 입기 좋아요
# 착용감도 편하고 회사갈때 입기 좋을것 같아요
# 리뷰2:  이뻐요
# 리뷰3:  생각했던거보다 타이트해서 놀랐네요 ㅠ
# 근데 소재, 색, 디자인은 고급스럽고 예쁩니다.
# 가슴 부분이 너무 붙어서... 가슴 있는분들은 쫌 부담스러울수도 있어요.
#
# ---- 001002 23번째 의류
# 상품 :  FRONTROW단독
# 평점 :  4.8
# 리뷰수 :  167
# 리뷰1:  이쁜데 좀 가격에 비해서는 비싸네영 세일해두!
# 리뷰2:  진짜 이뻐요 고급지네요 청바지 세미정장 다 잘어울려요
# 리뷰3:  촘촘한 그물에 비침이 심하지 않고 얇고 시원해요!
# 한쪽만 허리 선 절개되어 있는 점도 마음에 들어요
#
# ---- 001002 24번째 의류
# 상품 :  JMARK New York
# 평점 :  4.9
# 리뷰수 :  57
# 리뷰1:  뭔가 핏이 아쉬워요. 컬러는 예뻐요
# 리뷰2:  아주 얇은 여름 긴팔이고, 생각보다 팔뚝부분이 딱맞아서 암홀이 불편하긴합니다.!
# 리뷰3:  엄청 얇진않지만 그래도 살안타템으로 너무 좋을것같네요
#
# ---- 001002 25번째 의류
# 상품 :  Dunst for WOMEN
# 평점 :  5
# 리뷰수 :  3
# 리뷰1:  제가 딱 너무 좋아하는 컬러라 구매했습니다ㅎㅎ 핏도 완전 정핏이라 오피스룩으로 입기 좋을것 같아요!! 색감이 존예입니다,,ㅎㅎ
# 리뷰2:  보자마자 가을에 입으면 예쁠것 같아 주문했습니다.
# 색은 사진 과 비슷해요,,!! 다음달엔 가디건도 주문해야겤ㅅ습니다
# 리뷰3:  봄웜라 인간이지만 색이 너무 예뻐서 홀린듯이 구매했습니다ㅠㅋㅋ 가을웜톤에 가까운 올리브색인거같은데 너무 분위기있게 잘나왔어요 색상이! 55,66 걸쳐입는데 M사이즈 적당히 여유있게 잘 맞습니다
#
# ---- 001002 26번째 의류
# 상품 :  RE_L
# 평점 :  4.9
# 리뷰수 :  1,017
# 리뷰1:  올 여름 중 가장 잘산템 중 하나입니다. 에어컨바람 나오는 실내에서는 이 가디건을 입으면 오히려 더 춥기까지해요ㅋㅋㅋ 촉감도 고슬고슬하고 핏도 마음에 들어서 검정색 하나 더 쟁이려고요
# 리뷰2:  하늘색 사고 핏이 너무 예뻐서 재구매 했어요 역시 만족스럽네요
# 리뷰3:  후기보고 M했는데도 팔이 붙어서 날씬핏이 안나오네요 ㅠㅠ
# 그래서 좀 아쉽네요
#
# ---- 001002 27번째 의류
# 상품 :  Atelier Nain
# 평점 :  4.9
# 리뷰수 :  385
# 리뷰1:  디자인 흔치않고 엄청 날씬해보여요! 소재도 여름용 시원한 니트소재라 달라붙지도않고 하나도 안덥습니당
# 리뷰2:  엄청 시원하고 가벼운 소재라서 여름 내내 입기 너무 좋았어요. 디자인도 마음에 듭니다
# 리뷰3:  예뻐요!!
#
# ---- 001002 28번째 의류
# 상품 :  WOOALONG
# 평점 :  5
# 리뷰수 :  10
# 리뷰1:  유니크 하니 넘 예뻐요!!
# 리뷰2:  밑에 마감이 포인트로 잘 입을거같아서 구매했어요~ 다만 소재가 까슬거려서 안에 이너를 꼭 입어야할거같아요!
# 리뷰3:  까슬거리고 털 빠지는 재질이에요 핏되게 입으려면 s사이즈 사야 될 거 같아요
#
# ---- 001002 29번째 의류
# 상품 :  RE_L
# 평점 :  4.9
# 리뷰수 :  1,435
# 리뷰1:  너무 예쁘고 얇아서 그닥 안더워 괜찮습니다
# 근데 너무 약해서
# 옆사람이랑 살짝만 긁혀도 올이 나가서
# 조심해서입어야할듯
# 리뷰2:  핏을 여리여리하게 잡아주고 입었을 때 예뻐요. 팔 소매 부분이 좀 늘어나는게 흠이지만 잘 입고있어요
# 리뷰3:  몸에 착 감기고 왜 인기템인지 알겠네요 간절기까지 잘 활용할거같아요 되게 여성스러워보여요
#
# ---- 001002 30번째 의류
# 상품 :  ANEDIT단독
# 평점 :  4.9
# 리뷰수 :  165
# 리뷰1:  저 끈이 좀 불안불안해여 그리고 저한텐 조금 길어서 울어여ㅜ 그거 빼곤 무난하면서도 갠춘
# 리뷰2:  되게 여리여리하고 예쁜 니트 입니다
# 통풍이 잘 돼서 여름에 입기에도 좋은 것 같아요!
# 리뷰3:  좋아요
# ------ 001008 크롤링-------
#
# ---- 001008 1번째 의류
# 상품 :  INSTANTFUNK
# 평점 :  5
# 리뷰수 :  124
# 리뷰1:  와 바지맛집 맞네요 핏이이뻐요 부츠컷에 스판끼까지~! 최고
# 리뷰2:  바지는 진짜 핏이 예뻐요 근데 살면서 바지 처음 줄여봐요.. 크기는 겁나 깁니다
# 리뷰3:  소재도 부드럽고 핏도 이뻐요
# 뱃살부자라 허리 여유있어서 좋고 검정도 구매하고싶어요
#
# ---- 001008 2번째 의류
# 상품 :  MangoManyPlease
# 평점 :  0
# 리뷰수 :  0
# 리뷰1:  NO reviews
#
# ---- 001008 3번째 의류
# 상품 :  ouie단독
# 평점 :  5
# 리뷰수 :  115
# 리뷰1:  와 이 바지 진짜 예쁩니다 기장 수선은 해야하지만 너무너무 예쁘네요 강추
# 리뷰2:  입을일이 없어 한 여름에 입진 못했지만 내년에 잘 입을게요^^
# 리뷰3:  최고 바지입니다. 소재는 진인데 얇고 사이즈 넉넉하고
# 다리 길어보여요.
#
# ---- 001008 4번째 의류
# 상품 :  MaLoupe
# 평점 :  4.9
# 리뷰수 :  1,234
# 리뷰1:  사이즈 고민하다가 여름이니까 28로 했는데 매우 만족스럽습니다. 넉넉하니 잘 맞아요. 26은 딱 맞을것같아요. 핏 마음에 들고 저는 한여름에도 잘 입어지더라구요. 여름 교복이 되었습니닷
# 리뷰2:  바지가 다른 인터넷 사이트에서파는 저렴한 느낌이 아니고 탄탄하고 모양 잘 잡히는 만듦새가 꽤 좋은 바지입니다. 세일가로 4만원후반인가 5만원초반에 산거같구요. 제가 키가 크고 다리가 길고 골반이랑 엉덩이가 있는데 제 체형에 아주 잘 맞습니다.
# 요즘 와이드핏이 유행하는데 저는 키도 크고 골반 엉덩이도 있어서 와이드를 입으면 너무 거인같고 안예뻤는데 요바지는 딱 적당한 세미와이드에요.
# 소재는 한여름엔 불가(한여름엔 반바지나 원피스만 입습니다)하고 초여름이나 늦여름 봄 가을 잘 입을 수 있을 것 같아요.
# 제 체형에 잘 맞는 바지가 없는데 정말 너무 예쁘게 잘맞아서 그레이도 주문했습니다.
# 리뷰3:  바지 허리쪽이 제 체형에는 좀 안어울리네요ㅠ
# 키가 작아서 밑단은 줄여서 입었어요
#
# ---- 001008 5번째 의류
# 상품 :  ouie단독
# 평점 :  4.9
# 리뷰수 :  41
# 리뷰1:  시원하니 이쁩니당 배송도 생각보다 빨랐어요 우이 바지 벌써 세개째!
# 리뷰2:  길이는 엄청기네요..저는 8센치는 줄여야 할거 같아요..두께는 얇아서 겨울만빼고는 따뜻한 봄과 여름 시원한 가을까정 두루 두루 잘입믈거 같구요..
# 리뷰3:  소재가 진짜 얇고 시원해요 편하게 잘 입고 있습니다
#
# ---- 001008 6번째 의류
# 상품 :  emkm
# 평점 :  4.9
# 리뷰수 :  491
# 리뷰1:  고급스러운 화이트 느낌이예요
# 여름에도 무난하고 촉감이 부드러워 참 좋습니다
# 리뷰2:  길이가 길어서 수선집 필수지만 핏이 예쁩니다!!¨̮
# 리뷰3:  디자인이 깔끔해서 마음에 들어요
#
# ---- 001008 7번째 의류
# 상품 :  TILLIDIE
# 평점 :  4.9
# 리뷰수 :  434
# 리뷰1:  허리는 약간 가는편임데 허리사이즈 적당히 잚 맞고 길이나 품도 좋습니다
# 리뷰2:  편하게 잘입을거같아요
# 리뷰3:  편하고
# 다리가 날씬해 보여요
#
# ---- 001008 8번째 의류
# 상품 :  FACADE PATTERN
# 평점 :  4.9
# 리뷰수 :  19
# 리뷰1:  편하고 예쁘네요
# 리뷰2:  오랜 고민하던끝에 주문햇어요~ 지난번에 주문핶다가 배송 넘 오래걸리길래 취소했었는데 아무래도 핏이 예뻐서 재주문! 이번엔 배송 빠르네요. 소재감,컬러,핏 맘에들어요
# 리뷰3:  출산 후 배 아직 안들어갔는데 사이즈 잘 맞고 심지어 단점보완 잘해주는 팬츠네요. 넘 이뻐요. 이염가능성 있을수있으니 세탁 주의하려구요. 역시는 역시 파사드패턴 바지❤️
#
# ---- 001008 9번째 의류
# 상품 :  UMER
# 평점 :  4.9
# 리뷰수 :  1,408
# 리뷰1:  예쁘고 편해요. 골반 허리 엉덩이 다 잘 맞고 길이만 줄이면 될 것 같아요. 색도 마음에 들고 입었을 때 느낌이 편하고 좋고 핏도 예뻐요
# 리뷰2:  핏이 진짜 예뻐요
# 적당히 와이드 하고 기장도 좋네요
# 리뷰3:  묵직하니 핏이 좋네요
#
# ---- 001008 10번째 의류
# 상품 :  L’oiE단독
# 평점 :  4.9
# 리뷰수 :  55
# 리뷰1:  약간 A라인이네요 나름 만족합니다
# 리뷰2:  여행에서 편하게 입었어요~ 허리가 컸는데 허리띠하면 괜찮았어요
# 리뷰3:  기장이 애매해서 저는 길이 수선하고 입으려구요~
# 사이즈 대충보고 샀더니 살짝크네요 살도 조금 빠져서
# 옷은 맘에 들어용~
#
# ---- 001008 11번째 의류
# 상품 :  USS
# 평점 :  5
# 리뷰수 :  5
# 리뷰1:  너무 예뻐요.. 적당한 핏 바지 찾다가 우연히 알고리즘에 걸려서 생지랑 고민하다가 블랙으로 샀는데 하. 허리도 잘 맞고 기장도 좀 길긴하지만 좋아요 핏 너무 예쁨.. 단추구멍은 뻑뻑해서 가위로 좀 정리했어요ㅋㅋ 생지 이염때문에 안 샀는데 레귤러말고 슬림핏으로 사야겠어요ㅋㅋ 처음 본 브랜드인데 어스 바지맛집이네요
# 리뷰2:  기장은 길지만 허리랑 엉덩이쪽은 잘 맞아요!
# 처음 사보는 브랜드인데 핏도 예쁘고 괜찮네요~!
# 다만 단추 끼우는데 엄청 뻑뻑해서 잘 안됐어요
# 한여름 빼고는 잘 입을거같습니다
# 리뷰3:  기장은 길어서 원하던길이지만 스판도 좀있어서
# 입다보면 좀 품 하고 허리 늘어날꺼 같은 소재네요
# 편하게 입을 바지이긴해요
#
# ---- 001008 12번째 의류
# 상품 :  MEMUA
# 평점 :  5
# 리뷰수 :  3
# 리뷰1:  청바지 두번째 구매인데 좋아요. 두께감도 길이도 핏도 좋고 배송도 빠르네요. 세일해서 가격도 넘 좋아요.
# 리뷰2:  굿 굿 굿이요
# 리뷰3:  옷은 맘에 드는데
# 저에겐 M사이즈가 크네요
# 가격도 착해서
# S사이즈 하나 더 주문해야겠어요
#
# ---- 001008 13번째 의류
# 상품 :  USS
# 평점 :  4.9
# 리뷰수 :  14
# 리뷰1:  일단 넘 예뻐요
# 너무 부츠컷이라서 수선을하니 딱 예쁜 핏이에요
# 그리고 편해서 자주 손이 가는 바지에요
# 다만 입기만해도 신발이나 흰옷이나 손에 생지가 염색이 되서 ㅠㅠ 조심히 입어야해요
# 리뷰2:  예쁜데 허리가
# 너무커서 속옷다 보여요 ㅠ 허리 줄여서 입을까 생각중
# 이염이 심하지는 않은데 물묻으면 청색 묻어나서 세탁할때나 흰옷입을때는 조심해야할듯 합니다
# 신축성 좋아서 엄청 편해서 조금 작게 사셔도 되실것같아요 다른색도 사고싶음
# 리뷰3:  허리가
# 조금 불편한데 늘씬해보이도 이버료
#
# ---- 001008 14번째 의류
# 상품 :  L’oiE단독
# 평점 :  4.9
# 리뷰수 :  52
# 리뷰1:  생각보다 찔끔더크지만 그래도 괜찮은거같아요 너무 두껍지도않구요
# 리뷰2:  저한테는 크지만 롤업해서 입으니까 나름 괜찮습니다
# 천 빳빳하다고 해서 구입 했는데 오히려 착용감은 부드러웠숩니다
# 개인적으로 저는 구김이 많아서 환불하고 싶었는데 귀찮아서 집 앞에서만 입으려고요
# 컬러나 디자인은 깔끔해요
# 리뷰3:  꽉 끼지 않아 좋고 길이감도 짧지 않아 좋습니다
#
# ---- 001008 15번째 의류
# 상품 :  AUBE UE
# 평점 :  4.9
# 리뷰수 :  443
# 리뷰1:  살다보니 제가 화이트 바지도 사보네요
# 부해보인다 생각해서 늘 기피했는데...
# 진짜 예쁩니다 체형커버가 되다니 놀랐어요
# 화이트가 약간 아이보리 계열이라 부담없이 입을수있고
# 속옷 비침도 없네요 🥹
# 요즘 브랜드 바지 이 가격에 사기 힘든데 ㅜㅜ 가격대비 대만족해요
# 바지 맛집으로 워낙 유명해서 예전부터 애용했는데
# 봄에 품절돼서 못사고 이번에 재입고 되자마자
# 뮤 스트레이트 데님 저도 3컬러 다 사봤어요
# 스판이 좋아서 완전 편하고 허리는 살짝 여유있는 편이라 힙해보여요
# 보통 허리 31-32인치인 사람이라 엑스라지 길만 걸어온
# 사람인데 괜히 기분 좋네요
# 체형커버 갑인 바지 두께감도 딱이고 밴딩이 아닌게
# 믿기지않을만큼 편해요🩵🩵
# 리뷰2:  핏은 이쁜데 사이즈가 좀 커서 아쉬워여ㅠㅠ
# 리뷰3:  타브랜드의 와이드 화이트 팬츠 입는데 너무 부해보여서 고민하다가 이 바지는 덜부해보일거같아서 구매했어요 xs사이즈지만 여유있는편이고 생각보다 스판끼 있어요 많이 늘어나지 않았으면 좋겠어요 배송 오래 걸릴줄 알았는데 출고 진짜 빨랐어요
#
# ---- 001008 16번째 의류
# 상품 :  LANGER
# 평점 :  5
# 리뷰수 :  189
# 리뷰1:  스타일은 좋아요~일단 한여름과 한겨울에는 못 입고 무난한 날씨에 입을 수 있는 두께에요~
# 스타일이 그러다보니 생각보다 날씬해 보이진 않는 듯 해요..
# 길이감도 저한텐 수선할 필요없이 잘 입을 것 같고.
# 일단 키가 어느정도 있으면 더 잘 어울릴 듯.
# 할인할때 사서 정가였음 약간은 비싸다 생각할 것 같아요~
# 리뷰2:  언니 선물로 구입했는데 너무 잘 어울리고 사이즈 길 넘 마음에 들어하네요
# 리뷰3:  통은 큰거 알구 주문했는데 허리가 다른바지들보다 좀 더 큰거 같아요.그래도 핏.색상.디자인 모두 맘에 들어 너무 잘 입고있어요.랑거바지 핏이 이쁜거 같아서 어제 다른바지도 하나 더 주문했어요.기대되네요
#
# ---- 001008 17번째 의류
# 상품 :  emkm
# 평점 :  5
# 리뷰수 :  83
# 리뷰1:  색깔도 예쁘고
# 입었을 때 넘 예뻐요
# 맘에 듭니다!!!
# 리뷰2:  27-28인치라서 엠사이즈를 사고 싶었는데 품절되어 속는셈 치고 s입어봤는데 괜찮네요!
# 허리 처음에 조이는듯했지만 며칠 지나니까 괜찮아졌어요
# 으음키임에서 연청 화이트 바지사고 너뮤 맘에 들어서 3번째 구매인데 후회없어요❤️
# 리뷰3:  입고되기를을매나기다렸던지 ㅠㅠ 믿고사는으음키임
#
# ---- 001008 18번째 의류
# 상품 :  MaLoupe
# 평점 :  5
# 리뷰수 :  42
# 리뷰1:  생각보다 길고커요
# 리뷰2:  얇고 가벼워서 여름에 입기 좋아요 전 기장이 길어서 수선..
# 쿠폰받아 저렴하게 구매했네요
# 리뷰3:  완전완전 하늘하늘 시원한 소재감이라 시원하고 너무 편해요ㅜㅜ 살짝 길어서 수선한 뒤 일주일 2,3번은 입고 있어요.
#
# ---- 001008 19번째 의류
# 상품 :  emkm
# 평점 :  4.9
# 리뷰수 :  133
# 리뷰1:  emkm은 첫구매인데 앞으로 최애브랜드가 될것 같아요
# 핏이 너무 좋고 길이어 길어서 좋아요 자주 구매할수 있게 쿠폰할인 많이 해주셨음 좋겠어요^^
# 리뷰2:  165cm기준으로 m착용했고 기장은 딱 좋아요! 화이트, 라이트블루, 블랙까지 세 개 소장중인 인생 데님이에요~~ 허리는 조금 여유있지만 골반이 있는편이라 와이존 부각없이 예뻐요
# 리뷰3:  너무 커가주구ㅠㅠ 아쉽 색감은 좋아요
#
# ---- 001008 20번째 의류
# 상품 :  AUBE UE
# 평점 :  4.9
# 리뷰수 :  380
# 리뷰1:  청바지 소재가 유연하고 가벼워서 착용감도 좋아여!!
# 사이즈가 여유있게 나왔는데 핏은 존예입니다.....
# 엉덩이 골반 큰 편이라 M이랑 L중에 고민했는데 M도 여유있게 맞아요!!! L사이즈했으면 모델핏까진 아니지만 좀더 오버핏으로 떨어졌을 거 같아여 ㅎㅎ
#
# 키는 161cm이고 (다리가 긴 편이긴 함) 운동화랑 입었을 때 길이감이 너무 마음에 들어요 ㅋㅋㅋㅋ 대신 컨버스처럼 굽 없는 신발은 바지가 끌릴 거 같긴 합니다만 대부분 운동화가 굽이 있어서 걱정없어요 !!!! 딱 제가 원하던 길이랑 핏이라 감격스럽습니다 😭
#
# 뒤에 가죽패치도 청바지 색감이랑 너무 잘어울리고
# 청바지 색감도 사계절 부담없이 잘 입어질 색입니다
# 처음에도 언급했듯이 청바지 소재가 유연하고 가벼운 편이라 여름에 입기도 좋을 거 같아요!!!!
# 교복바지 각입니다 ㅋㅋㅋㅋㅋㅋ
# 리뷰2:  이 바지 정체가 뭐죠..? 입을때 좀 타이트한 느낌이라 반품할까 했는데, 완전히 입으니까 세상 편합니다. 이렇게 편한 청바지 진짜 오랜만이예요. 답답하지 않으면서도 몸매는 잘 잡아줘서 핏이 예뻐요. 얼릉 사세요!!!
# 리뷰3:  스판이네요 엄청 편합니다
# 여름에는 무리일 것 같지만요
#
# ---- 001008 21번째 의류
# 상품 :  FRONTROW단독
# 평점 :  5
# 리뷰수 :  48
# 리뷰1:  밝은색상을 구매하고 싶었는데 계속 품절이라; 아쉬운대로 구매했어요~ 모델착장이 없어 고민했는데 생각보다 진한색상이 아니어서 다행이네요ㅎ 크다는 후기보고 s로 했는데 정말 딱! 맞아요.. m사이즈였음 살짝 컸을 것 같아요
# 핏 예뻐요^^
# 리뷰2:  진짜 너무 맘에들어요
# 임신 후 살이 쪄서 인터넷주문하면 계속 맘에 안들어서 반품했는데, 오랜만에 맘에드는바지
# 뒷태가 부담스럽지않고 날씬해보이는 효과가 있네요
# 바지 이염만 심하지 않다면 완벽한 바지일거같은데
# 아직 세탁을 안해봐서 ....^^
# 리뷰3:  임신하고 골반이 넓어지고 뱃살이 안빠져서 임신전에 맞는 바지가 하나도 없는데 청바지는 입고 싶어서 고민하다 주문했는데 청바지가 늘어나는 재질이라 잘 맞아요😊 핏도 예쁘고 워싱도 예쁘고 맘에 듭니다
#
# ---- 001008 22번째 의류
# 상품 :  USS
# 평점 :  4.8
# 리뷰수 :  6
# 리뷰1:  핏이 좋네요. 부츠컷이면서 통이 넓어보여서 별론가 싶었는데 입어보니 다릅니다. 통도 그리 넓어보이지 않고 키가 작아도 수선 필요없이 5cm 굽 신으면 딱 좋아요. 다리도 길어보입니다. 다만 배가 조금 나와보이네요~~
# 리뷰2:  와우 바지 너무너무 이뻐용 헌데 제 키가 너무 작아서 바지 길이를 수선해야할 것 같긴 합니다!
# 허리는 딱 맞구요 핏 아주 예쁩니다. 날씬해보여요.
# 리뷰3:  이 바지 너무 이뻐요
# 블랙사고 너무 이뻐서 연청도 구입했어요
# 블랙보다 소재는 좀 더 부드럽네요
#
# ---- 001008 23번째 의류
# 상품 :  LOEIL
# 평점 :  4.9
# 리뷰수 :  244
# 리뷰1:  최근 살이 많이쪄서
# S, M 두개 구매했습니다.
# M은 힙하게 예쁜핏으로 입을 수 있을 것 같아요.
# 색상은 S사이즈보다 더 연하네요.
# 같은 상품이지만 색상때문에 다르게 입기 좋은 것 같아요. 키작녀에게도 딱이네요.
# 리뷰2:  최근 살이 많이쪄서 그런지 입는데 좀 시간이 걸리네요^^; 허리와 복부가 꽉 끼지만
# 살 좀 정리하면 예쁜핏으로 입을 수 있을 것 같아요.
# 색상도 길이감도 키작녀에게도 딱이네요.
# 사이즈 S, M 둘다 구매했습니다.
# M은 힙하게 입기 좋으네요.
# 리뷰3:  색상이 화면보다는 조금 흐립니다
# 후기보고 L사이즈 시켰는데 천만다행입니다
# 살짝 큰 M사이즈같은 느낌...
# M시켰음 너무 딱 맞아서 힘들었을버 같아요
# 바지는 무거운 감이 들고 냄새나서 바로 세탁했어요
#
# ---- 001008 24번째 의류
# 상품 :  UMER
# 평점 :  4.9
# 리뷰수 :  676
# 리뷰1:  인디고 블루 색상 사고 핏이 마음에 들어서 블랙 색상도 구매했습니다. 근데 상세사이즈도 조금 다르긴 했는데 허리는 더 맞고 허벅지나 엉덩이 부분은 커서 핏이 좀 달라요ㅠ
# 리뷰2:  핏이 이뻐요
# 다만 기장이 좀 짧아서 낮은굽 신발 신을때만 입어요
# 기장이 좀 길었음 좋겠어요
# 허리는 좀 여유가 있는데 골반은 맞아요
# 전 제인데님 블랙이 더 이쁜것 같아요
# 리뷰3:  인디고 색상 입고 재구매했어요.
# 다른 후기들처럼 무게는 나가는데 입으면 하나도 무겁지 않아요.
# 다리도 길어보이고 대만족이예요.
#
# ---- 001008 25번째 의류
# 상품 :  LANGER
# 평점 :  4.9
# 리뷰수 :  38
# 리뷰1:  핏이예쁘다는게뭔지입어보니까알겠네요
# 여름빼고는두루두루잘입을수있을것같고요~!
# 리뷰2:  기장이 너무길어 수선하였습니다.
# 선선해지면 입어야겠어요.
# 디자인 맘에 들어요
# 리뷰3:  한번 삿다가 너무 커서 반품햇는데 자꾸 아른거려서 세일할때 다시 삼 ㅜ 진짜 허리 너무 크고 길이도 긴데 줄여입게요ㅠ 핏은 개이쁘..
#
# ---- 001008 26번째 의류
# 상품 :  FACADE PATTERN
# 평점 :  4.9
# 리뷰수 :  49
# 리뷰1:  S.Xs고민하다 허리가 크면 불편할 듯 해. XS구매했는데, 딱 맘에 들어요. 모델핏처럼 입으려면S해야할 듯. 첨엔 붙는 듯 했는데, 조금 입고 있으니 허리도 다리통도 여유있어요.
# 리뷰2:  청색이랑 같은사이즈인데 좀더 작네요 색이 이뻐요 흔하지않은 컬러 굿~~~
# 리뷰3:  기장은조금 길어요 키가작은탓이고 재질좋습니다
#
# ---- 001008 27번째 의류
# 상품 :  LANGER
# 평점 :  5
# 리뷰수 :  8
# 리뷰1:  화면이랑 색상동일하고 신축성 없이 탄탄한 소재라서 잘 잡아줍니다 기장은 길어서 수선하거나 줄여야 할거 같지만 핏이 이뻐서 만족
# 리뷰2:  핏이랑 색이랑 예뻐요 길이는 좀 길어서 수선하고 입으려고 합니다
# 리뷰3:  너무 핏이 이쁩니다 호피데님도 눈여겨 보고 있어요 조만간 살것같네요 ㅎㅎ 디테일도 이쁘고 너무 맘에 쏙쏙 들어요!!!
#
# ---- 001008 28번째 의류
# 상품 :  FACADE PATTERN
# 평점 :  4.9
# 리뷰수 :  229
# 리뷰1:  편안하게 잘입을것 같아요
# 리뷰2:  왜 인기있는지 알겠어요 너무 멋잇고 마음에 쏙 들어요
# 리뷰3:  이뻐요.그치만 진짜 큼ㅋ
#
# ---- 001008 29번째 의류
# 상품 :  MaLoupe
# 평점 :  5
# 리뷰수 :  60
# 리뷰1:  원단 시원하고 핏이 이쁩니다
# 길이가 좀 긴편이에요
# 여름내내 잘 입고 있어요
# 리뷰2:  시원하고 편해서 즐겨입고 있습니다 🙂
# 리뷰3:  소재 시원하고 좋아요
# 키162기준 기장은 길어서 두단 줄였습니다~
#
# ---- 001008 30번째 의류
# 상품 :  mars en avril단독
# 평점 :  5
# 리뷰수 :  67
# 리뷰1:  바지 귀여워요 좀 어벙하긴하지만.. 나름 입을만한것 같아요~ 데님이라 시원해보이네용
# 리뷰2:  입으면 예쁘긴한데 통도크면서 짧아서 속바지를 입어도 조금 불편함은 감수해야할듯해요
# 리뷰3:  손이 제일 많이 가는 나의 최애 바지 입니당
