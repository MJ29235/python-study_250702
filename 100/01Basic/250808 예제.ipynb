# %%
# 인터파크 티켓에서 공연 카테고리를 클릭해 공연명과 일정 정보를 수집하세요.
# 신세계몰에서 ‘식품’ 카테고리의 오늘의 특가 상품명을 수집하세요.
# 페이스북 로그인 후 특정 페이지의 최근 게시글 제목을 수집하세요.
# 카카오맵에서 '맛집' 검색 후 스크롤하여 장소명과 별점을 수집하세요.

# %%
# 인터파크 티켓에서 공연 카테고리를 클릭해 공연명과 일정 정보를 수집하세요.

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import time

service = Service(ChromeDriverManager().install())
options = Options()
# options.add_argument("--headless")
options.add_argument("--window-size=1920x1080")
options.add_argument("--lang=ko_KR")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36")

driver = webdriver.Chrome(service=service, options=options)
url = "https://tickets.interpark.com/contents/genre/musical"
driver.get(url)
time.sleep(2)

try : 
    musical_button = driver.find_element(By.CSS_SELECTOR, "a._category-menu-selected_yvggm_21")
    musical_button.click()
    time.sleep(2)
except Exception as e:
    print("뮤지컬 버튼 클릭 실패 : ", e)

driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(1)

# cards = driver.find_elements(By.CSS_SELECTOR,"ul.TicketItem_contentsWrap__xCe3A")
# for i,card in enumerate(cards,1):
#     titles = card.find_elements(By.CSS_SELECTOR,"li.TicketItem_goodsName__Ju76j")
#     date = card.find_elements(By.CSS_SELECTOR,"li.TicketItem_playDate__5ePr2")
#     print(f"{i}. {titles.text.strip()},{date.text.strip()}")

# time.sleep(1)
# driver.quit()
# Out:
# 카드 방식으로 찾은 공연 수: 31
# 카드 1 처리 실패: Message: no such element: Unable to locate element: {"method":"css selector","selector":".TicketItem_goodsName__Ju76j"}
#   (Session info: chrome=138.0.7204.184); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	GetHandleVerifier [0x0x84ba83+63395]
# 	GetHandleVerifier [0x0x84bac4+63460]
# 	(No symbol) [0x0x692113]
# 	(No symbol) [0x0x6da85e]
# 	(No symbol) [0x0x6dabfb]
# 	(No symbol) [0x0x6d0081]
# 	(No symbol) [0x0x6ff3f4]
# 	(No symbol) [0x0x6cffa4]
# 	(No symbol) [0x0x6ff624]
# 	(No symbol) [0x0x7207ba]
# 	(No symbol) [0x0x6ff1a6]
# 	(No symbol) [0x0x6ce7b2]
# 	(No symbol) [0x0x6cf654]
# 	GetHandleVerifier [0x0xac8883+2672035]
# 	GetHandleVerifier [0x0xac3cba+2652634]
# 	GetHandleVerifier [0x0x872bca+223466]
# 	GetHandleVerifier [0x0x862cb8+158168]
# 	GetHandleVerifier [0x0x86978d+185517]
# 	GetHandleVerifier [0x0x853b78+96408]
# ...
