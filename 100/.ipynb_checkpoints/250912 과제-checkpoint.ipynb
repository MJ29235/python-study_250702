# %%
import requests
from bs4 import BeautifulSoup

url = "https://books.toscrape.com/catalogue/category/books/travel_2/index.html"
base_url = "https://books.toscrape.com/catalogue/"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

books = soup.select("article.product_pod")
category = "Travel"

for i, book in enumerate(books, 1):
    title = book.h3.a["title"]
    price = book.select_one("p.price_color").text.strip()
    stock = book.select_one("p.instock.availability").text.strip()

    rating_tag = book.select_one("p.star-rating")
    rating = rating_tag["class"][1] if rating_tag else "No rating"

    relative_url = book.h3.a["href"]
    product_url = base_url + relative_url.replace("../../../", "")

    print(f"\n {i}.\n제목: {title}")
    print(f"가격: {price}")
    print(f"재고: {stock}")
    print(f"평점: {rating}")
    print(f"카테고리: {category}")
    print(f"URL: {product_url}")
# Out:
#  1.
# 제목: It's Only the Himalayas
# 가격: Â£45.17
# 재고: In stock
# 평점: Two
# 카테고리: Travel
# URL: https://books.toscrape.com/catalogue/its-only-the-himalayas_981/index.html
#
#  2.
# 제목: Full Moon over Noahâs Ark: An Odyssey to Mount Ararat and Beyond
# 가격: Â£49.43
# 재고: In stock
# 평점: Four
# 카테고리: Travel
# URL: https://books.toscrape.com/catalogue/full-moon-over-noahs-ark-an-odyssey-to-mount-ararat-and-beyond_811/index.html
#
#  3.
# 제목: See America: A Celebration of Our National Parks & Treasured Sites
# 가격: Â£48.87
# 재고: In stock
# 평점: Three
# 카테고리: Travel
# URL: https://books.toscrape.com/catalogue/see-america-a-celebration-of-our-national-parks-treasured-sites_732/index.html
#
#  4.
# 제목: Vagabonding: An Uncommon Guide to the Art of Long-Term World Travel
# 가격: Â£36.94
# 재고: In stock
# 평점: Two
# 카테고리: Travel
# URL: https://books.toscrape.com/catalogue/vagabonding-an-uncommon-guide-to-the-art-of-long-term-world-travel_552/index.html
#
#  5.
# 제목: Under the Tuscan Sun
# 가격: Â£37.33
# 재고: In stock
# 평점: Three
# 카테고리: Travel
# URL: https://books.toscrape.com/catalogue/under-the-tuscan-sun_504/index.html
#
#  6.
# 제목: A Summer In Europe
# 가격: Â£44.34
# 재고: In stock
# 평점: Two
# 카테고리: Travel
# URL: https://books.toscrape.com/catalogue/a-summer-in-europe_458/index.html
#
#  7.
# 제목: The Great Railway Bazaar
# 가격: Â£30.54
# 재고: In stock
# 평점: One
# 카테고리: Travel
# URL: https://books.toscrape.com/catalogue/the-great-railway-bazaar_446/index.html
#
#  8.
# 제목: A Year in Provence (Provence #1)
# 가격: Â£56.88
# 재고: In stock
# 평점: Four
# 카테고리: Travel
# URL: https://books.toscrape.com/catalogue/a-year-in-provence-provence-1_421/index.html
#
#  9.
# 제목: The Road to Little Dribbling: Adventures of an American in Britain (Notes From a Small Island #2)
# 가격: Â£23.21
# 재고: In stock
# 평점: One
# 카테고리: Travel
# URL: https://books.toscrape.com/catalogue/the-road-to-little-dribbling-adventures-of-an-american-in-britain-notes-from-a-small-island-2_277/index.html
#
#  10.
# 제목: Neither Here nor There: Travels in Europe
# 가격: Â£38.95
# 재고: In stock
# 평점: Three
# 카테고리: Travel
# URL: https://books.toscrape.com/catalogue/neither-here-nor-there-travels-in-europe_198/index.html
#
#  11.
# 제목: 1,000 Places to See Before You Die
# 가격: Â£26.08
# 재고: In stock
# 평점: Five
# 카테고리: Travel
# URL: https://books.toscrape.com/catalogue/1000-places-to-see-before-you-die_1/index.html
