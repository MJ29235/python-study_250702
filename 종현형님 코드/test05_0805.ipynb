# %%
#브런치 홈페이지에서 인기 글 제목을 수집하세요.
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import urllib
import time

service = Service(ChromeDriverManager().install())

options = Options()
options.add_argument("--headless")
options.add_argument("--window-size=1920x1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")

driver = webdriver.Chrome(service=service, options=options)

query = "#sun"
encoded_query = urllib.parse.quote(query)

# url = f"https://brunch.co.kr/serial/list{query}#PUBLISH_TIME"
# driver.get(url)
# time.sleep(1)
weeks = ["#mon", "#tue", "#wed", "#thu", "#fri", "#sat", "#sun"]
# titles= driver.find_elements(By.CSS_SELECTOR, "strong.tit_info")

for week in weeks :
    driver.get(f"https://brunch.co.kr/serial/list{week}#PUBLISH_TIME")
    time.sleep(1)
    print(f"\n{week} 베스트\n")
    titles= driver.find_elements(By.CSS_SELECTOR, "strong.tit_info")
    for i, title in enumerate(titles, 1) :
        print(f"{i}. {title.text.strip().replace("\n","")}")

driver.quit()
# Out:
# #mon 베스트
#
# 1. 당신도 모르게
# 2. 두 번째 고양이 합사하기
# 3. 2-3 감정데이터 시대를 산다.
# 4. 사적인 집을 만들기 위한 질문들
# 5. 오프닝 : 카렌홀의 남자
# 6. 해바라기
# 7. 8. 인지
# 8. 자연과 친밀감 유지하기
# 9. 너무 늦은 시간
# 10. 아이가 이 책 재밌겠다, 말한다
# 11. 여름에 잘 어울리는 소설은?
# 12. 나홀로 제주여행
# 13. 2화. “가면 벗고 얘기하자”
# 14. Q. 1 - 10
# 15. 전지적 '이모'시점
# 16. 미술관(들)
# 17. 7월 마지막 주 감사일기
# 18. '할 수 있음'에서 '하고 싶음'으로
# 19. 출간 후에도 멈추지 않고 글을 쓰는 이유
# 20. 관찰일기 03 망설임과 감사
#
# #tue 베스트
#
# 1. 당신도 모르게
# 2. 두 번째 고양이 합사하기
# 3. 2-3 감정데이터 시대를 산다.
# 4. 사적인 집을 만들기 위한 질문들
# 5. 오프닝 : 카렌홀의 남자
# 6. 해바라기
# 7. 8. 인지
# 8. 자연과 친밀감 유지하기
# 9. 너무 늦은 시간
# 10. 아이가 이 책 재밌겠다, 말한다
# 11. 여름에 잘 어울리는 소설은?
# 12. 나홀로 제주여행
# 13. 2화. “가면 벗고 얘기하자”
# 14. Q. 1 - 10
# 15. 전지적 '이모'시점
# 16. 미술관(들)
# 17. 7월 마지막 주 감사일기
# 18. '할 수 있음'에서 '하고 싶음'으로
# 19. 출간 후에도 멈추지 않고 글을 쓰는 이유
# 20. 관찰일기 03 망설임과 감사
#
# #wed 베스트
#
# 1. 당신도 모르게
# 2. 두 번째 고양이 합사하기
# 3. 2-3 감정데이터 시대를 산다.
# 4. 사적인 집을 만들기 위한 질문들
# 5. 오프닝 : 카렌홀의 남자
# 6. 해바라기
# 7. 8. 인지
# 8. 자연과 친밀감 유지하기
# 9. 너무 늦은 시간
# 10. 아이가 이 책 재밌겠다, 말한다
# 11. 여름에 잘 어울리는 소설은?
# 12. 나홀로 제주여행
# 13. 2화. “가면 벗고 얘기하자”
# 14. Q. 1 - 10
# 15. 전지적 '이모'시점
# 16. 미술관(들)
# 17. 7월 마지막 주 감사일기
# 18. '할 수 있음'에서 '하고 싶음'으로
# 19. 출간 후에도 멈추지 않고 글을 쓰는 이유
# 20. 관찰일기 03 망설임과 감사
#
# #thu 베스트
#
# 1. 당신도 모르게
# 2. 두 번째 고양이 합사하기
# 3. 2-3 감정데이터 시대를 산다.
# 4. 사적인 집을 만들기 위한 질문들
# 5. 오프닝 : 카렌홀의 남자
# 6. 해바라기
# 7. 8. 인지
# 8. 자연과 친밀감 유지하기
# 9. 너무 늦은 시간
# 10. 아이가 이 책 재밌겠다, 말한다
# 11. 여름에 잘 어울리는 소설은?
# 12. 나홀로 제주여행
# 13. 2화. “가면 벗고 얘기하자”
# 14. Q. 1 - 10
# 15. 전지적 '이모'시점
# 16. 미술관(들)
# 17. 7월 마지막 주 감사일기
# 18. '할 수 있음'에서 '하고 싶음'으로
# 19. 출간 후에도 멈추지 않고 글을 쓰는 이유
# 20. 관찰일기 03 망설임과 감사
#
# #fri 베스트
#
# 1. 당신도 모르게
# 2. 두 번째 고양이 합사하기
# 3. 2-3 감정데이터 시대를 산다.
# 4. 사적인 집을 만들기 위한 질문들
# 5. 오프닝 : 카렌홀의 남자
# 6. 해바라기
# 7. 8. 인지
# 8. 자연과 친밀감 유지하기
# 9. 너무 늦은 시간
# 10. 아이가 이 책 재밌겠다, 말한다
# 11. 여름에 잘 어울리는 소설은?
# 12. 나홀로 제주여행
# 13. 2화. “가면 벗고 얘기하자”
# 14. Q. 1 - 10
# 15. 전지적 '이모'시점
# 16. 미술관(들)
# 17. 7월 마지막 주 감사일기
# 18. '할 수 있음'에서 '하고 싶음'으로
# 19. 출간 후에도 멈추지 않고 글을 쓰는 이유
# 20. 관찰일기 03 망설임과 감사
#
# #sat 베스트
#
# 1. 당신도 모르게
# 2. 두 번째 고양이 합사하기
# 3. 2-3 감정데이터 시대를 산다.
# 4. 사적인 집을 만들기 위한 질문들
# 5. 오프닝 : 카렌홀의 남자
# 6. 해바라기
# 7. 8. 인지
# 8. 자연과 친밀감 유지하기
# 9. 너무 늦은 시간
# 10. 아이가 이 책 재밌겠다, 말한다
# 11. 여름에 잘 어울리는 소설은?
# 12. 나홀로 제주여행
# 13. 2화. “가면 벗고 얘기하자”
# 14. Q. 1 - 10
# 15. 전지적 '이모'시점
# 16. 미술관(들)
# 17. 7월 마지막 주 감사일기
# 18. '할 수 있음'에서 '하고 싶음'으로
# 19. 출간 후에도 멈추지 않고 글을 쓰는 이유
# 20. 관찰일기 03 망설임과 감사
#
# #sun 베스트
#
# 1. 당신도 모르게
# 2. 두 번째 고양이 합사하기
# 3. 2-3 감정데이터 시대를 산다.
# 4. 사적인 집을 만들기 위한 질문들
# 5. 오프닝 : 카렌홀의 남자
# 6. 해바라기
# 7. 8. 인지
# 8. 자연과 친밀감 유지하기
# 9. 너무 늦은 시간
# 10. 아이가 이 책 재밌겠다, 말한다
# 11. 여름에 잘 어울리는 소설은?
# 12. 나홀로 제주여행
# 13. 2화. “가면 벗고 얘기하자”
# 14. Q. 1 - 10
# 15. 전지적 '이모'시점
# 16. 미술관(들)
# 17. 7월 마지막 주 감사일기
# 18. '할 수 있음'에서 '하고 싶음'으로
# 19. 출간 후에도 멈추지 않고 글을 쓰는 이유
# 20. 관찰일기 03 망설임과 감사

# %%
#구글 Scholar에서 'SEO Marketing' 논문 제목을 5개 수집하세요.
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import urllib
import time

service = Service(ChromeDriverManager().install())

options = Options()
options.add_argument("--headless")
options.add_argument("--window-size=1920x1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")

driver = webdriver.Chrome(service=service, options=options)

query = "scholar?hl=ko&as_sdt=0%2C5&q=SEO+Marketing&btnG="
encoded_query = urllib.parse.quote(query)

driver.get(f"https://scholar.google.com/{query}")
time.sleep(1)

titles = driver.find_elements(By.CSS_SELECTOR, "h3.gs_rt")

for i, title in enumerate(titles[:5], 1) :
    print(f"{i}. {title.text}")

driver.quit()
# Out:
# 1. [책] Inbound marketing and SEO: Insights from the Moz Blog
# 2. The role of search engine optimization in search marketing
# 3. Application marketing strategy search engine optimization (SEO)
# 4. [책] Optimize: How to attract and engage more customers by integrating SEO, social media, and content marketing
# 5. [PDF] ¿ Marketing online?¿ SEO?¿ SEM? Conceptos básicos

# %%
#TIOBE Index 사이트에서 상위 10개 프로그래밍 언어 이름을 수집하세요.
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import urllib
import time

service = Service(ChromeDriverManager().install())

options = Options()
options.add_argument("--headless")
options.add_argument("--window-size=1920x1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")

driver = webdriver.Chrome(service=service, options=options)

query = ""
encoded_query = urllib.parse.quote(query)

driver.get(f"https://www.tiobe.com/tiobe-index/{query}")
time.sleep(1)

titles = driver.find_elements(By.CSS_SELECTOR, "table#top20 > tbody > tr > td:nth-child(5)")


for i, title in enumerate(titles[:10], 1) :
    print(f"{i}위. {title.text}")

driver.quit()
# Out:
# 1위. Python
# 2위. C++
# 3위. C
# 4위. Java
# 5위. C#
# 6위. JavaScript
# 7위. Visual Basic
# 8위. Go
# 9위. Perl
# 10위. Delphi/Object Pascal

# %%
#데이터마켓(data.go.kr)에서 '소비' 관련 공공데이터 제목을 10개 수집하세요.
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import urllib
import time

service = Service(ChromeDriverManager().install())

options = Options()
options.add_argument("--headless")
options.add_argument("--window-size=1920x1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")

driver = webdriver.Chrome(service=service, options=options)

query = "tcs/dss/selectDataSetList.do?keyword=%EC%86%8C%EB%B9%84"
encoded_query = urllib.parse.quote(query)

driver.get(f"https://www.data.go.kr/{query}")
time.sleep(1)

titles = driver.find_elements(By.CSS_SELECTOR, "span.title")

for i, title in enumerate(titles[:10], 1) :
    print(f"{i}. {title.text}")

driver.quit()
# Out:
# 1. 소득소비조사
# 2. 인천광역시_소비 데이터
# 3. 국토연구원_부동산시장 소비심리 정보
# 4. 대전광역시 유성구_법정동별 소비금액 데이터
# 5. 대전광역시 유성구_건당 평균 소비 데이터
# 6. 농림축산식품부_우유 및 유제품 생산소비현황
# 7. 제주특별자치도_단체/개별 관광객 소비 데이터
# 8. 한국남부발전(주)_연료소비실적 정보
# 9. 한국서부발전(주)_연료소비실적 조회서비스
# 10. 한국중부발전(주)_연료소비실적 조회서비스

# %%
#알라딘에서 '자기계발' 베스트 도서의 제목과 저자를 수집하세요.
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import time

service = Service(ChromeDriverManager().install())
options = Options()
options.add_argument("--headless")
options.add_argument("--window-size=1920x1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")

driver = webdriver.Chrome(service=service, options=options)

url = "https://www.aladin.co.kr/shop/wbrowse.aspx?CID=38400&start=we_header"
driver.get(url)
time.sleep(2)

books = driver.find_elements(By.CSS_SELECTOR, "div.ss_book_box")

for i, book in enumerate(books, 1):
    try:
        title_tag = book.find_element(By.CSS_SELECTOR, "a.bo3")
        title = title_tag.text.strip()
    except:
        title = "제목 없음"

    try:
        author_links = book.find_elements(By.XPATH, ".//li/a[contains(@href, 'AuthorSearch')]")
        author = author_links[0].text.strip() if author_links else "저자 없음"
    except:
        author = "저자 없음"

    print(f"{i}. {title} - {author}")

driver.quit()
# Out:
# 1. 미묘한 메모의 묘미 - 김중혁
# 2. 열심히 살아도 불안한 사람들 - 랄리타 수글라니
# 3. 듀얼 브레인 - 이선 몰릭
# 4. 데일 카네기 인간관계론 - 데일 카네기
# 5. 행동은 불안을 이긴다 - 롭 다이얼
# 6. 다시, 가슴 뛰는 삶을 살아라 - 다릴 앙카
# 7. 질문의 격 - 유선경
# 8. 왓츠 유어 드림 - 사이먼 스큅
# 9. 데일 카네기 자기관리론 - 데일 카네기
# 10. 생각의 주도권을 디자인하라 - 박용후
# 11. 리얼리티 트랜서핑. - 박인수
# 12. 인생은 게임이다 - 플로렌스 스코벨 신
# 13. 생각 중독자를 위한 관계 수업 - 닉 트렌턴
# 14. 아티스트 웨이 : 30주년 기념 특별판 - 줄리아 캐머런
# 15. 나는 보았습니다 - 박진여
# 16. 살아갈 날들을 위한 괴테의 시 - 김종원
# 17. 그릿 Grit - 김주환
# 18. 창조적 행위 : 존재의 방식 - 릭 루빈
# 19. 한석준의 대화의 기술 - 한석준
# 20. 끝까지 해내는 뇌 - 카이라 보비넷
# 21. 간절히 말하면 기적처럼 이루어진다 - 이유진
# 22. 바쁜 뇌를 회복하라 - 로미 무슈타크
# 23. 아주 작은 습관의 힘 - 제임스 클리어
# 24. 원씽 - 제이 파파산
# 25. 퓨처 셀프 30만 부 기념 스페셜 에디션 - 벤저민 하디
